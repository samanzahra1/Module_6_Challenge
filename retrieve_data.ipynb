# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json
import os
from datetime import datetime
## Load the NASA_API_KEY from the env file
load_dotenv()
NASA_API_KEY = os.getenv('NASA_API_KEY')

# %% [markdown]
# ### CME Data

# %%
# Set the base URL to NASA's DONKI API:
base_url = "https://api.nasa.gov/DONKI/"

# Set the specifier for CMEs:
CME = "CME"

# Search for CMEs published between a begin and end date
startDate = "2013-05-01"
endDate   = "2024-05-01"

# Build URL for CME
cme_url = f'{base_url}{CME}?StartDate={startDate}&EndDate={endDate}&api_key={NASA_API_KEY}'

# %%
# Make a "GET" request for the CME URL and store it in a variable named cme_response
cme_response = requests.get(cme_url)
cme_response
# Out:
# <Response [200]>

# %%
# Convert the response variable to json and store it as a variable named cme_json
cme_json = cme_response.json()
cme_json
# Out:
# [{'activityID': '2025-02-13T01:36:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-13T01:36Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Faint, narrow CME first seen in the NE by SOHO LASCO C2 beginning at 2025-02-13T01:36Z, as well as by SOHO LASCO C3 in later frames. This event is not visible in STEREO A COR2 due to a data gap from 2025-02-12T10:38Z to 2025-02-13T03:23Z. There is no clear source seen for this event aside from general field line movement along the NE limb seen in SDO AIA 193.',
#   'submissionTime': '2025-02-13T14:09Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37004/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-13T08:23Z',
#     'latitude': 21.0,
#     'longitude': None,
#     'halfAngle': 11.0,
#     'speed': 515.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'POS measurement due to range of longitude fits (approx. E70 to E100) and no clear source.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2025-02-13T14:10Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37005/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-13T15:23:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-13T15:23Z',
#   'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'},
#    {'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': 'S07W10',
#   'activeRegionNum': None,
#   'note': 'This CME is visible to the N/NE in SOHO LASCO C2, C3, and STEREO A COR2 imagery. It is very faint with a diffuse front. The potential source of this CME is a dimming centered around S07W10 just East of AR13992 as seen in SDO/AIA 193 and 211 starting around 2025-02-13T14:00Z.',
#   'submissionTime': '2025-02-14T01:37Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37321/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-13T21:19Z',
#     'latitude': 23.0,
#     'longitude': -10.0,
#     'halfAngle': 24.0,
#     'speed': 546.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'These parameters are based on the best fit of features in SOHO LASCO C2/C3 and STEREO A COR2 imagery. There is likely deflection of this CME due to the large coronal hole south of the potential source location.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 10.7,
#     'submissionTime': '2025-02-14T01:39Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37322/-1',
#     'enlilList': [{'modelCompletionTime': '2025-02-14T01:34Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': '2025-02-16T04:00Z',
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': 4,
#       'kp_135': 5,
#       'kp_180': 6,
#       'isEarthGB': True,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37323/-1',
#       'impactList': [{'isGlancingBlow': True,
#         'location': 'Europa Clipper',
#         'arrivalTime': '2025-02-18T00:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Lucy',
#         'arrivalTime': '2025-02-17T12:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Mars',
#         'arrivalTime': '2025-02-18T04:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2025-02-15T16:00Z'}],
#       'cmeIDs': ['2025-02-13T15:23:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-13T17:36:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-13T17:36Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'This CME is visible to the SE in SOHO LASCO C2 and C3 imagery. There is no STEREO A COR2 imagery available for this CME due to a data gap beginning at 2025-02-13T17:09Z. The source of this CME is likely a filament eruption visible in SDO/AIA 304 and 171 just beyond the SE limb starting around 2025-02-13T16:30Z.',
#   'submissionTime': '2025-02-14T02:22Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37324/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-13T23:47Z',
#     'latitude': -57.0,
#     'longitude': None,
#     'halfAngle': 16.0,
#     'speed': 552.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'Plane-of-sky fit using SWPC_CAT measurement tool.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 12.0,
#     'submissionTime': '2025-02-14T02:23Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37325/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-13T21:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-13T21:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'}],
#   'sourceLocation': 'N20W45',
#   'activeRegionNum': None,
#   'note': 'Narrow, faint CME seen to the northeast in SOHO LASCO C2 during a STEREO A data gap. Likely associated with a small filament eruption starting around 2025-02-13T20:00Z in the NE on Earth-facing disk around N20W45 (seen best in SDO AIA 193).',
#   'submissionTime': '2025-02-14T12:55Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37329/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-14T03:06Z',
#     'latitude': 19.0,
#     'longitude': -54.0,
#     'halfAngle': 10.0,
#     'speed': 531.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Preliminary one spacecraft leading edge measurement of the CME assuming that the source on the Earth-facing disk best represents this CME.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 7.0,
#     'submissionTime': '2025-02-14T13:00Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37330/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-14T08:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-14T08:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'}],
#   'sourceLocation': 'S21E06',
#   'activeRegionNum': 13994,
#   'note': 'Wide, faint CME seen primarily to the east in SOHO LASCO C2 and STEREO A COR2 which appears to be associated with a C6.6-class flare from Active Region 13994 and subsequent eruption seen best in SDO AIA 094 and SDO AIA 304 with notable deflection to the east. Despite the overall weak eruptive signature, triangulation strongly suggests that the eruption is associated with front-sided activity bounded by longitudes -25 to -45.',
#   'submissionTime': '2025-02-14T14:13Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37332/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-14T13:21Z',
#     'latitude': -16.0,
#     'longitude': -32.0,
#     'halfAngle': 31.0,
#     'speed': 701.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Two spacecraft leading-edge measurement using SOHO LASCO C2 and STEREO A COR2 to corroborate the longitude.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 12.0,
#     'submissionTime': '2025-02-14T14:22Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37333/-1',
#     'enlilList': [{'modelCompletionTime': '2025-02-14T14:05Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': '2025-02-16T16:00Z',
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': 4,
#       'kp_135': 5,
#       'kp_180': 6,
#       'isEarthGB': True,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37334/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2025-02-16T00:30Z'},
#        {'isGlancingBlow': True,
#         'location': 'Europa Clipper',
#         'arrivalTime': '2025-02-18T03:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Lucy',
#         'arrivalTime': '2025-02-17T17:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Mars',
#         'arrivalTime': '2025-02-18T06:00Z'}],
#       'cmeIDs': ['2025-02-14T08:48:00-CME-001']}]}],
#   'linkedEvents': [{'activityID': '2025-02-14T07:31:00-FLR-001'}]},
#  {'activityID': '2025-02-14T14:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-14T14:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'}],
#   'sourceLocation': 'S12E36',
#   'activeRegionNum': 13991,
#   'note': 'Jet CME seen to the southeast in SOHO LASCO C2 and STEREO A COR2A likely associated with a minor eruption from Active Region 13991 (S12E36), as evidenced by an eruptive signature taking place in SDO AIA 193.',
#   'submissionTime': '2025-02-14T17:13Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37336/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-14T20:31Z',
#     'latitude': -34.0,
#     'longitude': -43.0,
#     'halfAngle': 10.0,
#     'speed': 592.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Two spacecraft leading edge measurement.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 7.0,
#     'submissionTime': '2025-02-14T17:14Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37337/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-14T17:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-14T17:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'}],
#   'sourceLocation': 'S21W00',
#   'activeRegionNum': 13994,
#   'note': "Narrow CME seen to the southeast in SOHO LASCO C2 during a STEREO A data gap; the CME is possibly associated with a minor eruption from Active Region 13994 located near S21W00 as seen in SDO AIA 94, 304, though it isn't definitive where the eruption originates. Triangulation is not currently possible due to a STA COR2 data gap.",
#   'submissionTime': '2025-02-14T19:40Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37339/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-14T23:43Z',
#     'latitude': -34.0,
#     'longitude': None,
#     'halfAngle': 13.0,
#     'speed': 628.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'Preliminary plane of sky measurement given no STEREO A COR2 data is available.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 5.0,
#     'submissionTime': '2025-02-14T19:41Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37340/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-14T21:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-14T21:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': 'N14E33',
#   'activeRegionNum': None,
#   'note': 'CME seen to the NE in SOHO LASCO C2/C3 only, STEREO COR2A beacon data entirely misses this event. Partially overlaps with CME 2025-02-14T22:00Z to the SE. The source for this CME is likely an area of the disk ~N14E33 which brightens and releases some filament material to the NE starting around 2025-02-14T20:58Z, best observed in SDO AIA 171/193/304.',
#   'submissionTime': '2025-02-15T03:22Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37342/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-15T04:12Z',
#     'latitude': 4.0,
#     'longitude': -33.0,
#     'halfAngle': 17.0,
#     'speed': 507.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Single spacecraft 3D measurement using only SOHO LASCO C2/C3 imagery due to a STEREO COR2A data gap covering this CME, using the source coordinates of N14E33 as a basis.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2025-02-15T03:24Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37343/-1',
#     'enlilList': [{'modelCompletionTime': '2025-02-15T02:06Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37346/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2025-02-16T20:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Europa Clipper',
#         'arrivalTime': '2025-02-19T06:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Mars',
#         'arrivalTime': '2025-02-19T12:00Z'}],
#       'cmeIDs': ['2025-02-14T21:48:00-CME-001']},
#      {'modelCompletionTime': '2025-02-15T18:14Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': '2025-02-17T12:00Z',
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': 3,
#       'kp_135': 5,
#       'kp_180': 5,
#       'isEarthGB': True,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37358/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2025-02-16T19:51Z'},
#        {'isGlancingBlow': False,
#         'location': 'Europa Clipper',
#         'arrivalTime': '2025-02-19T06:00Z'},
#        {'isGlancingBlow': False,
#         'location': 'Mars',
#         'arrivalTime': '2025-02-19T11:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Lucy',
#         'arrivalTime': '2025-02-18T20:00Z'}],
#       'cmeIDs': ['2025-02-14T21:48:00-CME-001',
#        '2025-02-15T01:36:00-CME-001']},
#      {'modelCompletionTime': '2025-02-15T20:21Z',
#       'au': 5.5,
#       'estimatedShockArrivalTime': '2025-02-17T12:00Z',
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': 3,
#       'kp_135': 5,
#       'kp_180': 5,
#       'isEarthGB': True,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37363/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2025-02-16T19:35Z'},
#        {'isGlancingBlow': False,
#         'location': 'Europa Clipper',
#         'arrivalTime': '2025-02-19T06:00Z'},
#        {'isGlancingBlow': False,
#         'location': 'Mars',
#         'arrivalTime': '2025-02-19T11:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Lucy',
#         'arrivalTime': '2025-02-18T20:00Z'}],
#       'cmeIDs': ['2025-02-14T21:48:00-CME-001',
#        '2025-02-15T01:36:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-14T22:00:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-14T22:00Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': 'S30E68',
#   'activeRegionNum': None,
#   'note': 'CME seen to the SE in SOHO LASCO C2/C3 only, STEREO COR2A beacon data entirely misses this event. Partially overlaps with CME 2025-02-14T21:48Z to the NE. The source for this CME is likely a broad area of the disk ~S30E68 which slowly dims and moves field lines to the SE starting around 2025-02-14T21:00Z, best observed in SDO AIA 171/193 and GOES SUVI 284. There is a concurrent, separate M1.8 flare from AR 13990 (S12E13) which peaked at 2025-02-14T20:57Z which was considered for a source here, but ruled out with lower confidence than the SE quadrant dimming mentioned prior.',
#   'submissionTime': '2025-02-15T03:24Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37344/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-15T09:37Z',
#     'latitude': -21.0,
#     'longitude': -68.0,
#     'halfAngle': 27.0,
#     'speed': 303.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Single spacecraft 3D measurement using only SOHO LASCO C2/C3 imagery due to a STEREO COR2A data gap covering this CME, using the source coordinates of S30E68 as a basis.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 9.1,
#     'submissionTime': '2025-02-15T03:26Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37345/-1',
#     'enlilList': [{'modelCompletionTime': '2025-02-15T02:44Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37347/-1',
#       'impactList': [{'isGlancingBlow': True,
#         'location': 'Europa Clipper',
#         'arrivalTime': '2025-02-22T06:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Mars',
#         'arrivalTime': '2025-02-22T10:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2025-02-18T12:00Z'}],
#       'cmeIDs': ['2025-02-14T22:00:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-15T01:25:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-15T01:25Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': "Faint southeastern CME with a dimpled/fuzzy front, seen in both coronagraphs (in SOHO LASCO and in STEREO A COR2 after a data gap). It's source is unclear but possibly the very faint rising post-eruptive arcades and super minor dimming seen around 2025-02-15T00:40Z centered around (S30E65).",
#   'submissionTime': '2025-02-15T20:11Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37360/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-15T15:58Z',
#     'latitude': -20.0,
#     'longitude': -65.0,
#     'halfAngle': 28.0,
#     'speed': 242.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'A very speculative measurement based on the possible but not clear source and on a very approximate fit with two coronagraph. The fit is uncertain since especially in STEREO A the front of this CME is super unclear.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2025-02-15T20:13Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37361/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-15T01:36:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-15T01:36Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'N11E31',
#   'activeRegionNum': None,
#   'note': 'Fast CME seen  to the NE in both coronagraphs, faint in SOHO LASCO and bright in STEREO A COR2. In STEREO A it is only seen after the nighttime data gap ends. Its source is likely a significant filament eruption centered around N11E31, seen starting around 2025-02-15T00:56Z in GOES SUVI 304 and in SDO AIA 304, but also seen as small area brightening in SDO AIA 193. There is also a lower class C flare associated with it.',
#   'submissionTime': '2025-02-15T22:03Z',
#   'versionId': 2,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37353/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-15T05:48Z',
#     'latitude': 10.0,
#     'longitude': -31.0,
#     'halfAngle': 20.0,
#     'speed': 722.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Analysis based on the fit with two coronagraphs; it corresponds well to the location of the source eruption.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2025-02-15T22:04Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37354/-1',
#     'enlilList': [{'modelCompletionTime': '2025-02-15T17:52Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': '2025-02-17T12:00Z',
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': 3,
#       'kp_135': 4,
#       'kp_180': 5,
#       'isEarthGB': True,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37355/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2025-02-16T20:38Z'},
#        {'isGlancingBlow': False,
#         'location': 'Europa Clipper',
#         'arrivalTime': '2025-02-19T06:00Z'},
#        {'isGlancingBlow': False,
#         'location': 'Mars',
#         'arrivalTime': '2025-02-19T11:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Lucy',
#         'arrivalTime': '2025-02-18T20:00Z'}],
#       'cmeIDs': ['2025-02-15T01:36:00-CME-001']},
#      {'modelCompletionTime': '2025-02-15T18:14Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': '2025-02-17T12:00Z',
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': 3,
#       'kp_135': 5,
#       'kp_180': 5,
#       'isEarthGB': True,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37358/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2025-02-16T19:51Z'},
#        {'isGlancingBlow': False,
#         'location': 'Europa Clipper',
#         'arrivalTime': '2025-02-19T06:00Z'},
#        {'isGlancingBlow': False,
#         'location': 'Mars',
#         'arrivalTime': '2025-02-19T11:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Lucy',
#         'arrivalTime': '2025-02-18T20:00Z'}],
#       'cmeIDs': ['2025-02-14T21:48:00-CME-001',
#        '2025-02-15T01:36:00-CME-001']},
#      {'modelCompletionTime': '2025-02-15T20:21Z',
#       'au': 5.5,
#       'estimatedShockArrivalTime': '2025-02-17T12:00Z',
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': 3,
#       'kp_135': 5,
#       'kp_180': 5,
#       'isEarthGB': True,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37363/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2025-02-16T19:35Z'},
#        {'isGlancingBlow': False,
#         'location': 'Europa Clipper',
#         'arrivalTime': '2025-02-19T06:00Z'},
#        {'isGlancingBlow': False,
#         'location': 'Mars',
#         'arrivalTime': '2025-02-19T11:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Lucy',
#         'arrivalTime': '2025-02-18T20:00Z'}],
#       'cmeIDs': ['2025-02-14T21:48:00-CME-001',
#        '2025-02-15T01:36:00-CME-001']}]}],
#   'linkedEvents': [{'activityID': '2025-02-15T00:50:00-FLR-001'}]},
#  {'activityID': '2025-02-15T13:25:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-15T13:25Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Bright CME with a high southern latitude, seen to the west in STEREO A COR2 and almost exactly to the south in SOHO LASCO, indicating a backsided source. Coronal signatures include a huge prominence seen directly to the south in GOES SUVI 304 starting at 2025-02-12:56Z and originating behind the south limb, and also seen as an extensive movement of matter/field lines to the south and southeast in GOES SUVI 284, also likely happening behind the southern limb. Coronal signatures are almost not seen in SDO AIA, except for minimal movement of ejecta seen in AIA 304.',
#   'submissionTime': '2025-02-15T18:34Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37356/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-15T17:38Z',
#     'latitude': -43.0,
#     'longitude': 173.0,
#     'halfAngle': 37.0,
#     'speed': 820.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Analysis based on the fit with two coronagraphs and corresponding well to the southern filament see in EUVI imagery.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2025-02-15T18:35Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37357/-1',
#     'enlilList': [{'modelCompletionTime': '2025-02-15T20:50Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37365/-1',
#       'impactList': [{'isGlancingBlow': True,
#         'location': 'BepiColombo',
#         'arrivalTime': '2025-02-16T10:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Parker Solar Probe',
#         'arrivalTime': '2025-02-17T09:00Z'}],
#       'cmeIDs': ['2025-02-15T13:25:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-15T19:36:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-15T19:36Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Narrow CME visible in the southwest of SOHO LASCO C2/C3. Not visible in STEREO A COR2 due to a data gap starting at 2025-02-15T17:09Z. The source is not visible in EUV imagery, and my be farsided.',
#   'submissionTime': '2025-02-15T23:48Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37367/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-16T05:21Z',
#     'latitude': -74.0,
#     'longitude': None,
#     'halfAngle': 17.0,
#     'speed': 365.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'Plane-of-sky measurement using SOHO LASCO C2/C3 difference imagery in SWPC_CAT due to lack of known source location.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 7.6,
#     'submissionTime': '2025-02-15T23:50Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37368/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-15T20:36:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-15T20:36Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': 'N06W90',
#   'activeRegionNum': 13983,
#   'note': 'CME visible to the northwest in SOHO LASCO C2/C3. The CME is partially obscured by the pylon in SOHO LASCO C3. No visible in STEREO A COR2 due to a data gap starting at 2025-02-15T17:09Z. The source is an eruption from Active Region 13983 (approx. N06W90) starting at 2025-02-15T19:22Z. Brightening and opening field lines are best seen in SDO AIA 171/193 and GOES SUVI 284. The eruption is also visible in SDO AIA 304 imagery.',
#   'submissionTime': '2025-02-16T00:06Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37369/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-16T02:30Z',
#     'latitude': 39.0,
#     'longitude': 85.0,
#     'halfAngle': 22.0,
#     'speed': 605.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on approximate source location. Only SOHO LASCO C2 imagery was available for a measurement, as the CME was blocked by the pylon in SOHO LASCO C3.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 8.1,
#     'submissionTime': '2025-02-16T00:08Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37370/-1',
#     'enlilList': [{'modelCompletionTime': '2025-02-16T00:24Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37372/-1',
#       'impactList': None,
#       'cmeIDs': ['2025-02-15T20:36:00-CME-001']}]}],
#   'linkedEvents': [{'activityID': '2025-02-15T19:22:00-FLR-001'}]},
#  {'activityID': '2025-02-16T00:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-16T00:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Narrow flux rope CME seen to the SW in SOHO LASCO C2/C3 and STEREO A COR2. The source is not visible in available EUV imagery, but is on the farside based on triangulation between the SOHO LASCO and STEREO A COR2 coronagraphs. This CME is partially covered by a data gap in STEREO A COR2 which lasted from 2025-02-15T16:53Z to 2025-02-16T05:23Z.',
#   'submissionTime': '2025-02-16T18:53Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37379/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-16T08:52Z',
#     'latitude': -53.0,
#     'longitude': 152.0,
#     'halfAngle': 18.0,
#     'speed': 403.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Best fit measurement using several SOHO LASCO C3 frames and two frames of STEREO A COR2 before the leading edge leaves the COR2 field of view. This CME is partially covered by a data gap in STEREO A COR2 which lasted from 2025-02-15T16:53Z to 2025-02-16T05:23Z.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 17.0,
#     'submissionTime': '2025-02-16T19:00Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37380/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-16T09:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-16T09:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'N27E30',
#   'activeRegionNum': None,
#   'note': 'Faint loop CME seen to the S in SOHO LASCO C2 and the SE in STEREO A COR2. The leading edge is too diffuse to discern in SOHO LASCO C3. Source is a small eruption from N27E30: a narrow set of opening field lines from the location is seen in GOES SUVI 284 at 2025-02-16T07:45Z as well as post-eruptive brightening seen in SDO AIA 304 at 08:25Z, followed immediately by a much wider and fainter set of opening field lines which extends across the southern hemisphere of the disk all the way to roughly near AR 13994 (S20W22).',
#   'submissionTime': '2025-02-16T20:20Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37381/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-16T18:48Z',
#     'latitude': -56.0,
#     'longitude': 3.0,
#     'halfAngle': 28.0,
#     'speed': 368.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Best fit measurement using SOHO LASCO C2 and STEREO A COR2, as well as the source location seen in UV imagery. Leading edge is too diffuse to track in SOHO LASCO C3.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 6.0,
#     'submissionTime': '2025-02-16T20:21Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37382/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-16T10:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-16T10:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Narrow loop CME to the N in SOHO LASCO C2/C3 and NW in STEREO A COR2. The source is not visible in available EUV imagery, but is on the farside based on triangulation between the SOHO LASCO and STEREO A COR2 coronagraphs.',
#   'submissionTime': '2025-02-16T18:32Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37377/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-16T20:38Z',
#     'latitude': 54.0,
#     'longitude': 163.0,
#     'halfAngle': 13.0,
#     'speed': 325.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Best fit measurement using an abundance of SOHO LASCO C2 frames, two frames of C3, and two frames of STEREO A COR2. The leading edge becomes diffuse after a few frames of C3 and of COR2.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 8.0,
#     'submissionTime': '2025-02-16T18:58Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37378/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-16T12:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-16T12:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': 'N20W60',
#   'activeRegionNum': None,
#   'note': 'Faint CME seen to the NW in SOHO LASCO C2/C3. This CME is completely covered by a data gap in STEREO A COR2 which lasted from 2025-02-16T11:38Z to 2025-02-16T15:23Z. Source is the partial liftoff of a filament seen starting as early as 2025-02-16T10:48Z in SDO AIA 304 and in GOES SUVI 304/284 as brightening and departure of some filamentary material and opening of surrounding field lines. Filament spans from N00W40, arcs up to N20W60, then arcs down slightly to N10W70, as seen in SDO AIA 304 at 2025-02-16T10:48Z.',
#   'submissionTime': '2025-02-16T20:43Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37383/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-16T21:09Z',
#     'latitude': 32.0,
#     'longitude': 61.0,
#     'halfAngle': 22.0,
#     'speed': 394.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Best fit measurement using candidate source location, several SOHO LASCO C2 frames, and two frames of SOHO LASCO C3. The leading edge is narrow and for most frames is completely obstructed by the pylon in SOHO LASCO C3. This CME is completely covered by a data gap in STEREO A COR2 which lasted from 2025-02-16T11:38Z to 2025-02-16T15:23Z.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 9.0,
#     'submissionTime': '2025-02-16T20:45Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37384/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-16T17:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-16T17:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': "This CME is faint but visible to the northeast in SOHO LASCO C2/C3 imagery. This event is not observed in STEREO A COR2 due to it's faintness and a data gap starting at 2025-02-16T18:23Z. The source is likely far-sided as there are no source signatures on the Earth-facing disk at the time of this event.",
#   'submissionTime': '2025-02-17T02:27Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37386/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-17T01:42Z',
#     'latitude': 50.0,
#     'longitude': None,
#     'halfAngle': 36.0,
#     'speed': 441.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'A plane-of-sky measurement was made using a longitude of -90 degrees due to the far-sided and therefore unknown source location.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 6.2,
#     'submissionTime': '2025-02-17T02:29Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37387/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-16T19:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-16T19:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'This CME is visible to the southeast in SOHO LASCO C2/C3 imagery, but is not seen in STEREO A COR2 due to a data gap starting at 2025-02-16T18:23Z. The source is likely far-sided, and may be related to a faint opening of field lines observed over the southeast limb in SDO AIA 171 and 193 imagery starting around 2025-02-16T19:20Z.',
#   'submissionTime': '2025-02-18T12:11Z',
#   'versionId': 2,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37388/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-17T02:35Z',
#     'latitude': -38.0,
#     'longitude': None,
#     'halfAngle': 10.0,
#     'speed': 488.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'A plane-of-sky measurement was made using a longitude of -90 degrees due to the far-sided and therefore unknown source location.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 7.0,
#     'submissionTime': '2025-02-18T12:11Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37389/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-17T00:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-17T00:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'This CME is visible to the southeast in SOHO LASCO C2/C3 imagery for a few frames before becoming too diffuse to observe. It is not seen in STEREO A COR2 due to a data gap starting at 2025-02-16T18:23Z. The source is likely far-sided, and may be related to faint field-line movement visible over the southeast limb in SDO AIA 171 imagery starting around 2025-02-16T23:30Z.',
#   'submissionTime': '2025-02-17T02:52Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37390/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-17T07:53Z',
#     'latitude': -50.0,
#     'longitude': None,
#     'halfAngle': 10.0,
#     'speed': 491.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'A plane-of-sky measurement was made using a longitude of -90 degrees due to the far-sided and therefore unknown source location.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 5.6,
#     'submissionTime': '2025-02-17T02:53Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37391/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-17T03:24:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-17T03:24Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'}],
#   'sourceLocation': 'N50W10',
#   'activeRegionNum': None,
#   'note': 'Extremely faint loop CME visible to the N in SOHO LASCO C2. The leading edge is not discernable in SOHO LASCO C3 or in STEREO A COR2. Source is subtle brightening and field line movement at N50 and spanning W00-W20, just north of a coronal hole, seen in SDO AIA 193 and GOES SUVI 284 lasting between 2025-02-17T01:40Z-02:50Z.',
#   'submissionTime': '2025-02-17T20:29Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37398/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-17T12:14Z',
#     'latitude': 63.0,
#     'longitude': -4.0,
#     'halfAngle': 33.0,
#     'speed': 400.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on source location and best fit in SOHO LASCO C2. Latitude matches well, but longitude is measuring slightly east of source location; there may have been deflection due to the nearby coronal hole observed in UV imagery.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 6.0,
#     'submissionTime': '2025-02-17T20:30Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37399/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-17T20:00:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-17T20:00Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Faint CME visible to the north in SOHO LASCO C2 and C3. STEREO A COR2 is in a data gap during this event. There is no clear source for this CME.',
#   'submissionTime': '2025-02-18T02:18Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37400/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-18T05:12Z',
#     'latitude': 84.0,
#     'longitude': None,
#     'halfAngle': 19.0,
#     'speed': 371.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'Parameters based on plane-of-sky analysis using SWPC_CAT and SOHO LASCO imagery. No STEREO A COR2 imagery was available during this measurement.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 7.4,
#     'submissionTime': '2025-02-18T02:20Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37401/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-19T06:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-19T06:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'This event is faint but visible to the northeast in SOHO LASCO C2/C3 and north in STEREO A COR2 imagery. The source is likely far-sided as there are no source signatures on the Earth-facing disk at the time of this event.',
#   'submissionTime': '2025-02-19T13:14Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37406/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-19T13:31Z',
#     'latitude': 64.0,
#     'longitude': -141.0,
#     'halfAngle': 18.0,
#     'speed': 439.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on the best fit between SOHO LASCO C2 and STEREO A COR2 imagery.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 8.1,
#     'submissionTime': '2025-02-19T13:15Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37407/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-19T07:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-19T07:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': 'S23W65',
#   'activeRegionNum': 13994,
#   'note': 'This CME is visible to the southwest in SOHO LASCO C2/C3 imagery. This event may become too faint before entering the STEREO A COR2 field of view, as it is not easily observed. The source is likely related to an eruption from Active Region 13994 (S23W65) starting around 2025-02-19T06:25Z as seen in SDO AIA 131, 171, 193, 304 imagery. A subsequent opening of field lines is visible over the southwest limb in SDO AIA 193 and GOES SUVI 284 imagery at this time as well.',
#   'submissionTime': '2025-02-19T12:57Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37404/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-19T17:45Z',
#     'latitude': -32.0,
#     'longitude': 65.0,
#     'halfAngle': 24.0,
#     'speed': 336.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measured longitude based on the source location. As this event is not easily observed in STEREO A COR2 imagery, a triangulated measurement was not made and the measured parameters may vary slightly as a result.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 6.6,
#     'submissionTime': '2025-02-19T13:00Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37405/-1',
#     'enlilList': [{'modelCompletionTime': '2025-02-19T13:12Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37408/-1',
#       'impactList': [{'isGlancingBlow': True,
#         'location': 'Juice',
#         'arrivalTime': '2025-02-21T20:00Z'}],
#       'cmeIDs': ['2025-02-19T07:12:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2025-02-19T09:24:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-02-19T09:24Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'This CME is faint but visible to the northeast in SOHO LASCO C2/C3 and to the north in STEREO A COR2 imagery. The source is likely far-sided as there are no source signatures on the Earth-facing disk at the time or in the vicinity of this event.',
#   'submissionTime': '2025-02-19T13:24Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37409/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-02-19T17:54Z',
#     'latitude': 59.0,
#     'longitude': -143.0,
#     'halfAngle': 18.0,
#     'speed': 363.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on the best fit between SOHO LASCO C2 and STEREO A COR2 imagery.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
# ...
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'A super faint jet to the northwest, seen mostly in SOHO LASCO C2 and in a few early timestamps of C3 and too faint to be seen in STEREO A COR2. There is no flare that can be associated with it but there is some brightening in AR 14024 after 2025-03-12T06Z seen in SDO AIA 193 and it is possibly associated with activity in this Active Region.',
#   'submissionTime': '2025-03-12T17:31Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37795/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-03-12T16:23Z',
#     'latitude': 31.0,
#     'longitude': None,
#     'halfAngle': 19.0,
#     'speed': 383.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'No clear source found on disk and no STEREO A COR2 imagery available for this faint event, so only plane-of-sky measurement is definitive.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2025-03-12T17:36Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37796/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-03-12T11:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-03-12T11:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Super faint and narrow jet only seen in SOHO LASCO C2 running difference imagery and in a few early C3 images and not seen in STEREO A COR2. No source has been found for this jet.',
#   'submissionTime': '2025-03-12T17:53Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37797/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-03-12T18:47Z',
#     'latitude': -69.0,
#     'longitude': None,
#     'halfAngle': 10.0,
#     'speed': 481.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'Super faint and narrow jet only seen in SOHO LASCO C2 running difference imagery and in a few early C3 images and not seen in STEREO A COR2. No source has been found for this jet.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2025-03-12T17:55Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37798/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-03-12T20:04:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-03-12T20:04Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME first seen to the NE in SOHO LASCO C2 white light imagery starting at 2025-03-12T20:04Z. Also seen to the NE in SOHO LASCO C3 but is not seen in STEREO A COR2. This jet may have been visible in running difference imagery shortly before it was visible in white light imagery and has a half-width of less than ten degrees. There is not a good source candidate on the Earth-facing disk; however, there are some possible post eruptive arcades on or just beyond the NE limb (approximately N35-N40) best seen in SDO AIA 171 beginning around 2025-03-12T21:15Z that could be related to this jet.',
#   'submissionTime': '2025-03-12T23:43Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37801/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-03-13T04:04Z',
#     'latitude': 47.0,
#     'longitude': None,
#     'halfAngle': 10.0,
#     'speed': 432.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'Plane-of-sky measurement made with running difference imagery from SOHO LASCO C2/C3. A plane-of-sky measurement was chosen due to the lack of certainty in a source location.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2025-03-12T23:46Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37802/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-03-13T01:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-03-13T01:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Faint CME seen to the SSE in SOHO LASCO C2/C3 and STEREO COR2A. The source may be field line movement in SDO AIA 171 observed over the SSW limb beginning around 2025-03-12T23:18Z.',
#   'submissionTime': '2025-03-13T19:11Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37810/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-03-13T11:09Z',
#     'latitude': -71.0,
#     'longitude': 54.0,
#     'halfAngle': 10.0,
#     'speed': 374.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Difficult to triangulate measurement between SOHO LASCO C3 and STEREO COR2A due to the faint, wispy nature of the leading edge. Good confidence in the high southern latitude and longitude around W50-W60.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2025-03-13T19:13Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37811/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-03-13T04:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-03-13T04:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'S12E90',
#   'activeRegionNum': 14028,
#   'note': 'Faint CME seen to the ESE in SOHO LASCO C2 and STEREO COR2A for a few frames before it fades, never reaching LASCO C3 imagery. First seen more clearly in SOHO LASCO C2 running difference imagery at 2025-03-13T03:48Z. The source for this CME is likely field line movement in SDO AIA 171 on or just inside the SE limb starting around 2025-03-13T02:53Z, from the northern side of AR 14028.',
#   'submissionTime': '2025-03-13T18:39Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37807/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-03-13T17:06Z',
#     'latitude': -20.0,
#     'longitude': -90.0,
#     'halfAngle': 20.0,
#     'speed': 274.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Triangulated measurement between SOHO LASCO C2 and STEREO COR2A, using only the earliest frames as the CME fades into the running difference background by 2025-03-13T06:00Z.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2025-03-13T18:41Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37808/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-03-13T09:38:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-03-13T09:38Z',
#   'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME seen to the SW in STEREO COR2A only, as SOHO LASCO C2/C3 is in a data gap from 2025-03-13T07:30Z -> 2025-03-13T22:10Z. No source for this CME is observed in SDO AIA or STEREO A EUVI imagery.',
#   'submissionTime': '2025-03-13T18:33Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37805/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-03-13T16:43Z',
#     'latitude': -26.0,
#     'longitude': None,
#     'halfAngle': 10.0,
#     'speed': 489.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'STEREO A plane-of-sky measurement as no SOHO LASCO C2/C3 imagery is available. At the CME start time STEREO A is located 30.981 degrees west of Earth, putting its western plane-of-sky around W121 relative to Earth.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 8.0,
#     'submissionTime': '2025-03-13T18:35Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37806/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-03-13T17:36:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-03-13T17:36Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': 'N20E13',
#   'activeRegionNum': 14020,
#   'note': 'CME seen to the northeast in SOHO LASCO C2 composed of a bright narrow bulk and a fainter shock extending to the north and west relative to the bulk. The source is a minor eruption from near Active Region 4020 (N20E13) with northern deflection as seen in SDO AIA 193, 171, 304 as early as 2025-03-13T16:49Z; darkening in SDO AIA 193, brightening in SDO AIA 304 and the appearance of a breaking loop in SDO AIA 171.',
#   'submissionTime': '2025-03-14T12:23Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37816/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-03-13T22:13Z',
#     'latitude': 27.0,
#     'longitude': -17.0,
#     'halfAngle': 10.0,
#     'speed': 698.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'One spacecraft measurement (SOHO) of the leading edge assuming some modest northern deflection and fitting relative to the source observed in EUV imagery.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 8.0,
#     'submissionTime': '2025-03-14T15:18Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37817/-1',
#     'enlilList': [{'modelCompletionTime': '2025-03-14T12:21Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37818/-1',
#       'impactList': None,
#       'cmeIDs': ['2025-03-13T17:36:00-CME-001']}]},
#    {'isMostAccurate': True,
#     'time21_5': '2025-03-13T22:46Z',
#     'latitude': 26.0,
#     'longitude': -4.0,
#     'halfAngle': 37.0,
#     'speed': 618.0,
#     'type': 'C',
#     'featureCode': 'SH',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement of wider shock front using only SOHO C2 and knowledge of the source as determined from EUV imagery. Attached WSA-Enlil+Cone simulation was executed in support of SEP models and should not be used for CME trajectory analysis. Based on simulation output, there is low confidence the CME may arrive at Earth very weakly.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 7.0,
#     'submissionTime': '2025-03-14T15:27Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37821/-1',
#     'enlilList': [{'modelCompletionTime': '2025-03-14T15:26Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': '2025-03-16T07:48Z',
#       'estimatedDuration': 11.7,
#       'rmin_re': 6.6,
#       'kp_18': None,
#       'kp_90': 4,
#       'kp_135': 5,
#       'kp_180': 6,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37822/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'BepiColombo',
#         'arrivalTime': '2025-03-14T15:56Z'},
#        {'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2025-03-14T20:56Z'}],
#       'cmeIDs': ['2025-03-13T17:36:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2025-03-14T01:55:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-03-14T01:55Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME seen to the northeast in SOHO LASCO C2 composed of a bright narrow bulk extending to the northeast and second more minor outflow seen more to the north. The source may be associated with a minor eruption seen near the eastern limb around E80 as early as 2025-03-14T02:00Z; mostly in GOES SUVI 284 imagery, or may be far-sided.',
#   'submissionTime': '2025-03-14T12:47Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37819/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-03-14T07:14Z',
#     'latitude': 23.0,
#     'longitude': -74.0,
#     'halfAngle': 10.0,
#     'speed': 689.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Two spacecraft leading edge measurement in order to triangulate a possible longitude; uncertainty in longitude up to +/- 20 degrees.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 8.0,
#     'submissionTime': '2025-03-14T12:48Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37820/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2025-03-14T15:25:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2025-03-14T15:25Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': 'N08E11',
#   'activeRegionNum': 14022,
#   'note': 'CME first seen in the NE by SOHO LASCO C2 beginning at 2025-03-14T15:25Z, as well as by SOHO LASCO C3 in later frames. This CME is not visible in STEREO A COR2 due to a data gap beginning at 14/15:53Z. The source of this event is a minor eruption from AR 4022 (N08E11) beginning at approx. 14/14:28Z. Dimming seen in SDO AIA 193 and 211 suggest a strong Eastern deflection.',
#   'submissionTime': '2025-03-14T21:06Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37824/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2025-03-14T21:45Z',
#     'latitude': 8.0,
#     'longitude': -40.0,
#     'halfAngle': 10.0,
#     'speed': 491.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on approximate source location and best fit in SOHO LASCO C2. This event is measuring slightly more narrow than the SWPC_CAT lower limit of 10 degrees.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2025-03-14T21:08Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37825/-1',
#     'enlilList': [{'modelCompletionTime': '2025-03-14T21:19Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37826/-1',
#       'impactList': [{'isGlancingBlow': True,
#         'location': 'BepiColombo',
#         'arrivalTime': '2025-03-15T16:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Europa Clipper',
#         'arrivalTime': '2025-03-19T22:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Mars',
#         'arrivalTime': '2025-03-19T12:00Z'}],
#       'cmeIDs': ['2025-03-14T15:25:00-CME-001']}]}],
#   'linkedEvents': None}]

# %%
# Preview the first result in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(cme_json, indent=4))
# Out:
# [
#     {
#         "activityID": "2025-02-13T01:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-13T01:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Faint, narrow CME first seen in the NE by SOHO LASCO C2 beginning at 2025-02-13T01:36Z, as well as by SOHO LASCO C3 in later frames. This event is not visible in STEREO A COR2 due to a data gap from 2025-02-12T10:38Z to 2025-02-13T03:23Z. There is no clear source seen for this event aside from general field line movement along the NE limb seen in SDO AIA 193.",
#         "submissionTime": "2025-02-13T14:09Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37004/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-13T08:23Z",
#                 "latitude": 21.0,
#                 "longitude": null,
#                 "halfAngle": 11.0,
#                 "speed": 515.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "Plane-of-sky",
#                 "note": "POS measurement due to range of longitude fits (approx. E70 to E100) and no clear source.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2025-02-13T14:10Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37005/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-02-13T15:23:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-13T15:23Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "S07W10",
#         "activeRegionNum": null,
#         "note": "This CME is visible to the N/NE in SOHO LASCO C2, C3, and STEREO A COR2 imagery. It is very faint with a diffuse front. The potential source of this CME is a dimming centered around S07W10 just East of AR13992 as seen in SDO/AIA 193 and 211 starting around 2025-02-13T14:00Z.",
#         "submissionTime": "2025-02-14T01:37Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37321/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-13T21:19Z",
#                 "latitude": 23.0,
#                 "longitude": -10.0,
#                 "halfAngle": 24.0,
#                 "speed": 546.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "These parameters are based on the best fit of features in SOHO LASCO C2/C3 and STEREO A COR2 imagery. There is likely deflection of this CME due to the large coronal hole south of the potential source location.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 10.7,
#                 "submissionTime": "2025-02-14T01:39Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37322/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2025-02-14T01:34Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2025-02-16T04:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 4,
#                         "kp_135": 5,
#                         "kp_180": 6,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37323/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Europa Clipper",
#                                 "arrivalTime": "2025-02-18T00:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2025-02-17T12:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Mars",
#                                 "arrivalTime": "2025-02-18T04:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2025-02-15T16:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2025-02-13T15:23:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-02-13T17:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-13T17:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "This CME is visible to the SE in SOHO LASCO C2 and C3 imagery. There is no STEREO A COR2 imagery available for this CME due to a data gap beginning at 2025-02-13T17:09Z. The source of this CME is likely a filament eruption visible in SDO/AIA 304 and 171 just beyond the SE limb starting around 2025-02-13T16:30Z.",
#         "submissionTime": "2025-02-14T02:22Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37324/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-13T23:47Z",
#                 "latitude": -57.0,
#                 "longitude": null,
#                 "halfAngle": 16.0,
#                 "speed": 552.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "Plane-of-sky",
#                 "note": "Plane-of-sky fit using SWPC_CAT measurement tool.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 12.0,
#                 "submissionTime": "2025-02-14T02:23Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37325/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-02-13T21:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-13T21:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             }
#         ],
#         "sourceLocation": "N20W45",
#         "activeRegionNum": null,
#         "note": "Narrow, faint CME seen to the northeast in SOHO LASCO C2 during a STEREO A data gap. Likely associated with a small filament eruption starting around 2025-02-13T20:00Z in the NE on Earth-facing disk around N20W45 (seen best in SDO AIA 193).",
#         "submissionTime": "2025-02-14T12:55Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37329/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-14T03:06Z",
#                 "latitude": 19.0,
#                 "longitude": -54.0,
#                 "halfAngle": 10.0,
#                 "speed": 531.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Preliminary one spacecraft leading edge measurement of the CME assuming that the source on the Earth-facing disk best represents this CME.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 7.0,
#                 "submissionTime": "2025-02-14T13:00Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37330/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-02-14T08:48:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-14T08:48Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             }
#         ],
#         "sourceLocation": "S21E06",
#         "activeRegionNum": 13994,
#         "note": "Wide, faint CME seen primarily to the east in SOHO LASCO C2 and STEREO A COR2 which appears to be associated with a C6.6-class flare from Active Region 13994 and subsequent eruption seen best in SDO AIA 094 and SDO AIA 304 with notable deflection to the east. Despite the overall weak eruptive signature, triangulation strongly suggests that the eruption is associated with front-sided activity bounded by longitudes -25 to -45.",
#         "submissionTime": "2025-02-14T14:13Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37332/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-14T13:21Z",
#                 "latitude": -16.0,
#                 "longitude": -32.0,
#                 "halfAngle": 31.0,
#                 "speed": 701.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Two spacecraft leading-edge measurement using SOHO LASCO C2 and STEREO A COR2 to corroborate the longitude.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 12.0,
#                 "submissionTime": "2025-02-14T14:22Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37333/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2025-02-14T14:05Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2025-02-16T16:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 4,
#                         "kp_135": 5,
#                         "kp_180": 6,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37334/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2025-02-16T00:30Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Europa Clipper",
#                                 "arrivalTime": "2025-02-18T03:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2025-02-17T17:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Mars",
#                                 "arrivalTime": "2025-02-18T06:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2025-02-14T08:48:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2025-02-14T07:31:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2025-02-14T14:48:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-14T14:48Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             }
#         ],
#         "sourceLocation": "S12E36",
#         "activeRegionNum": 13991,
#         "note": "Jet CME seen to the southeast in SOHO LASCO C2 and STEREO A COR2A likely associated with a minor eruption from Active Region 13991 (S12E36), as evidenced by an eruptive signature taking place in SDO AIA 193.",
#         "submissionTime": "2025-02-14T17:13Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37336/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-14T20:31Z",
#                 "latitude": -34.0,
#                 "longitude": -43.0,
#                 "halfAngle": 10.0,
#                 "speed": 592.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Two spacecraft leading edge measurement.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 7.0,
#                 "submissionTime": "2025-02-14T17:14Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37337/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-02-14T17:48:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-14T17:48Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             }
#         ],
#         "sourceLocation": "S21W00",
#         "activeRegionNum": 13994,
#         "note": "Narrow CME seen to the southeast in SOHO LASCO C2 during a STEREO A data gap; the CME is possibly associated with a minor eruption from Active Region 13994 located near S21W00 as seen in SDO AIA 94, 304, though it isn't definitive where the eruption originates. Triangulation is not currently possible due to a STA COR2 data gap.",
#         "submissionTime": "2025-02-14T19:40Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37339/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-14T23:43Z",
#                 "latitude": -34.0,
#                 "longitude": null,
#                 "halfAngle": 13.0,
#                 "speed": 628.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "Plane-of-sky",
#                 "note": "Preliminary plane of sky measurement given no STEREO A COR2 data is available.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 5.0,
#                 "submissionTime": "2025-02-14T19:41Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37340/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-02-14T21:48:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-14T21:48Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "N14E33",
#         "activeRegionNum": null,
#         "note": "CME seen to the NE in SOHO LASCO C2/C3 only, STEREO COR2A beacon data entirely misses this event. Partially overlaps with CME 2025-02-14T22:00Z to the SE. The source for this CME is likely an area of the disk ~N14E33 which brightens and releases some filament material to the NE starting around 2025-02-14T20:58Z, best observed in SDO AIA 171/193/304.",
#         "submissionTime": "2025-02-15T03:22Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37342/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-15T04:12Z",
#                 "latitude": 4.0,
#                 "longitude": -33.0,
#                 "halfAngle": 17.0,
#                 "speed": 507.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Single spacecraft 3D measurement using only SOHO LASCO C2/C3 imagery due to a STEREO COR2A data gap covering this CME, using the source coordinates of N14E33 as a basis.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2025-02-15T03:24Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37343/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2025-02-15T02:06Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37346/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2025-02-16T20:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Europa Clipper",
#                                 "arrivalTime": "2025-02-19T06:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Mars",
#                                 "arrivalTime": "2025-02-19T12:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2025-02-14T21:48:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2025-02-15T18:14Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2025-02-17T12:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 3,
#                         "kp_135": 5,
#                         "kp_180": 5,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37358/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2025-02-16T19:51Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Europa Clipper",
#                                 "arrivalTime": "2025-02-19T06:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Mars",
#                                 "arrivalTime": "2025-02-19T11:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2025-02-18T20:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2025-02-14T21:48:00-CME-001",
#                             "2025-02-15T01:36:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2025-02-15T20:21Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": "2025-02-17T12:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 3,
#                         "kp_135": 5,
#                         "kp_180": 5,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37363/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2025-02-16T19:35Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Europa Clipper",
#                                 "arrivalTime": "2025-02-19T06:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Mars",
#                                 "arrivalTime": "2025-02-19T11:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2025-02-18T20:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2025-02-14T21:48:00-CME-001",
#                             "2025-02-15T01:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-02-14T22:00:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-14T22:00Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "S30E68",
#         "activeRegionNum": null,
#         "note": "CME seen to the SE in SOHO LASCO C2/C3 only, STEREO COR2A beacon data entirely misses this event. Partially overlaps with CME 2025-02-14T21:48Z to the NE. The source for this CME is likely a broad area of the disk ~S30E68 which slowly dims and moves field lines to the SE starting around 2025-02-14T21:00Z, best observed in SDO AIA 171/193 and GOES SUVI 284. There is a concurrent, separate M1.8 flare from AR 13990 (S12E13) which peaked at 2025-02-14T20:57Z which was considered for a source here, but ruled out with lower confidence than the SE quadrant dimming mentioned prior.",
#         "submissionTime": "2025-02-15T03:24Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37344/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-15T09:37Z",
#                 "latitude": -21.0,
#                 "longitude": -68.0,
#                 "halfAngle": 27.0,
#                 "speed": 303.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Single spacecraft 3D measurement using only SOHO LASCO C2/C3 imagery due to a STEREO COR2A data gap covering this CME, using the source coordinates of S30E68 as a basis.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 9.1,
#                 "submissionTime": "2025-02-15T03:26Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37345/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2025-02-15T02:44Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37347/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Europa Clipper",
#                                 "arrivalTime": "2025-02-22T06:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Mars",
#                                 "arrivalTime": "2025-02-22T10:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2025-02-18T12:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2025-02-14T22:00:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-02-15T01:25:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-15T01:25Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Faint southeastern CME with a dimpled/fuzzy front, seen in both coronagraphs (in SOHO LASCO and in STEREO A COR2 after a data gap). It's source is unclear but possibly the very faint rising post-eruptive arcades and super minor dimming seen around 2025-02-15T00:40Z centered around (S30E65).",
#         "submissionTime": "2025-02-15T20:11Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37360/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-15T15:58Z",
#                 "latitude": -20.0,
#                 "longitude": -65.0,
#                 "halfAngle": 28.0,
#                 "speed": 242.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "A very speculative measurement based on the possible but not clear source and on a very approximate fit with two coronagraph. The fit is uncertain since especially in STEREO A the front of this CME is super unclear.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2025-02-15T20:13Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37361/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-02-15T01:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-15T01:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "N11E31",
#         "activeRegionNum": null,
#         "note": "Fast CME seen  to the NE in both coronagraphs, faint in SOHO LASCO and bright in STEREO A COR2. In STEREO A it is only seen after the nighttime data gap ends. Its source is likely a significant filament eruption centered around N11E31, seen starting around 2025-02-15T00:56Z in GOES SUVI 304 and in SDO AIA 304, but also seen as small area brightening in SDO AIA 193. There is also a lower class C flare associated with it.",
#         "submissionTime": "2025-02-15T22:03Z",
#         "versionId": 2,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37353/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-15T05:48Z",
#                 "latitude": 10.0,
#                 "longitude": -31.0,
#                 "halfAngle": 20.0,
#                 "speed": 722.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Analysis based on the fit with two coronagraphs; it corresponds well to the location of the source eruption.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2025-02-15T22:04Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37354/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2025-02-15T17:52Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2025-02-17T12:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 3,
#                         "kp_135": 4,
#                         "kp_180": 5,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37355/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2025-02-16T20:38Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Europa Clipper",
#                                 "arrivalTime": "2025-02-19T06:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Mars",
#                                 "arrivalTime": "2025-02-19T11:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2025-02-18T20:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2025-02-15T01:36:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2025-02-15T18:14Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2025-02-17T12:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 3,
#                         "kp_135": 5,
#                         "kp_180": 5,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37358/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2025-02-16T19:51Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Europa Clipper",
#                                 "arrivalTime": "2025-02-19T06:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Mars",
#                                 "arrivalTime": "2025-02-19T11:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2025-02-18T20:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2025-02-14T21:48:00-CME-001",
#                             "2025-02-15T01:36:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2025-02-15T20:21Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": "2025-02-17T12:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 3,
#                         "kp_135": 5,
#                         "kp_180": 5,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37363/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2025-02-16T19:35Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Europa Clipper",
#                                 "arrivalTime": "2025-02-19T06:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Mars",
#                                 "arrivalTime": "2025-02-19T11:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2025-02-18T20:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2025-02-14T21:48:00-CME-001",
#                             "2025-02-15T01:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2025-02-15T00:50:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2025-02-15T13:25:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-15T13:25Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Bright CME with a high southern latitude, seen to the west in STEREO A COR2 and almost exactly to the south in SOHO LASCO, indicating a backsided source. Coronal signatures include a huge prominence seen directly to the south in GOES SUVI 304 starting at 2025-02-12:56Z and originating behind the south limb, and also seen as an extensive movement of matter/field lines to the south and southeast in GOES SUVI 284, also likely happening behind the southern limb. Coronal signatures are almost not seen in SDO AIA, except for minimal movement of ejecta seen in AIA 304.",
#         "submissionTime": "2025-02-15T18:34Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37356/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-15T17:38Z",
#                 "latitude": -43.0,
#                 "longitude": 173.0,
#                 "halfAngle": 37.0,
#                 "speed": 820.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Analysis based on the fit with two coronagraphs and corresponding well to the southern filament see in EUVI imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2025-02-15T18:35Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37357/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2025-02-15T20:50Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37365/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "BepiColombo",
#                                 "arrivalTime": "2025-02-16T10:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2025-02-17T09:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2025-02-15T13:25:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-02-15T19:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-15T19:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Narrow CME visible in the southwest of SOHO LASCO C2/C3. Not visible in STEREO A COR2 due to a data gap starting at 2025-02-15T17:09Z. The source is not visible in EUV imagery, and my be farsided.",
#         "submissionTime": "2025-02-15T23:48Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37367/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-16T05:21Z",
#                 "latitude": -74.0,
#                 "longitude": null,
#                 "halfAngle": 17.0,
#                 "speed": 365.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "Plane-of-sky",
#                 "note": "Plane-of-sky measurement using SOHO LASCO C2/C3 difference imagery in SWPC_CAT due to lack of known source location.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 7.6,
#                 "submissionTime": "2025-02-15T23:50Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37368/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-02-15T20:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-15T20:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "N06W90",
#         "activeRegionNum": 13983,
#         "note": "CME visible to the northwest in SOHO LASCO C2/C3. The CME is partially obscured by the pylon in SOHO LASCO C3. No visible in STEREO A COR2 due to a data gap starting at 2025-02-15T17:09Z. The source is an eruption from Active Region 13983 (approx. N06W90) starting at 2025-02-15T19:22Z. Brightening and opening field lines are best seen in SDO AIA 171/193 and GOES SUVI 284. The eruption is also visible in SDO AIA 304 imagery.",
#         "submissionTime": "2025-02-16T00:06Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37369/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-16T02:30Z",
#                 "latitude": 39.0,
#                 "longitude": 85.0,
#                 "halfAngle": 22.0,
#                 "speed": 605.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on approximate source location. Only SOHO LASCO C2 imagery was available for a measurement, as the CME was blocked by the pylon in SOHO LASCO C3.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 8.1,
#                 "submissionTime": "2025-02-16T00:08Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37370/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2025-02-16T00:24Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37372/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2025-02-15T20:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2025-02-15T19:22:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2025-02-16T00:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-16T00:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Narrow flux rope CME seen to the SW in SOHO LASCO C2/C3 and STEREO A COR2. The source is not visible in available EUV imagery, but is on the farside based on triangulation between the SOHO LASCO and STEREO A COR2 coronagraphs. This CME is partially covered by a data gap in STEREO A COR2 which lasted from 2025-02-15T16:53Z to 2025-02-16T05:23Z.",
#         "submissionTime": "2025-02-16T18:53Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37379/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-16T08:52Z",
#                 "latitude": -53.0,
#                 "longitude": 152.0,
#                 "halfAngle": 18.0,
#                 "speed": 403.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Best fit measurement using several SOHO LASCO C3 frames and two frames of STEREO A COR2 before the leading edge leaves the COR2 field of view. This CME is partially covered by a data gap in STEREO A COR2 which lasted from 2025-02-15T16:53Z to 2025-02-16T05:23Z.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 17.0,
#                 "submissionTime": "2025-02-16T19:00Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37380/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-02-16T09:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-02-16T09:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "N27E30",
#         "activeRegionNum": null,
#         "note": "Faint loop CME seen to the S in SOHO LASCO C2 and the SE in STEREO A COR2. The leading edge is too diffuse to discern in SOHO LASCO C3. Source is a small eruption from N27E30: a narrow set of opening field lines from the location is seen in GOES SUVI 284 at 2025-02-16T07:45Z as well as post-eruptive brightening seen in SDO AIA 304 at 08:25Z, followed immediately by a much wider and fainter set of opening field lines which extends across the southern hemisphere of the disk all the way to roughly near AR 13994 (S20W22).",
#         "submissionTime": "2025-02-16T20:20Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37381/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-02-16T18:48Z",
# ...
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Faint CME seen to the SSE in SOHO LASCO C2/C3 and STEREO COR2A. The source may be field line movement in SDO AIA 171 observed over the SSW limb beginning around 2025-03-12T23:18Z.",
#         "submissionTime": "2025-03-13T19:11Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37810/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-03-13T11:09Z",
#                 "latitude": -71.0,
#                 "longitude": 54.0,
#                 "halfAngle": 10.0,
#                 "speed": 374.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Difficult to triangulate measurement between SOHO LASCO C3 and STEREO COR2A due to the faint, wispy nature of the leading edge. Good confidence in the high southern latitude and longitude around W50-W60.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2025-03-13T19:13Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37811/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-03-13T04:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-03-13T04:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S12E90",
#         "activeRegionNum": 14028,
#         "note": "Faint CME seen to the ESE in SOHO LASCO C2 and STEREO COR2A for a few frames before it fades, never reaching LASCO C3 imagery. First seen more clearly in SOHO LASCO C2 running difference imagery at 2025-03-13T03:48Z. The source for this CME is likely field line movement in SDO AIA 171 on or just inside the SE limb starting around 2025-03-13T02:53Z, from the northern side of AR 14028.",
#         "submissionTime": "2025-03-13T18:39Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37807/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-03-13T17:06Z",
#                 "latitude": -20.0,
#                 "longitude": -90.0,
#                 "halfAngle": 20.0,
#                 "speed": 274.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Triangulated measurement between SOHO LASCO C2 and STEREO COR2A, using only the earliest frames as the CME fades into the running difference background by 2025-03-13T06:00Z.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2025-03-13T18:41Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37808/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-03-13T09:38:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-03-13T09:38Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "CME seen to the SW in STEREO COR2A only, as SOHO LASCO C2/C3 is in a data gap from 2025-03-13T07:30Z -> 2025-03-13T22:10Z. No source for this CME is observed in SDO AIA or STEREO A EUVI imagery.",
#         "submissionTime": "2025-03-13T18:33Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37805/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-03-13T16:43Z",
#                 "latitude": -26.0,
#                 "longitude": null,
#                 "halfAngle": 10.0,
#                 "speed": 489.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "Plane-of-sky",
#                 "note": "STEREO A plane-of-sky measurement as no SOHO LASCO C2/C3 imagery is available. At the CME start time STEREO A is located 30.981 degrees west of Earth, putting its western plane-of-sky around W121 relative to Earth.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 8.0,
#                 "submissionTime": "2025-03-13T18:35Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37806/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-03-13T17:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-03-13T17:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "N20E13",
#         "activeRegionNum": 14020,
#         "note": "CME seen to the northeast in SOHO LASCO C2 composed of a bright narrow bulk and a fainter shock extending to the north and west relative to the bulk. The source is a minor eruption from near Active Region 4020 (N20E13) with northern deflection as seen in SDO AIA 193, 171, 304 as early as 2025-03-13T16:49Z; darkening in SDO AIA 193, brightening in SDO AIA 304 and the appearance of a breaking loop in SDO AIA 171.",
#         "submissionTime": "2025-03-14T12:23Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37816/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-03-13T22:13Z",
#                 "latitude": 27.0,
#                 "longitude": -17.0,
#                 "halfAngle": 10.0,
#                 "speed": 698.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "One spacecraft measurement (SOHO) of the leading edge assuming some modest northern deflection and fitting relative to the source observed in EUV imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 8.0,
#                 "submissionTime": "2025-03-14T15:18Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37817/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2025-03-14T12:21Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37818/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2025-03-13T17:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-03-13T22:46Z",
#                 "latitude": 26.0,
#                 "longitude": -4.0,
#                 "halfAngle": 37.0,
#                 "speed": 618.0,
#                 "type": "C",
#                 "featureCode": "SH",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement of wider shock front using only SOHO C2 and knowledge of the source as determined from EUV imagery. Attached WSA-Enlil+Cone simulation was executed in support of SEP models and should not be used for CME trajectory analysis. Based on simulation output, there is low confidence the CME may arrive at Earth very weakly.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 7.0,
#                 "submissionTime": "2025-03-14T15:27Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37821/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2025-03-14T15:26Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2025-03-16T07:48Z",
#                         "estimatedDuration": 11.7,
#                         "rmin_re": 6.6,
#                         "kp_18": null,
#                         "kp_90": 4,
#                         "kp_135": 5,
#                         "kp_180": 6,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37822/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "BepiColombo",
#                                 "arrivalTime": "2025-03-14T15:56Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2025-03-14T20:56Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2025-03-13T17:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-03-14T01:55:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-03-14T01:55Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "CME seen to the northeast in SOHO LASCO C2 composed of a bright narrow bulk extending to the northeast and second more minor outflow seen more to the north. The source may be associated with a minor eruption seen near the eastern limb around E80 as early as 2025-03-14T02:00Z; mostly in GOES SUVI 284 imagery, or may be far-sided.",
#         "submissionTime": "2025-03-14T12:47Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37819/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-03-14T07:14Z",
#                 "latitude": 23.0,
#                 "longitude": -74.0,
#                 "halfAngle": 10.0,
#                 "speed": 689.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Two spacecraft leading edge measurement in order to triangulate a possible longitude; uncertainty in longitude up to +/- 20 degrees.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 8.0,
#                 "submissionTime": "2025-03-14T12:48Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37820/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2025-03-14T15:25:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2025-03-14T15:25Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "N08E11",
#         "activeRegionNum": 14022,
#         "note": "CME first seen in the NE by SOHO LASCO C2 beginning at 2025-03-14T15:25Z, as well as by SOHO LASCO C3 in later frames. This CME is not visible in STEREO A COR2 due to a data gap beginning at 14/15:53Z. The source of this event is a minor eruption from AR 4022 (N08E11) beginning at approx. 14/14:28Z. Dimming seen in SDO AIA 193 and 211 suggest a strong Eastern deflection.",
#         "submissionTime": "2025-03-14T21:06Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/37824/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2025-03-14T21:45Z",
#                 "latitude": 8.0,
#                 "longitude": -40.0,
#                 "halfAngle": 10.0,
#                 "speed": 491.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on approximate source location and best fit in SOHO LASCO C2. This event is measuring slightly more narrow than the SWPC_CAT lower limit of 10 degrees.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2025-03-14T21:08Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/37825/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2025-03-14T21:19Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/37826/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "BepiColombo",
#                                 "arrivalTime": "2025-03-15T16:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Europa Clipper",
#                                 "arrivalTime": "2025-03-19T22:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Mars",
#                                 "arrivalTime": "2025-03-19T12:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2025-03-14T15:25:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     }
# ]

# %%
# Convert cme_json to a Pandas DataFrame 
df = pd.DataFrame(cme_json)
df

# Keep only the columns: activityID, startTime, linkedEvents
df= df[['activityID', 'startTime', 'linkedEvents']]
df.head()

#call the data base [ then pick columns [
# Out:
#                     activityID          startTime  \
# 0  2025-02-13T01:36:00-CME-001  2025-02-13T01:36Z
# 1  2025-02-13T15:23:00-CME-001  2025-02-13T15:23Z
# 2  2025-02-13T17:36:00-CME-001  2025-02-13T17:36Z
# 3  2025-02-13T21:12:00-CME-001  2025-02-13T21:12Z
# 4  2025-02-14T08:48:00-CME-001  2025-02-14T08:48Z
#
#                                       linkedEvents
# 0                                             None
# 1                                             None
# 2                                             None
# 3                                             None
# 4  [{'activityID': '2025-02-14T07:31:00-FLR-001'}]

# %%
# Notice that the linkedEvents column allows us to identify the corresponding GST
# Remove rows with missing 'linkedEvents' since we won't be able to assign these to GSTs
df_cleaned = df.dropna(subset="linkedEvents")
df_cleaned
# Out:
#                       activityID          startTime  \
# 4    2025-02-14T08:48:00-CME-001  2025-02-14T08:48Z
# 10   2025-02-15T01:36:00-CME-001  2025-02-15T01:36Z
# 13   2025-02-15T20:36:00-CME-001  2025-02-15T20:36Z
# 27   2025-02-20T00:00:00-CME-001  2025-02-20T00:00Z
# 32   2025-02-20T10:36:00-CME-001  2025-02-20T10:36Z
# 44   2025-02-22T21:36:00-CME-001  2025-02-22T21:36Z
# 46   2025-02-23T02:36:00-CME-001  2025-02-23T02:36Z
# 50   2025-02-23T19:36:00-CME-001  2025-02-23T19:36Z
# 53   2025-02-24T07:00:00-CME-001  2025-02-24T07:00Z
# 55   2025-02-24T21:24:00-CME-001  2025-02-24T21:24Z
# 56   2025-02-25T12:38:00-CME-001  2025-02-25T12:38Z
# 58   2025-02-26T06:48:00-CME-001  2025-02-26T06:48Z
# 63   2025-02-27T00:12:00-CME-001  2025-02-27T00:12Z
# 70   2025-02-28T17:12:00-CME-001  2025-02-28T17:12Z
# 71   2025-02-28T17:24:00-CME-001  2025-02-28T17:24Z
# 73   2025-03-01T18:24:00-CME-001  2025-03-01T18:24Z
# 74   2025-03-01T23:36:00-CME-001  2025-03-01T23:36Z
# 75   2025-03-02T04:00:00-CME-001  2025-03-02T04:00Z
# 76   2025-03-02T06:24:00-CME-001  2025-03-02T06:24Z
# 77   2025-03-02T09:48:00-CME-001  2025-03-02T09:48Z
# 99   2025-03-07T21:49:00-CME-001  2025-03-07T21:49Z
# 100  2025-03-07T22:12:00-CME-001  2025-03-07T22:12Z
# 111  2025-03-11T14:00:00-CME-001  2025-03-11T14:00Z
# 113  2025-03-11T22:24:00-CME-001  2025-03-11T22:24Z
#
#                                           linkedEvents
# 4      [{'activityID': '2025-02-14T07:31:00-FLR-001'}]
# 10     [{'activityID': '2025-02-15T00:50:00-FLR-001'}]
# 13     [{'activityID': '2025-02-15T19:22:00-FLR-001'}]
# 27   [{'activityID': '2025-02-19T23:23:00-FLR-001'}...
# 32     [{'activityID': '2025-02-23T21:20:00-IPS-001'}]
# 44     [{'activityID': '2025-02-22T20:55:00-FLR-001'}]
# 46     [{'activityID': '2025-02-23T02:00:00-FLR-001'}]
# 50     [{'activityID': '2025-02-23T19:22:00-FLR-001'}]
# 53   [{'activityID': '2025-02-24T06:53:00-FLR-001'}...
# 55   [{'activityID': '2025-02-24T21:50:00-FLR-001'}...
# 56   [{'activityID': '2025-02-25T11:20:00-FLR-001'}...
# 58     [{'activityID': '2025-02-28T19:32:00-IPS-001'}]
# 63     [{'activityID': '2025-02-26T22:37:00-FLR-001'}]
# 70     [{'activityID': '2025-03-01T03:22:00-SEP-001'}]
# 71     [{'activityID': '2025-02-28T16:18:00-FLR-001'}]
# 73   [{'activityID': '2025-03-04T17:10:00-IPS-001'}...
# 74     [{'activityID': '2025-03-01T22:44:00-FLR-001'}]
# 75     [{'activityID': '2025-03-02T03:37:00-FLR-001'}]
# 76     [{'activityID': '2025-03-02T05:46:00-FLR-001'}]
# 77     [{'activityID': '2025-03-02T09:26:00-FLR-001'}]
# 99     [{'activityID': '2025-03-07T20:54:00-FLR-001'}]
# 100    [{'activityID': '2025-03-10T13:44:00-IPS-001'}]
# 111    [{'activityID': '2025-03-11T13:03:00-FLR-001'}]
# 113    [{'activityID': '2025-03-11T21:19:00-FLR-001'}]

# %%
# Notice that the linkedEvents sometimes contains multiple events per row
# Write a nested for loop that iterates first over each row in the cme DataFrame (using the index)
# and then iterates over the values in 'linkedEvents' 
# and adds the elements individually to a list of dictionaries where each row is one element 
# Initialize an empty list to store the expanded rows
# Iterate over each index in the DataFrame
# Iterate over each dictionary in the list
# # Append a new dictionary to the expanded_rows list for each dictionary item and corresponding 'activityID' and 'startTime' value
#Create a new DataFrame from the expanded rows
#ASK TA!!!!!!!!!!!!!!!!!!! - result is fine. Dont need function but it woks so its fine. 

expanded_rows = []
for index, row in df_cleaned.iterrows():
    activityID = row['activityID']
    startTime = row['startTime']
    linkedEvents = row['linkedEvents']
    for event in linkedEvents:
        expanded_rows.append({'activityID': activityID, 'startTime': startTime, 'linkedEvents': event})
    
df_expanded = pd.DataFrame(expanded_rows)
df_expanded.head()
# Out:
#                     activityID          startTime  \
# 0  2025-02-14T08:48:00-CME-001  2025-02-14T08:48Z
# 1  2025-02-15T01:36:00-CME-001  2025-02-15T01:36Z
# 2  2025-02-15T20:36:00-CME-001  2025-02-15T20:36Z
# 3  2025-02-20T00:00:00-CME-001  2025-02-20T00:00Z
# 4  2025-02-20T00:00:00-CME-001  2025-02-20T00:00Z
#
#                                     linkedEvents
# 0  {'activityID': '2025-02-14T07:31:00-FLR-001'}
# 1  {'activityID': '2025-02-15T00:50:00-FLR-001'}
# 2  {'activityID': '2025-02-15T19:22:00-FLR-001'}
# 3  {'activityID': '2025-02-19T23:23:00-FLR-001'}
# 4  {'activityID': '2025-02-23T14:08:00-IPS-001'}

# %%
# Create a function called extract_activityID_from_dict that 
# takes a dict as input such as in linkedEvents
# and verify below that it works as expected using 
# one row from linkedEvents as an example
# Be sure to use a try and except block to handle errors
# Log the error or print it for debugging


# Create a function called extract_activityID_from_dict that takes a dict as input such as in linkedEvents and extracts the value of that dict
def extract_activityID_from_dict(input_dict):
        try:
                activityID = input_dict.get('activityID', None)
                return activityID
        except (ValueError, TypeError) as e:
                print(f"Error processing input dictionary: {input_dict}. Error: {e}")
                return None

extract_activityID_from_dict(df_expanded.loc[0,'linkedEvents'])
# Out:
# '2025-02-14T07:31:00-FLR-001'

# %%
# Apply this function to each row in the 'linkedEvents' column (you can use apply() and a lambda function)
# and create a new column called 'GST_ActivityID' using loc indexer:
# Apply the function to the 'linkedEvents' column
# Verify the new column
# Define the function

df_expanded.loc[:, 'GST_ActivityID']= df_expanded['linkedEvents'].apply(lambda x: extract_activityID_from_dict(x))
df_expanded.head()
# Out:
#                     activityID          startTime  \
# 0  2025-02-14T08:48:00-CME-001  2025-02-14T08:48Z
# 1  2025-02-15T01:36:00-CME-001  2025-02-15T01:36Z
# 2  2025-02-15T20:36:00-CME-001  2025-02-15T20:36Z
# 3  2025-02-20T00:00:00-CME-001  2025-02-20T00:00Z
# 4  2025-02-20T00:00:00-CME-001  2025-02-20T00:00Z
#
#                                     linkedEvents               GST_ActivityID
# 0  {'activityID': '2025-02-14T07:31:00-FLR-001'}  2025-02-14T07:31:00-FLR-001
# 1  {'activityID': '2025-02-15T00:50:00-FLR-001'}  2025-02-15T00:50:00-FLR-001
# 2  {'activityID': '2025-02-15T19:22:00-FLR-001'}  2025-02-15T19:22:00-FLR-001
# 3  {'activityID': '2025-02-19T23:23:00-FLR-001'}  2025-02-19T23:23:00-FLR-001
# 4  {'activityID': '2025-02-23T14:08:00-IPS-001'}  2025-02-23T14:08:00-IPS-001

# %%
# Remove rows with missing GST_ActivityID, since we can't assign them to GSTs:
df_expanded = df_expanded.dropna(subset="GST_ActivityID")
df_expanded.head()
# Out:
#                     activityID          startTime  \
# 0  2025-02-14T08:48:00-CME-001  2025-02-14T08:48Z
# 1  2025-02-15T01:36:00-CME-001  2025-02-15T01:36Z
# 2  2025-02-15T20:36:00-CME-001  2025-02-15T20:36Z
# 3  2025-02-20T00:00:00-CME-001  2025-02-20T00:00Z
# 4  2025-02-20T00:00:00-CME-001  2025-02-20T00:00Z
#
#                                     linkedEvents               GST_ActivityID
# 0  {'activityID': '2025-02-14T07:31:00-FLR-001'}  2025-02-14T07:31:00-FLR-001
# 1  {'activityID': '2025-02-15T00:50:00-FLR-001'}  2025-02-15T00:50:00-FLR-001
# 2  {'activityID': '2025-02-15T19:22:00-FLR-001'}  2025-02-15T19:22:00-FLR-001
# 3  {'activityID': '2025-02-19T23:23:00-FLR-001'}  2025-02-19T23:23:00-FLR-001
# 4  {'activityID': '2025-02-23T14:08:00-IPS-001'}  2025-02-23T14:08:00-IPS-001

# %%
# print out the datatype of each column in this DataFrame:
df_expanded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   activityID      35 non-null     object
#  1   startTime       35 non-null     object
#  2   linkedEvents    35 non-null     object
#  3   GST_ActivityID  35 non-null     object
# dtypes: object(4)
# memory usage: 1.2+ KB

# %%
# Convert the 'GST_ActivityID' column to string format 
df_expanded['GST_ActivityID'] = df_expanded['GST_ActivityID'].astype(str)

# Convert startTime to datetime format  
df_expanded["startTime"] = pd.to_datetime(df_expanded['startTime'])

# Rename startTime to startTime_CME and activityID to cmeID
df_expanded = df_expanded.rename(columns={
    'startTime': 'startTime_CME',
    'activityID': 'cmeID'
})

# Drop linkedEvents
df_expanded = df_expanded.drop(columns =['linkedEvents'])

# Verify that all steps were executed correctly
df_expanded
# Out:
#                           cmeID             startTime_CME  \
# 0   2025-02-14T08:48:00-CME-001 2025-02-14 08:48:00+00:00
# 1   2025-02-15T01:36:00-CME-001 2025-02-15 01:36:00+00:00
# 2   2025-02-15T20:36:00-CME-001 2025-02-15 20:36:00+00:00
# 3   2025-02-20T00:00:00-CME-001 2025-02-20 00:00:00+00:00
# 4   2025-02-20T00:00:00-CME-001 2025-02-20 00:00:00+00:00
# 5   2025-02-20T10:36:00-CME-001 2025-02-20 10:36:00+00:00
# 6   2025-02-22T21:36:00-CME-001 2025-02-22 21:36:00+00:00
# 7   2025-02-23T02:36:00-CME-001 2025-02-23 02:36:00+00:00
# 8   2025-02-23T19:36:00-CME-001 2025-02-23 19:36:00+00:00
# 9   2025-02-24T07:00:00-CME-001 2025-02-24 07:00:00+00:00
# 10  2025-02-24T07:00:00-CME-001 2025-02-24 07:00:00+00:00
# 11  2025-02-24T07:00:00-CME-001 2025-02-24 07:00:00+00:00
# 12  2025-02-24T21:24:00-CME-001 2025-02-24 21:24:00+00:00
# 13  2025-02-24T21:24:00-CME-001 2025-02-24 21:24:00+00:00
# 14  2025-02-24T21:24:00-CME-001 2025-02-24 21:24:00+00:00
# 15  2025-02-24T21:24:00-CME-001 2025-02-24 21:24:00+00:00
# 16  2025-02-24T21:24:00-CME-001 2025-02-24 21:24:00+00:00
# 17  2025-02-24T21:24:00-CME-001 2025-02-24 21:24:00+00:00
# 18  2025-02-24T21:24:00-CME-001 2025-02-24 21:24:00+00:00
# 19  2025-02-25T12:38:00-CME-001 2025-02-25 12:38:00+00:00
# 20  2025-02-25T12:38:00-CME-001 2025-02-25 12:38:00+00:00
# 21  2025-02-26T06:48:00-CME-001 2025-02-26 06:48:00+00:00
# 22  2025-02-27T00:12:00-CME-001 2025-02-27 00:12:00+00:00
# 23  2025-02-28T17:12:00-CME-001 2025-02-28 17:12:00+00:00
# 24  2025-02-28T17:24:00-CME-001 2025-02-28 17:24:00+00:00
# 25  2025-03-01T18:24:00-CME-001 2025-03-01 18:24:00+00:00
# 26  2025-03-01T18:24:00-CME-001 2025-03-01 18:24:00+00:00
# 27  2025-03-01T23:36:00-CME-001 2025-03-01 23:36:00+00:00
# 28  2025-03-02T04:00:00-CME-001 2025-03-02 04:00:00+00:00
# 29  2025-03-02T06:24:00-CME-001 2025-03-02 06:24:00+00:00
# 30  2025-03-02T09:48:00-CME-001 2025-03-02 09:48:00+00:00
# 31  2025-03-07T21:49:00-CME-001 2025-03-07 21:49:00+00:00
# 32  2025-03-07T22:12:00-CME-001 2025-03-07 22:12:00+00:00
# 33  2025-03-11T14:00:00-CME-001 2025-03-11 14:00:00+00:00
# 34  2025-03-11T22:24:00-CME-001 2025-03-11 22:24:00+00:00
#
#                  GST_ActivityID
# 0   2025-02-14T07:31:00-FLR-001
# 1   2025-02-15T00:50:00-FLR-001
# 2   2025-02-15T19:22:00-FLR-001
# 3   2025-02-19T23:23:00-FLR-001
# 4   2025-02-23T14:08:00-IPS-001
# 5   2025-02-23T21:20:00-IPS-001
# 6   2025-02-22T20:55:00-FLR-001
# 7   2025-02-23T02:00:00-FLR-001
# 8   2025-02-23T19:22:00-FLR-001
# 9   2025-02-24T06:53:00-FLR-001
# 10  2025-02-26T05:26:00-IPS-001
# 11  2025-02-27T09:00:00-GST-001
# 12  2025-02-24T21:50:00-FLR-001
# 13  2025-02-25T00:11:00-SEP-001
# 14  2025-02-25T00:17:00-SEP-001
# 15  2025-02-25T00:20:00-SEP-001
# 16  2025-02-25T00:42:00-SEP-001
# 17  2025-02-25T03:05:00-SEP-001
# 18  2025-02-25T03:52:00-SEP-001
# 19  2025-02-25T11:20:00-FLR-001
# 20  2025-02-28T08:30:00-IPS-001
# 21  2025-02-28T19:32:00-IPS-001
# 22  2025-02-26T22:37:00-FLR-001
# 23  2025-03-01T03:22:00-SEP-001
# 24  2025-02-28T16:18:00-FLR-001
# 25  2025-03-04T17:10:00-IPS-001
# 26  2025-03-07T17:35:00-RBE-001
# 27  2025-03-01T22:44:00-FLR-001
# 28  2025-03-02T03:37:00-FLR-001
# 29  2025-03-02T05:46:00-FLR-001
# 30  2025-03-02T09:26:00-FLR-001
# 31  2025-03-07T20:54:00-FLR-001
# 32  2025-03-10T13:44:00-IPS-001
# 33  2025-03-11T13:03:00-FLR-001
# 34  2025-03-11T21:19:00-FLR-001

# %%
# We are only interested in CMEs related to GSTs so keep only rows where the GST_ActivityID column contains 'GST'
# use the method 'contains()' from the str library.  
#nameofcolumn.str.contains("whatever you're trying to match on")


df_new = df_expanded[df_expanded["GST_ActivityID"].str.contains("GST")] 
df_new
# Out:
#                           cmeID             startTime_CME  \
# 11  2025-02-24T07:00:00-CME-001 2025-02-24 07:00:00+00:00
#
#                  GST_ActivityID
# 11  2025-02-27T09:00:00-GST-001

# %% [markdown]
# ### GST Data

# %%
# Set the base URL to NASA's DONKI API:
base_url = "https://api.nasa.gov/DONKI/"

# Set the specifier for GSTs:
GST = "GST"

# Search for GSTs published between a begin and end date
startDate = "2013-05-01"
endDate   = "2024-05-01"

# Build URL for GST
gst_url = f'{base_url}{GST}?startDate={startDate}&endDate={endDate}&api_key={NASA_API_KEY}'
gst_url
# Out:
# 'https://api.nasa.gov/DONKI/GST?startDate=2013-05-01&endDate=2024-05-01&api_key=xd6laDXZahJaqfGeG0teFyg5EjIWGziP7XsdnUjm'

# %%
# Make a "GET" request for the GST URL and store it in a variable named gst_response
gst_response = requests.get(gst_url)
gst_response.url
# Out:
# 'https://api.nasa.gov/DONKI/GST?startDate=2013-05-01&endDate=2024-05-01&api_key=xd6laDXZahJaqfGeG0teFyg5EjIWGziP7XsdnUjm'

# %%
# Convert the response variable to json and store it as a variable named gst_json

# Preview the first result in JSON format
# Use json.dumps with argument indent=4 to format data

#why is the data not printing

gst_json = gst_response.json()
print(json.dumps(gst_json, indent=4))
# Out:
# [
#     {
#         "gstID": "2013-06-01T01:00:00-GST-001",
#         "startTime": "2013-06-01T01:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2013-06-01T01:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/326/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2013-05-31T15:45:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2013-07-15T19:26Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2013-06-07T03:00:00-GST-001",
#         "startTime": "2013-06-07T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2013-06-07T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/330/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2013-06-02T20:24:00-CME-001"
#             }
#         ],
#         "submissionTime": "2013-07-15T19:41Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2013-06-29T03:00:00-GST-001",
#         "startTime": "2013-06-29T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2013-06-29T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2013-06-29T06:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/561/-1",
#         "linkedEvents": null,
#         "submissionTime": "2013-09-25T04:48Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2013-10-02T03:00:00-GST-001",
#         "startTime": "2013-10-02T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2013-10-02T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/3317/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2013-09-29T22:40:00-CME-001"
#             },
#             {
#                 "activityID": "2013-10-02T01:54:00-IPS-001"
#             },
#             {
#                 "activityID": "2013-10-02T02:47:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2013-10-02T13:23Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2013-12-08T00:00:00-GST-001",
#         "startTime": "2013-12-08T00:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2013-12-08T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/3738/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2013-12-04T23:12:00-CME-001"
#             },
#             {
#                 "activityID": "2013-12-07T21:30:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2013-12-08T03:42Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2014-02-19T03:00:00-GST-001",
#         "startTime": "2014-02-19T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2014-02-19T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/4632/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2014-02-16T14:15:00-CME-001"
#             },
#             {
#                 "activityID": "2014-02-19T03:10:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2014-03-18T23:25Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2014-02-20T03:00:00-GST-001",
#         "startTime": "2014-02-20T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2014-02-20T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/4633/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2014-02-18T01:25:00-CME-001"
#             },
#             {
#                 "activityID": "2014-02-20T02:50:00-IPS-001"
#             },
#             {
#                 "activityID": "2014-02-20T05:14:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2014-03-19T20:13Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2014-02-27T18:00:00-GST-001",
#         "startTime": "2014-02-27T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2014-02-27T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/4640/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2014-02-25T01:25:00-CME-001"
#             },
#             {
#                 "activityID": "2014-02-27T16:10:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2014-03-19T22:41Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2014-06-08T03:00:00-GST-001",
#         "startTime": "2014-06-08T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2014-06-08T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2014-06-08T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/5691/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2014-06-04T13:25:00-CME-001"
#             },
#             {
#                 "activityID": "2014-06-07T16:09:00-IPS-001"
#             },
#             {
#                 "activityID": "2014-06-08T05:08:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2014-06-08T05:28Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2014-08-19T21:00:00-GST-001",
#         "startTime": "2014-08-19T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2014-08-20T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/6430/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2014-08-15T21:12:00-CME-001"
#             },
#             {
#                 "activityID": "2014-08-19T05:57:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2014-08-20T00:37Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2014-09-12T15:00:00-GST-001",
#         "startTime": "2014-09-12T15:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2014-09-12T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2014-09-13T00:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/6639/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2014-09-10T18:18:00-CME-001"
#             },
#             {
#                 "activityID": "2014-09-12T15:26:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2014-09-12T18:11Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-01-07T06:00:00-GST-001",
#         "startTime": "2015-01-07T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-01-07T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-01-07T12:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/7537/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-01-07T05:24:00-IPS-001"
#             },
#             {
#                 "activityID": "2015-01-07T08:40:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2015-01-07T13:42Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2015-03-17T06:00:00-GST-001",
#         "startTime": "2015-03-17T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-03-17T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-17T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-17T15:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-17T18:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-17T21:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-18T00:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-18T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-18T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8031/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-03-15T02:00:00-CME-001"
#             },
#             {
#                 "activityID": "2015-03-17T04:05:00-IPS-001"
#             },
#             {
#                 "activityID": "2015-03-16T00:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-03-18T18:43Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2015-03-22T06:00:00-GST-001",
#         "startTime": "2015-03-22T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-03-22T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8077/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-03-21T20:25:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2015-03-22T09:34Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-04-10T03:00:00-GST-001",
#         "startTime": "2015-04-10T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-04-10T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-04-10T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-04-10T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8201/-1",
#         "linkedEvents": null,
#         "submissionTime": "2015-04-10T06:11Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-04-16T21:00:00-GST-001",
#         "startTime": "2015-04-16T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-04-17T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8246/-1",
#         "linkedEvents": null,
#         "submissionTime": "2015-04-17T00:14Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-05-13T03:00:00-GST-001",
#         "startTime": "2015-05-13T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-05-13T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-05-13T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8487/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-05-12T17:20:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-05-13T06:28Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-05-13T04:30:00-GST-001",
#         "startTime": "2015-05-13T04:30Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-05-13T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8489/-1",
#         "linkedEvents": null,
#         "submissionTime": "2015-05-13T12:08Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-05-19T00:00:00-GST-001",
#         "startTime": "2015-05-19T00:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-05-19T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-05-19T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8521/-1",
#         "linkedEvents": null,
#         "submissionTime": "2015-05-19T03:50Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-06-08T06:00:00-GST-001",
#         "startTime": "2015-06-08T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-06-08T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8621/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-06-08T00:16:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-06-08T09:10Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-06-22T18:00:00-GST-001",
#         "startTime": "2015-06-22T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-06-22T21:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-06-22T21:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-06-23T03:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-06-23T06:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-06-23T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-06-23T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8763/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-06-21T02:48:00-CME-001"
#             },
#             {
#                 "activityID": "2015-06-22T17:59:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2015-06-22T21:22Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-06-25T06:00:00-GST-001",
#         "startTime": "2015-06-25T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-06-25T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8802/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-06-22T18:36:00-CME-001"
#             },
#             {
#                 "activityID": "2015-06-24T12:57:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2015-06-25T09:24Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-07-04T13:00:00-GST-001",
#         "startTime": "2015-07-04T13:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-07-05T00:00Z",
#                 "kpIndex": 5.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-07-05T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-07-05T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8862/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-07-04T11:58:00-IPS-001"
#             },
#             {
#                 "activityID": "2015-07-04T11:59:00-HSS-001"
#             },
#             {
#                 "activityID": "2015-07-04T20:20:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2015-07-05T01:39Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-08-15T09:00:00-GST-001",
#         "startTime": "2015-08-15T09:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-08-15T12:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-08-15T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-08-16T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9113/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-08-12T15:12:00-CME-001"
#             },
#             {
#                 "activityID": "2015-08-13T00:30:00-CME-001"
#             },
#             {
#                 "activityID": "2015-08-15T07:43:00-IPS-001"
#             },
#             {
#                 "activityID": "2015-08-15T11:03:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2015-08-15T12:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-08-23T06:00:00-GST-001",
#         "startTime": "2015-08-23T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-08-23T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9162/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-08-23T07:15:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-08-23T09:10Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-08-27T03:00:00-GST-001",
#         "startTime": "2015-08-27T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-08-27T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-08-27T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9200/-1",
#         "linkedEvents": null,
#         "submissionTime": "2015-08-27T06:43Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-08-27T21:00:00-GST-001",
#         "startTime": "2015-08-27T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-08-28T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-08-28T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9210/-1",
#         "linkedEvents": null,
#         "submissionTime": "2015-08-28T00:29Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-08-28T18:00:00-GST-001",
#         "startTime": "2015-08-28T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-08-28T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9230/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-08-28T16:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-08-31T13:46Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-09-07T15:00:00-GST-001",
#         "startTime": "2015-09-07T15:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-09-07T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-07T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-08T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-08T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-08T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9274/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-09-07T12:22:00-HSS-001"
#             },
#             {
#                 "activityID": "2015-09-07T13:20:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2015-09-09T16:52Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2015-09-09T03:00:00-GST-001",
#         "startTime": "2015-09-09T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-09-09T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-09T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-09T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-09T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-10T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9294/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-09-04T14:12:00-CME-001"
#             },
#             {
#                 "activityID": "2015-09-04T19:24:00-CME-001"
#             }
#         ],
#         "submissionTime": "2015-09-09T15:16Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2015-09-11T06:00:00-GST-001",
#         "startTime": "2015-09-11T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-09-11T09:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-11T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-11T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9302/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-09-06T23:30:00-CME-001"
#             },
#             {
#                 "activityID": "2015-09-07T10:36:00-CME-001"
#             },
#             {
#                 "activityID": "2015-09-11T06:43:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-09-11T09:32Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-09-20T06:00:00-GST-001",
#         "startTime": "2015-09-20T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-09-20T09:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9349/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-09-18T05:00:00-CME-001"
#             },
#             {
#                 "activityID": "2015-09-20T05:33:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2015-09-20T09:16Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-09-20T09:00:00-GST-001",
#         "startTime": "2015-09-20T09:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-09-20T12:00Z",
#                 "kpIndex": 5.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9352/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-09-18T05:00:00-CME-001"
#             },
#             {
#                 "activityID": "2015-09-20T05:33:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2015-09-20T13:39Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-10-07T18:00:00-GST-001",
#         "startTime": "2015-10-07T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-10-07T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-07T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-07T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-07T21:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-07T21:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-08T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-08T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-08T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9466/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-10-07T13:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-10-07T20:04Z",
#         "versionId": 3
#     },
#     {
#         "gstID": "2015-11-07T03:00:00-GST-001",
#         "startTime": "2015-11-07T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-11-07T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-11-07T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9662/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-11-04T14:24:00-CME-001"
#             },
#             {
#                 "activityID": "2015-11-06T17:34:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2015-11-07T06:43Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-11-10T12:00:00-GST-001",
#         "startTime": "2015-11-10T12:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-11-10T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9682/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-11-09T19:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-11-10T15:36Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-12-20T03:00:00-GST-001",
#         "startTime": "2015-12-20T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-12-20T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-12-20T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-12-20T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-12-21T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-12-21T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-12-21T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9878/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-12-16T09:36:00-CME-001"
#             },
#             {
#                 "activityID": "2015-12-16T14:48:00-CME-001"
#             },
#             {
#                 "activityID": "2015-12-19T15:27:00-IPS-001"
#             },
#             {
#                 "activityID": "2015-12-20T00:04:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2015-12-20T06:47Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-12-31T13:30:00-GST-001",
#         "startTime": "2015-12-31T13:30Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-12-31T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-12-31T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-01-01T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-01-01T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9956/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-12-28T12:39:00-CME-001"
#             },
#             {
#                 "activityID": "2015-12-31T23:52:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2015-12-31T15:32Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-01-21T03:00:00-GST-001",
#         "startTime": "2016-01-21T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-01-21T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10074/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-01-15T00:00:00-CME-001"
#             },
#             {
#                 "activityID": "2016-01-21T10:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-01-21T06:28Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-02-16T18:00:00-GST-001",
#         "startTime": "2016-02-16T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-02-16T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-02-16T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10217/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-02-16T01:55:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-02-16T22:00Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2016-02-17T21:00:00-GST-001",
#         "startTime": "2016-02-17T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-02-18T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10231/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-02-16T01:55:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-02-18T01:19Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "none",
#         "startTime": "2016-02-17T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-02-19T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10233/-1",
#         "linkedEvents": null,
#         "submissionTime": "2016-02-18T01:06Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2016-03-06T18:00:00-GST-001",
#         "startTime": "2016-03-06T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-03-06T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-03-06T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-03-07T00:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10302/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-03-06T04:30:00-IPS-001"
#             },
#             {
#                 "activityID": "2016-03-06T09:00:00-HSS-001"
#             },
#             {
#                 "activityID": "2016-03-06T16:32:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2016-03-06T21:35Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-03-11T12:00:00-GST-001",
#         "startTime": "2016-03-11T12:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-03-11T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-03-11T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10325/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-03-11T04:21:00-IPS-001"
#             },
#             {
#                 "activityID": "2016-03-11T13:00:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2016-03-11T15:39Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-04-02T21:00:00-GST-001",
#         "startTime": "2016-04-02T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-04-03T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10421/-1",
#         "linkedEvents": null,
#         "submissionTime": "2016-04-03T00:28Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-04-02T22:30:00-GST-001",
#         "startTime": "2016-04-02T22:30Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-04-03T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10423/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-03-31T01:25:00-CME-001"
#             }
#         ],
#         "submissionTime": "2016-04-03T00:31Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-05-02T03:00:00-GST-001",
#         "startTime": "2016-05-02T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-05-02T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10581/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-05-01T13:30:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-05-02T06:22Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-05-08T00:00:00-GST-001",
#         "startTime": "2016-05-08T00:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-05-08T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-05-08T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-05-08T06:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-05-08T06:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-05-08T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-05-09T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-05-09T03:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10610/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-05-08T01:21:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-05-08T03:31Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-06-06T03:00:00-GST-001",
#         "startTime": "2016-06-06T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-06-06T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10741/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-06-04T23:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-06-06T06:26Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-06-14T18:00:00-GST-001",
#         "startTime": "2016-06-14T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-06-14T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-06-14T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10775/-1",
#         "linkedEvents": null,
#         "submissionTime": "2016-06-14T21:29Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-09-01T21:00:00-GST-001",
#         "startTime": "2016-09-01T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-09-02T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-09-02T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-09-03T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/11205/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-09-01T10:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-09-02T12:18Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2016-09-27T15:00:00-GST-001",
#         "startTime": "2016-09-27T15:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-09-27T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/11309/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-09-26T07:05:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-09-27T18:24Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-09-28T18:00:00-GST-001",
#         "startTime": "2016-09-28T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-09-28T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/11318/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-09-26T07:05:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-09-28T21:36Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-10-13T15:00:00-GST-001",
#         "startTime": "2016-10-13T15:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-10-13T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-10-13T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-10-14T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/11387/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-10-08T21:09:00-CME-001"
#             },
#             {
#                 "activityID": "2016-10-12T21:21:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2016-10-13T18:27Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-10-25T12:00:00-GST-001",
#         "startTime": "2016-10-25T12:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-10-25T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-10-25T15:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-10-25T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-10-26T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-10-26T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-10-26T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/11438/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-10-25T09:29:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-10-25T14:16Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-11-25T03:00:00-GST-001",
#         "startTime": "2016-11-25T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-11-25T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/11725/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-11-24T05:14:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-11-25T06:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-12-21T15:00:00-GST-001",
#         "startTime": "2016-12-21T15:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-12-21T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/12019/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-12-21T03:37:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-12-21T18:44Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2017-03-01T23:00:00-GST-001",
#         "startTime": "2017-03-01T23:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2017-03-02T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2017-03-02T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/12246/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2017-03-01T06:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2017-03-01T23:56Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2017-03-27T09:00:00-GST-001",
#         "startTime": "2017-03-27T09:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2017-03-27T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2017-03-27T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2017-03-27T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/12324/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2017-03-27T00:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2017-03-27T12:18Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2017-04-20T03:00:00-GST-001",
#         "startTime": "2017-04-20T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2017-04-20T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/12475/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2017-04-18T18:02:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2017-04-20T06:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2017-04-22T03:00:00-GST-001",
#         "startTime": "2017-04-22T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2017-04-22T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/12490/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2017-04-18T18:02:00-HSS-001"
#             },
#             {
#                 "activityID": "2017-04-21T11:20:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2017-04-22T06:38Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2017-04-23T06:00:00-GST-001",
#         "startTime": "2017-04-23T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2017-04-23T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/12495/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2017-04-21T11:20:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2017-04-23T14:55Z",
#         "versionId": 1
#     },
#     {
# ...
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/24366/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-03-20T02:41:00-CME-001"
#             },
#             {
#                 "activityID": "2023-03-20T14:42:00-CME-001"
#             },
#             {
#                 "activityID": "2023-03-23T09:10:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-03-23T14:52:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-03-23T15:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-04-23T18:00:00-GST-001",
#         "startTime": "2023-04-23T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-04-23T21:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-04-24T00:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-04-24T03:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-04-24T06:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-04-24T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-04-24T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/24772/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-04-21T18:12:00-CME-001"
#             },
#             {
#                 "activityID": "2023-04-23T17:00:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-04-23T19:15:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-04-23T21:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-05-06T03:00:00-GST-001",
#         "startTime": "2023-05-06T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-05-06T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/24962/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-05-06T00:25:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2023-05-06T06:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-05-20T00:00:00-GST-001",
#         "startTime": "2023-05-20T00:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-05-20T03:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-05-20T06:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/25253/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-05-19T20:36:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-05-20T03:34:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2023-05-20T13:21Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2023-05-21T18:00:00-GST-001",
#         "startTime": "2023-05-21T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-05-21T21:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-05-22T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/25292/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-05-21T14:20:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2023-05-22T12:00Z",
#         "versionId": 3
#     },
#     {
#         "gstID": "2023-06-15T21:00:00-GST-001",
#         "startTime": "2023-06-15T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-06-16T00:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-06-16T06:00Z",
#                 "kpIndex": 6.33,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/25577/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-06-15T05:46:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-06-15T09:15:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2023-06-16T00:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-08-05T03:00:00-GST-001",
#         "startTime": "2023-08-05T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-08-05T06:00Z",
#                 "kpIndex": 6.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/26336/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-08-02T09:12:00-CME-001"
#             },
#             {
#                 "activityID": "2023-08-05T02:10:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2023-08-05T06:39Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-09-03T00:00:00-GST-001",
#         "startTime": "2023-09-03T00:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-09-03T03:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/26745/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-09-01T18:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2023-09-06T15:14Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2023-09-12T15:00:00-GST-001",
#         "startTime": "2023-09-12T15:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-09-12T18:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/26894/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-09-12T10:18:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-09-12T13:46:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-09-12T18:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-09-19T00:00:00-GST-001",
#         "startTime": "2023-09-19T00:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-09-19T03:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-09-19T06:00Z",
#                 "kpIndex": 6.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/26987/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-09-14T23:12:00-CME-001"
#             },
#             {
#                 "activityID": "2023-09-16T09:12:00-CME-001"
#             },
#             {
#                 "activityID": "2023-09-18T12:58:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-09-18T17:54:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-09-19T03:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-09-24T18:00:00-GST-001",
#         "startTime": "2023-09-24T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-09-24T21:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-09-25T00:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/27105/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-09-24T19:52:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-09-24T22:30:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-09-24T21:32Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-11-05T09:00:00-GST-001",
#         "startTime": "2023-11-05T09:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-11-05T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-11-05T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-11-05T18:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-11-05T21:00Z",
#                 "kpIndex": 6.33,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-11-06T06:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/27600/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-11-02T03:36:00-CME-001"
#             },
#             {
#                 "activityID": "2023-11-03T05:48:00-CME-001"
#             },
#             {
#                 "activityID": "2023-11-05T08:10:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-11-05T10:34:00-MPC-001"
#             },
#             {
#                 "activityID": "2023-11-05T11:45:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-11-05T14:52:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-11-06T17:27Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2023-11-25T18:00:00-GST-001",
#         "startTime": "2023-11-25T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-11-25T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/27882/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-11-22T21:36:00-CME-001"
#             },
#             {
#                 "activityID": "2023-11-24T18:50:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-11-24T18:50:00-HSS-001"
#             },
#             {
#                 "activityID": "2023-11-25T07:59:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-11-25T09:28:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-11-29T15:14Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2023-12-01T09:00:00-GST-001",
#         "startTime": "2023-12-01T09:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-12-01T12:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-12-01T15:00Z",
#                 "kpIndex": 6.33,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/27948/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-11-28T20:24:00-CME-001"
#             },
#             {
#                 "activityID": "2023-11-28T20:48:00-CME-001"
#             },
#             {
#                 "activityID": "2023-12-01T08:48:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-12-01T11:04:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-12-01T12:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-12-18T06:00:00-GST-001",
#         "startTime": "2023-12-18T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-12-18T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/28236/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-12-14T17:38:00-CME-001"
#             },
#             {
#                 "activityID": "2023-12-17T07:32:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-12-17T10:54:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-12-18T09:34Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2024-03-03T18:00:00-GST-001",
#         "startTime": "2024-03-03T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2024-03-03T21:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/29440/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2024-02-28T17:48:00-CME-001"
#             },
#             {
#                 "activityID": "2024-03-03T08:47:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2024-03-03T21:35Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2024-03-23T21:00:00-GST-001",
#         "startTime": "2024-03-23T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2024-03-24T00:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/29751/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2024-03-23T12:49:00-IPS-001"
#             },
#             {
#                 "activityID": "2024-03-23T15:35:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2024-03-24T00:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2024-03-24T12:00:00-GST-001",
#         "startTime": "2024-03-24T12:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2024-03-24T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2024-03-24T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2024-03-24T18:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2024-03-24T21:00Z",
#                 "kpIndex": 6.33,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/29769/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2024-03-23T01:25:00-CME-001"
#             },
#             {
#                 "activityID": "2024-03-23T01:48:00-CME-001"
#             },
#             {
#                 "activityID": "2024-03-24T14:10:00-IPS-001"
#             },
#             {
#                 "activityID": "2024-03-24T16:25:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2024-03-24T15:31Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2024-04-19T18:00:00-GST-001",
#         "startTime": "2024-04-19T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2024-04-19T21:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/30153/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2024-04-15T06:48:00-CME-001"
#             },
#             {
#                 "activityID": "2024-04-19T04:53:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2024-04-19T21:40Z",
#         "versionId": 1
#     }
# ]

# %%
# Convert gst_json to a Pandas DataFrame  

# Keep only the columns: gstID, startTime, linkedEvents

df_gst = pd.DataFrame(gst_json)


df_gst= df_gst[['gstID', 'startTime', 'linkedEvents']]
df_gst.head()
# Out:
#                          gstID          startTime  \
# 0  2013-06-01T01:00:00-GST-001  2013-06-01T01:00Z
# 1  2013-06-07T03:00:00-GST-001  2013-06-07T03:00Z
# 2  2013-06-29T03:00:00-GST-001  2013-06-29T03:00Z
# 3  2013-10-02T03:00:00-GST-001  2013-10-02T03:00Z
# 4  2013-12-08T00:00:00-GST-001  2013-12-08T00:00Z
#
#                                         linkedEvents
# 0    [{'activityID': '2013-05-31T15:45:00-HSS-001'}]
# 1    [{'activityID': '2013-06-02T20:24:00-CME-001'}]
# 2                                               None
# 3  [{'activityID': '2013-09-29T22:40:00-CME-001'}...
# 4  [{'activityID': '2013-12-04T23:12:00-CME-001'}...

# %%
# Notice that the linkedEvents column allows us to identify the corresponding CME
# Remove rows with missing 'linkedEvents' since we won't be able to assign these to CME
df_gst = df_gst.dropna(subset=["linkedEvents"])
df_gst.head()
# Out:
#                          gstID          startTime  \
# 0  2013-06-01T01:00:00-GST-001  2013-06-01T01:00Z
# 1  2013-06-07T03:00:00-GST-001  2013-06-07T03:00Z
# 3  2013-10-02T03:00:00-GST-001  2013-10-02T03:00Z
# 4  2013-12-08T00:00:00-GST-001  2013-12-08T00:00Z
# 5  2014-02-19T03:00:00-GST-001  2014-02-19T03:00Z
#
#                                         linkedEvents
# 0    [{'activityID': '2013-05-31T15:45:00-HSS-001'}]
# 1    [{'activityID': '2013-06-02T20:24:00-CME-001'}]
# 3  [{'activityID': '2013-09-29T22:40:00-CME-001'}...
# 4  [{'activityID': '2013-12-04T23:12:00-CME-001'}...
# 5  [{'activityID': '2014-02-16T14:15:00-CME-001'}...

# %%
# Notice that the linkedEvents sometimes contains multiple events per row
# Use the explode method to ensure that each row is one element. Ensure to reset the index and drop missing values.
df_gst = df_gst.explode('linkedEvents', ignore_index=True).dropna()
df_gst.head()
# Out:
#                          gstID          startTime  \
# 0  2013-06-01T01:00:00-GST-001  2013-06-01T01:00Z
# 1  2013-06-07T03:00:00-GST-001  2013-06-07T03:00Z
# 2  2013-10-02T03:00:00-GST-001  2013-10-02T03:00Z
# 3  2013-10-02T03:00:00-GST-001  2013-10-02T03:00Z
# 4  2013-10-02T03:00:00-GST-001  2013-10-02T03:00Z
#
#                                     linkedEvents
# 0  {'activityID': '2013-05-31T15:45:00-HSS-001'}
# 1  {'activityID': '2013-06-02T20:24:00-CME-001'}
# 2  {'activityID': '2013-09-29T22:40:00-CME-001'}
# 3  {'activityID': '2013-10-02T01:54:00-IPS-001'}
# 4  {'activityID': '2013-10-02T02:47:00-MPC-001'}

# %%
# Apply the extract_activityID_from_dict function to each row in the 'linkedEvents' column (you can use apply() and a lambda function)
# and create a new column called 'CME_ActivityID' using loc indexer:

# Remove rows with missing CME_ActivityID, since we can't assign them to CMEs:

df_gst.loc[:,'CME_ActivityID'] = df_gst['linkedEvents'].apply(lambda x: extract_activityID_from_dict(x))
df_gst = df_gst.dropna(subset="CME_ActivityID")
df_gst.head()
# Out:
# Empty DataFrame
# Columns: [gstID, startTime, linkedEvents, CME_ActivityID]
# Index: []

# %%
# Convert the 'CME_ActivityID' column to string format 
if 'CME_ActivityID' in df.columns:
    df['CME_ActivityID'] = df['CME_ActivityID'].astype(str)
else:
    print("Error: 'CME_ActivityID' column not found. Ensure it was created correctly.")

# Convert the 'gstID' column to string format 
if 'GST_ActivityID' in df.columns:
    df['GST_ActivityID'] = df['GST_ActivityID'].astype(str)
else:
    print("Error: 'GST_ActivityID' column not found. Ensure it was loaded correctly.")

# Convert startTime to datetime format  
if 'startTime' in df.columns:
    df['startTime'] = pd.to_datetime(df['startTime'], errors='coerce')
else:
    print("Error: 'startTime' column not found. Ensure it was loaded correctly.")

# Rename startTime to startTime_GST 
df.rename(columns={'startTime': 'startTime_GST'}, inplace=True)

# Drop linkedEvents
df.rename(columns={'startTime': 'startTime_GST'}, inplace=True)

# Verify that all steps were executed correctly
print(df.info()) 
print(df.head())
# Out:
# Error: 'GST_ActivityID' column not found. Ensure it was loaded correctly.
# Error: 'startTime' column not found. Ensure it was loaded correctly.
# <class 'pandas.core.frame.DataFrame'>
# Index: 105 entries, 0 to 116
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gstID           105 non-null    object
#  1   startTime_GST   105 non-null    datetime64[ns, UTC]
#  2   linkedEvents    105 non-null    object
#  3   CME_ActivityID  105 non-null    object
# dtypes: datetime64[ns, UTC](1), object(3)
# memory usage: 4.1+ KB
# None
#                          gstID             startTime_GST  \
# 0  2013-06-01T01:00:00-GST-001 2013-06-01 01:00:00+00:00
# 1  2013-06-07T03:00:00-GST-001 2013-06-07 03:00:00+00:00
# 3  2013-10-02T03:00:00-GST-001 2013-10-02 03:00:00+00:00
# 4  2013-12-08T00:00:00-GST-001 2013-12-08 00:00:00+00:00
# 5  2014-02-19T03:00:00-GST-001 2014-02-19 03:00:00+00:00
#
#                                         linkedEvents  \
# 0    [{'activityID': '2013-05-31T15:45:00-HSS-001'}]
# 1    [{'activityID': '2013-06-02T20:24:00-CME-001'}]
# 3  [{'activityID': '2013-09-29T22:40:00-CME-001'}...
# 4  [{'activityID': '2013-12-04T23:12:00-CME-001'}...
# 5  [{'activityID': '2014-02-16T14:15:00-CME-001'}...
#
#                 CME_ActivityID
# 0  2013-05-31T15:45:00-HSS-001
# 1  2013-06-02T20:24:00-CME-001
# 3  2013-09-29T22:40:00-CME-001
# 4  2013-12-04T23:12:00-CME-001
# 5  2014-02-16T14:15:00-CME-001

# %%
# We are only interested in GSTs related to CMEs so keep only rows where the CME_ActivityID column contains 'CME'
# use the method 'contains()' from the str library.

# %% [markdown]
# ### Merge both datatsets

# %%
# Now merge both datasets using 'gstID' and 'CME_ActivityID' for gst and 'GST_ActivityID' and 'cmeID' for cme. Use the 'left_on' and 'right_on' specifiers.

# %%
# Verify that the new DataFrame has the same number of rows as cme and gst

# %% [markdown]
# ### Computing the time it takes for a CME to cause a GST

# %%
# Compute the time diff between startTime_GST and startTime_CME by creating a new column called `timeDiff`.
time_diff = startTime_GST - startTime_CME
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 # Compute the time diff between startTime_GST and startTime_CME by creating a new column called `timeDiff`.
# ----> 2 time_diff = startTime_GST - startTime_CME
#
# NameError: name 'startTime_GST' is not defined

# %%
# Use describe() to compute the mean and median time 
# that it takes for a CME to cause a GST.

# %% [markdown]
# ### Exporting data in csv format

# %%
# Export data to CSV without the index
df.to_csv('collected_data.csv', index=False)
