# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json
import os
from datetime import datetime
## Load the NASA_API_KEY from the env file
load_dotenv()
NASA_API_KEY = os.getenv('NASA_API_KEY')

# %% [markdown]
# ### CME Data

# %%
# Set the base URL to NASA's DONKI API:
base_url = "https://api.nasa.gov/DONKI/"

# Set the specifier for CMEs:
CME = "CME"

# Search for CMEs published between a begin and end date
startDate = "2013-05-01"
endDate   = "2024-05-01"

# Build URL for CME
cme_url = f'{base_url}{CME}?StartDate={startDate}&EndDate={endDate}&api_key={NASA_API_KEY}'

# %%
# Make a "GET" request for the CME URL and store it in a variable named cme_response
cme_response = requests.get(cme_url)
cme_response
# Out:
# <Response [200]>

# %%
# Convert the response variable to json and store it as a variable named cme_json
cme_json = cme_response.json()
cme_json
# Out:
# [{'activityID': '2024-10-26T06:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-26T06:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'S16E60',
#   'activeRegionNum': 13873,
#   'note': 'This CME is visible as a partial halo directed towards the southeast in SOHO LASCO C2/C3 and STEREO A COR2 imagery. The source is an eruption which is associated with an M9.5 flare from Active Region 13873 (S14E56) and X1.8 flare from Active Region 13873 (S16E60) starting around 2024-10-26T06:30Z as seen in SDO AIA 131, 171, 193, 304 imagery. A wide opening of field lines is visible over the southeast limb in SDO AIA 171 and 193, with post eruptive arcades visible in SDO AIA 131, 171, 193, 304 starting around 07:50Z.',
#   'submissionTime': '2024-10-30T14:51Z',
#   'versionId': 3,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34212/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-26T09:04Z',
#     'latitude': -32.0,
#     'longitude': -54.0,
#     'halfAngle': 53.0,
#     'speed': 1523.0,
#     'type': 'O',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement of the bulk portion based on the approximate source location and best fit between SOHO LASCO C2/C3 and STEREO A COR2 imagery. This event is wide and difficult to fit between coronagraphs, with measured longitudes ranging from -41 to -66.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 21.5,
#     'submissionTime': '2024-10-26T17:58Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34213/-1',
#     'enlilList': [{'modelCompletionTime': '2024-10-26T15:54Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': '2024-10-28T04:00Z',
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': 5,
#       'kp_135': 7,
#       'kp_180': 7,
#       'isEarthGB': True,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34216/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Lucy',
#         'arrivalTime': '2024-10-27T18:03Z'},
#        {'isGlancingBlow': False,
#         'location': 'Parker Solar Probe',
#         'arrivalTime': '2024-10-27T07:24Z'},
#        {'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-10-27T06:53Z'},
#        {'isGlancingBlow': True,
#         'location': 'OSIRIS-APEX',
#         'arrivalTime': '2024-10-28T00:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-10-28T18:00Z'}],
#       'cmeIDs': ['2024-10-26T06:48:00-CME-001']},
#      {'modelCompletionTime': '2024-10-26T16:17Z',
#       'au': 5.5,
#       'estimatedShockArrivalTime': '2024-10-28T04:00Z',
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': 5,
#       'kp_135': 7,
#       'kp_180': 7,
#       'isEarthGB': True,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34217/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Lucy',
#         'arrivalTime': '2024-10-27T18:07Z'},
#        {'isGlancingBlow': False,
#         'location': 'Parker Solar Probe',
#         'arrivalTime': '2024-10-27T07:03Z'},
#        {'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-10-27T06:58Z'},
#        {'isGlancingBlow': True,
#         'location': 'OSIRIS-APEX',
#         'arrivalTime': '2024-10-28T00:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-10-28T18:00Z'}],
#       'cmeIDs': ['2024-10-26T06:48:00-CME-001']}]},
#    {'isMostAccurate': True,
#     'time21_5': '2024-10-26T08:52Z',
#     'latitude': -19.0,
#     'longitude': -34.0,
#     'halfAngle': 54.0,
#     'speed': 1677.0,
#     'type': 'O',
#     'featureCode': 'SH',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'SHOCK MEASUREMENT based on the best fit between SOHO LASCO C2/C3 and STEREO A COR2 imagery tracking the wider, faint front which precedes the bulk of this CME. This measurement does not capture the entire shock feature observed in both coronagraphs, and instead follows the leading edge of the shock best, missing the widest portions of the partial halo.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 14.6,
#     'submissionTime': '2024-10-26T17:58Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34221/-1',
#     'enlilList': [{'modelCompletionTime': '2024-10-26T18:18Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': '2024-10-27T15:51Z',
#       'estimatedDuration': 19.1,
#       'rmin_re': 4.9,
#       'kp_18': None,
#       'kp_90': 8,
#       'kp_135': 9,
#       'kp_180': 9,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34225/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Lucy',
#         'arrivalTime': '2024-10-27T10:53Z'},
#        {'isGlancingBlow': False,
#         'location': 'Parker Solar Probe',
#         'arrivalTime': '2024-10-27T07:21Z'},
#        {'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-10-27T01:14Z'},
#        {'isGlancingBlow': False,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-10-28T02:03Z'},
#        {'isGlancingBlow': True,
#         'location': 'OSIRIS-APEX',
#         'arrivalTime': '2024-10-28T15:00Z'}],
#       'cmeIDs': ['2024-10-26T06:48:00-CME-001']},
#      {'modelCompletionTime': '2024-10-26T18:41Z',
#       'au': 5.5,
#       'estimatedShockArrivalTime': '2024-10-27T15:45Z',
#       'estimatedDuration': 18.3,
#       'rmin_re': 4.9,
#       'kp_18': None,
#       'kp_90': 8,
#       'kp_135': 9,
#       'kp_180': 9,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34226/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Lucy',
#         'arrivalTime': '2024-10-27T10:52Z'},
#        {'isGlancingBlow': False,
#         'location': 'Parker Solar Probe',
#         'arrivalTime': '2024-10-27T07:07Z'},
#        {'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-10-27T01:07Z'},
#        {'isGlancingBlow': False,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-10-28T02:22Z'},
#        {'isGlancingBlow': True,
#         'location': 'OSIRIS-APEX',
#         'arrivalTime': '2024-10-28T15:00Z'}],
#       'cmeIDs': ['2024-10-26T06:48:00-CME-001']}]}],
#   'linkedEvents': [{'activityID': '2024-10-26T05:57:00-FLR-001'},
#    {'activityID': '2024-10-26T06:32:00-FLR-001'},
#    {'activityID': '2024-10-26T16:45:00-SEP-001'},
#    {'activityID': '2024-10-26T18:05:00-SEP-001'},
#    {'activityID': '2024-10-26T18:57:00-SEP-001'},
#    {'activityID': '2024-10-26T19:02:00-SEP-001'},
#    {'activityID': '2024-10-26T19:50:00-SEP-001'},
#    {'activityID': '2024-10-26T20:06:00-SEP-001'},
#    {'activityID': '2024-10-26T21:43:00-SEP-001'},
#    {'activityID': '2024-10-28T04:13:00-IPS-001'},
#    {'activityID': '2024-10-28T08:57:00-SEP-001'},
#    {'activityID': '2024-10-28T16:58:00-IPS-001'}]},
#  {'activityID': '2024-10-26T08:09:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-26T08:09Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'S35E60',
#   'activeRegionNum': None,
#   'note': 'Loop CME seen to the south-southeast in the outflow of the halo CME 2024-10-26T06:48Z. May be associated with a secondary eruption or outflow near S35E60.',
#   'submissionTime': '2024-10-26T19:33Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34228/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-26T15:33Z',
#     'latitude': -63.0,
#     'longitude': -85.0,
#     'halfAngle': 19.0,
#     'speed': 506.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Leading edge measurement using two spacecraft showing southward deflection of the eruption.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 9.0,
#     'submissionTime': '2024-10-26T19:40Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34230/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-26T08:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-26T08:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Narrow yet bright CME seen best in SOHO C2 nearly due west along the outflow of several more minor CMEs to the southwest. Likely associated with eruptive activity just behind the western limb as evidenced by opening field lines seen in GOES SUVI 284 around 2024-10-26T07:45Z.',
#   'submissionTime': '2024-10-26T20:25Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34235/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-26T23:40Z',
#     'latitude': -1.0,
#     'longitude': 93.0,
#     'halfAngle': 15.0,
#     'speed': 225.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Triangulation accomplished using two spacecraft leading edge measurement.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 6.0,
#     'submissionTime': '2024-10-26T20:27Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34236/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-26T12:23:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-26T12:23Z',
#   'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Faint CME/outflow in the wake of the earlier significant 2024-10-26T06:48Z CME. Its source is not clear but there is some movement in the filament eruption in the SE preceding this time.',
#   'submissionTime': '2024-10-27T16:53Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34243/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-26T17:12Z',
#     'latitude': -62.0,
#     'longitude': -31.0,
#     'halfAngle': 28.0,
#     'speed': 684.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Very approximate analysis based on the fit with two coronagraphs.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-27T16:54Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34244/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-26T17:38:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-26T17:38Z',
#   'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Jet CME seen to the south-southeast in STEREO A COR2. Unclear source. May potentially be associated with eruptive activity from the southeast, including the recently eruptive Active Region 3872 with strong southward deflection. No SOHO imagery is available to corroborate a potential longitude due to comet observing.',
#   'submissionTime': '2024-10-27T00:31Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34237/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-27T00:09Z',
#     'latitude': -70.0,
#     'longitude': None,
#     'halfAngle': 10.0,
#     'speed': 448.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'STEREO A plane of sky measurement (-62.7 degrees longitude).',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 8.0,
#     'submissionTime': '2024-10-27T00:32Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34238/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-27T15:53:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-27T15:53Z',
#   'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'This CME is visible to the NE in SOHO LASCO C3 and STEREO A COR2 imagery. SOHO LASCO C2 imagery is not available for this event due to an on-going comet campaign. The sources is best seen in SDO/AIA 171 as fast moving/opening field lines far behind the NE limb.',
#   'submissionTime': '2024-10-27T21:53Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34245/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-27T20:10Z',
#     'latitude': 30.0,
#     'longitude': -122.0,
#     'halfAngle': 43.0,
#     'speed': 625.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Parameters based on best fit in SOHO LASCO C3 and STEREO A COR2 imagery. Limited STEREO A frames available for this event.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 17.5,
#     'submissionTime': '2024-10-27T21:54Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34246/-1',
#     'enlilList': [{'modelCompletionTime': '2024-10-27T22:05Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34247/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'OSIRIS-APEX',
#         'arrivalTime': '2024-10-29T23:23Z'},
#        {'isGlancingBlow': False,
#         'location': 'Parker Solar Probe',
#         'arrivalTime': '2024-10-29T13:20Z'}],
#       'cmeIDs': ['2024-10-27T15:53:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-28T08:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-28T08:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': 'N20E100',
#   'activeRegionNum': None,
#   'note': 'Bright lightbulb CME first seen in the NE by SOHO LASCO C2 beginning at 2024-10-28T08:48Z, as well as by STEREO A COR2 in later frames. This CME is currently not visible in SOHO LASCO C3 due to a data gap that began at 2024-10-28T02:30Z. The source of this event is a large filament eruption seen along the NE limb (centered at approx. N20E100) in SDO AIA , GOES SUVI and STEREO A EUVI 304. Opening field lines are also visible in SDO AIA 171, 193, 211, and GOES SUVI 284.',
#   'submissionTime': '2024-10-28T15:53Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34257/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-28T15:52Z',
#     'latitude': 24.0,
#     'longitude': -110.0,
#     'halfAngle': 37.0,
#     'speed': 568.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on approximate source location and best fit between SOHO LASCO C2 and STEREO A COR2.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-28T15:54Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34258/-1',
#     'enlilList': [{'modelCompletionTime': '2024-10-28T16:05Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34259/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'OSIRIS-APEX',
#         'arrivalTime': '2024-10-30T21:57Z'},
#        {'isGlancingBlow': False,
#         'location': 'Parker Solar Probe',
#         'arrivalTime': '2024-10-30T08:13Z'}],
#       'cmeIDs': ['2024-10-28T08:48:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-28T14:00:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-28T14:00Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Bright CME first seen in the SW by SOHO LASCO C2 beginning at 2024-10-28T14:00Z, as well as by STEREO A COR2 in later frames. This CME is observed in SOHO LASCO C3 white light imagery, but running difference image quality at this time does not capture the front. The source of this event is a far sided eruption seen along the SW limb. Wide opening field lines can be seen in SDO AIA 171, 193, 211, GOES SUVI 284, and STEREO A EUVI 195. Post eruptive arcades are also visible in SDO AIA 211 and STEREO A EUVI 195.',
#   'submissionTime': '2024-10-29T01:34Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34263/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-28T18:58Z',
#     'latitude': -54.0,
#     'longitude': 95.0,
#     'halfAngle': 43.0,
#     'speed': 755.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Triangulated measurement between SOHO LASCO C2/STEREO COR2A, and the observed source just beyond the SW limb in SDO AIA imagery. SOHO LASCO is currently in a comet observation campaign affecting imagery, notably LASCO C3 running difference which does not observe the front at all while it can be seen in C3 white light. Enough C2 and COR2A imagery is available and usable for a confident fit, nonetheless.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 14.0,
#     'submissionTime': '2024-10-29T01:37Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34264/-1',
#     'enlilList': [{'modelCompletionTime': '2024-10-29T01:33Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34265/-1',
#       'impactList': None,
#       'cmeIDs': ['2024-10-28T14:00:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-29T02:53:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-29T02:53Z',
#   'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME visible to the southwest in STEREO A COR2 and SOHO LASCO C3. The imagery it is not available in SOHO LASCO C2 due to an ongoing campaign. The source is likely on the far side.',
#   'submissionTime': '2024-10-29T14:31Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34267/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-29T09:43Z',
#     'latitude': -53.0,
#     'longitude': 125.0,
#     'halfAngle': 11.0,
#     'speed': 517.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'direct',
#     'measurementTechnique': 'StereoCAT',
#     'note': 'Measurement based on triangulation between SOHO LASCO C3 and STEREO A COR2 imagery in SWPC_CAT.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-29T14:41Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34268/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-29T04:30:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-29T04:30Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Narrow CME visible to the SE in SOHO LASCO C2/C3 and STEREO A COR2. The CME is not visible in SOHO LASCO C2 due to a campaign. There are two potential on-disk sources for this CME, including dimming seen around S25E10 in SDO AIA 193 starting at 2024-10-29T01:47Z and a region of dimming centered around N05W00 best seen in SDO AIA 193 starting at 2024-10-29T00:37Z. The eruptions are also visible in STEREO A EUV 195.',
#   'submissionTime': '2024-10-29T15:31Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34269/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-29T12:07Z',
#     'latitude': -62.0,
#     'longitude': -20.0,
#     'halfAngle': 10.0,
#     'speed': 344.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'direct',
#     'measurementTechnique': 'StereoCAT',
#     'note': 'Triangulation based on the SOHO LASCO C3 and STEREO A COR2 white light imagery in StereoCAT.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-29T15:32Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34270/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-29T06:30:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-29T06:30Z',
#   'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Narrow CME visible to the SW in SOHO LASCO C3 and STEREO A COR2. Not visible in SOHO LASCO C2 due to an ongoing campaign. The potential source is an eruption best seen in SDO AIA 171 starting at 2024-10-29T05:57Z, not clearly seen from STEREO A EUV imagery.',
#   'submissionTime': '2024-10-29T18:26Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34274/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-29T15:52Z',
#     'latitude': -48.0,
#     'longitude': 95.0,
#     'halfAngle': 10.0,
#     'speed': 314.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'StereoCAT',
#     'note': 'StereoCAT measurement based on triangulation between STEREO A COR2 and SOHO LASCO C3 white light imagery.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-29T18:27Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34275/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-29T06:53:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-29T06:53Z',
#   'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Narrow CME visible to the SE in SOHO LASCO C3 and STEREO A COR2. The CME is not visible in SOHO LASCO C2 due to a campaign There are two potential on-disk sources for this CME, including dimming seen around S25E10 in SDO AIA 193 starting at 2024-10-29T01:47Z and a region of dimming centered around N05W00 best seen in SDO AIA 193 starting at 2024-10-29T00:37Z. The eruptions are also visible in STEREO A EUV 195.',
#   'submissionTime': '2024-10-29T15:53Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34271/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-29T15:38Z',
#     'latitude': -57.0,
#     'longitude': -23.0,
#     'halfAngle': 10.0,
#     'speed': 435.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'direct',
#     'measurementTechnique': 'StereoCAT',
#     'note': 'Measurement based on triangulation between SOHO LASCO C3 and STEREO A COR2 white light imagery in StereoCAT.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-29T15:57Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34272/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-29T13:23:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-29T13:23Z',
#   'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'This event is visible for one frame in STEREO A COR2 imagery to the southwest, prior to a data gap from 2024-10-29T13:23Z to 23:23Z. In SOHO LASCO C3 this event is visible as a partial halo directed towards the southwest, but the CME is only observable for a few frames before it exits the field of view. The source is a large filament eruption spanning about S37W25 to S15W90, likely extending beyond the western limb, which begins to erupt around 2024-10-29T12:40Z as seen in SDO AIA 131, 171, 193, 304 imagery. Dimming is visible around the eruption site in SDO AIA 193 around 14:15Z, and post eruptive arcades begin to form around 17:15Z in SDO AIA 171 and 193 imagery.',
#   'submissionTime': '2024-10-30T00:02Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34277/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-29T18:13Z',
#     'latitude': -31.0,
#     'longitude': 46.0,
#     'halfAngle': 47.0,
#     'speed': 922.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'BULK MEASUREMENT based on the approximate source location. This measurement relies on only a few frames of SOHO LASCO C3 imagery, for which the CME is near the end of the SOHO LASCO C3 field of view. Multiple measurements resulted in longitudes spanning 41 to 54 degrees and speeds ranging from 800 to 1054 km/s. This measurement is speculative due to the limited image availability at the time of this event.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 33.4,
#     'submissionTime': '2024-10-30T02:53Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34278/-1',
#     'enlilList': [{'modelCompletionTime': '2024-10-30T18:31Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': '2024-11-01T10:00Z',
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': 3,
#       'kp_135': 4,
#       'kp_180': 4,
#       'isEarthGB': True,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34300/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Mars',
#         'arrivalTime': '2024-11-01T22:39Z'},
#        {'isGlancingBlow': False,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-10-31T17:15Z'},
#        {'isGlancingBlow': True,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-10-31T18:00Z'}],
#       'cmeIDs': ['2024-10-29T13:23:00-CME-001']},
#      {'modelCompletionTime': '2024-10-30T18:52Z',
#       'au': 5.5,
#       'estimatedShockArrivalTime': '2024-11-01T10:00Z',
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': 3,
#       'kp_135': 4,
#       'kp_180': 4,
#       'isEarthGB': True,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34304/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Mars',
#         'arrivalTime': '2024-11-01T22:19Z'},
#        {'isGlancingBlow': False,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-10-31T16:58Z'},
#        {'isGlancingBlow': True,
#         'location': 'Juno',
#         'arrivalTime': '2024-11-11T06:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-10-31T18:00Z'}],
#       'cmeIDs': ['2024-10-29T13:23:00-CME-001']}]},
#    {'isMostAccurate': True,
#     'time21_5': '2024-10-29T18:13Z',
#     'latitude': -21.0,
#     'longitude': 33.0,
#     'halfAngle': 52.0,
#     'speed': 1047.0,
#     'type': 'O',
#     'featureCode': 'SH',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'SHOCK measurement based on the approximate source location tracking the faint, wider feature surrounding the bulk portion of this CME. This measurement is preliminary due to limited coronagraph imagery and the measured parameters may vary.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 32.7,
#     'submissionTime': '2024-10-30T02:53Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34286/-1',
#     'enlilList': [{'modelCompletionTime': '2024-10-30T20:26Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': '2024-10-31T19:19Z',
#       'estimatedDuration': 33.5,
#       'rmin_re': 5.8,
#       'kp_18': None,
#       'kp_90': 5,
#       'kp_135': 6,
#       'kp_180': 7,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34307/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Lucy',
#         'arrivalTime': '2024-10-31T21:50Z'},
#        {'isGlancingBlow': False,
#         'location': 'Mars',
#         'arrivalTime': '2024-11-01T14:31Z'},
#        {'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-10-31T03:59Z'},
#        {'isGlancingBlow': False,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-10-31T10:50Z'}],
#       'cmeIDs': ['2024-10-29T13:23:00-CME-001']},
#      {'modelCompletionTime': '2024-10-30T20:48Z',
#       'au': 5.5,
#       'estimatedShockArrivalTime': '2024-10-31T19:10Z',
#       'estimatedDuration': 33.0,
#       'rmin_re': 5.8,
#       'kp_18': None,
#       'kp_90': 5,
#       'kp_135': 6,
#       'kp_180': 7,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34310/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'Lucy',
#         'arrivalTime': '2024-10-31T21:50Z'},
#        {'isGlancingBlow': False,
#         'location': 'Mars',
#         'arrivalTime': '2024-11-01T14:13Z'},
#        {'isGlancingBlow': False,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-10-31T03:53Z'},
#        {'isGlancingBlow': False,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-10-31T10:36Z'},
#        {'isGlancingBlow': True,
#         'location': 'Juno',
#         'arrivalTime': '2024-11-11T00:00Z'}],
#       'cmeIDs': ['2024-10-29T13:23:00-CME-001']}]}],
#   'linkedEvents': [{'activityID': '2024-10-31T19:28:00-IPS-001'},
#    {'activityID': '2024-11-01T00:02:00-IPS-001'}]},
#  {'activityID': '2024-10-29T19:56:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-29T19:56Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'This CME is visible to the southwest in SOHO LASCO C2/C3 imagery prior to a data gap starting at 2024-10-29T20:42Z. The source is likely far-sided as there are no source signatures on the Earth-facing disk around the time of this event.',
#   'submissionTime': '2024-10-30T02:35Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34284/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-30T00:05Z',
#     'latitude': -40.0,
#     'longitude': None,
#     'halfAngle': 10.0,
#     'speed': 729.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'A plane-of-sky measurement was made using a longitude of 90 degrees due to the far-sided and therefore unknown source location.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 7.9,
#     'submissionTime': '2024-10-30T02:37Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34285/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-29T23:23:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-29T23:23Z',
#   'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'UPDATE: This CME has an updated start time of 2024-10-29T21:48Z as seen in backfilled SOHO LASCO C2 imagery. This CME is visible to the southwest in SOHO LASCO C2/C3 and STEREO A COR2 imagery after a data gap lasting from 2024-10-29T13:23Z to 23:23Z. At the time of this event there was a data gap in SOHO LASCO C2/C3 imagery from 20:42Z to 23:54Z, which has since backfilled. The source is likely far-sided as there are no source signatures on the Earth-facing disk around the time of this event.',
#   'submissionTime': '2024-11-10T20:53Z',
#   'versionId': 2,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34280/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-30T03:54Z',
#     'latitude': -48.0,
#     'longitude': 116.0,
#     'halfAngle': 11.0,
#     'speed': 508.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on the best fit between SOHO LASCO C3 and STEREO A COR2 imagery.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 13.6,
#     'submissionTime': '2024-10-30T02:25Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34281/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-29T23:53:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-29T23:53Z',
#   'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'This CME is visible to the south in STEREO A COR2 and in SOHO LASCO C3 imagery after a data gap lasting from 20:42Z to 23:54Z. The source is likely far-sided as there are no source signatures on the Earth-facing disk around the time of this event.',
#   'submissionTime': '2024-10-30T02:29Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34282/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-30T05:58Z',
#     'latitude': -71.0,
#     'longitude': 20.0,
#     'halfAngle': 19.0,
#     'speed': 560.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on the best fit between SOHO LASCO C2/C3 and STEREO A COR2 imagery.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 38.0,
#     'submissionTime': '2024-10-30T02:31Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34283/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-30T02:00:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-30T02:00Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME first seen to the SW in SOHO LASCO C2 starting at 2024-10-30T02:00Z. Also seen to the SW in SOHO LASCO C3 and STEREO A COR2. The source of this CME is likely beyond the SW limb as there is no definitive source on the Earth-facing disk.',
#   'submissionTime': '2024-10-30T17:44Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34288/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-30T08:34Z',
#     'latitude': -50.0,
#     'longitude': 109.0,
#     'halfAngle': 23.0,
#     'speed': 550.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement made with running difference imagery from SOHO LASCO C2/C3 and STEREO A COR2 using SWPC_CAT.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-30T17:46Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34289/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-30T04:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-30T04:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME first seen to the SSW in SOHO LASCO C2 starting at 2024-10-30T04:12Z. Also seen to the SSW in SOHO LASCO C3 and STEREO A COR2. The source of this CME is likely an area of broad and slow moving field lines on the SSW limb in GOES SUVI 284 starting as early as 2024-10-30T02:30Z, but with a more defined rising loop seen at 2024-10-30T03:25Z. There is also a localized area of dimming best seen in SDO AIA 193 in the SW quadrant of the Earth-facing disk starting about 2024-10-30T03:28Z. It is difficult to distinguish the sources of CME: 2024-10-30T04:12Z and the slower moving CME: 2024-10-30T05:00Z that is slightly farther to the S.',
#   'submissionTime': '2024-10-30T18:01Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34290/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-30T08:25Z',
#     'latitude': -60.0,
#     'longitude': 29.0,
#     'halfAngle': 27.0,
#     'speed': 950.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement made with running difference imagery from SOHO LASCO C2/C3 and STEREO A COR2 using SWPC_CAT.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-30T18:02Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34291/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-30T05:00:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-30T05:00Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME first seen to the S in SOHO LASCO C2 starting at 2024-10-30T05:00Z. Also seen to the S in SOHO LASCO C3 and STEREO A COR2. The source of this CME is likely an area of broad and slow moving field lines on the SSW limb in GOES SUVI 284 starting as early as 2024-10-30T02:30Z, but with a more defined rising loop seen at 2024-10-30T03:25Z. There is also a localized area of dimming best seen in SDO AIA 193 in the SW quadrant of the Earth-facing disk starting about 2024-10-30T03:28Z. It is difficult to distinguish the sources of CME: 2024-10-30T05:00Z and the faster moving CME: 2024-10-30T04:12Z that is slightly farther to the SSW.',
#   'submissionTime': '2024-10-30T18:08Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34292/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-30T13:53Z',
#     'latitude': -56.0,
#     'longitude': -1.0,
#     'halfAngle': 28.0,
#     'speed': 412.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement made with running difference imagery from SOHO LASCO C2/C3 and STEREO A COR2 using SWPC_CAT.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-30T18:09Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34293/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-30T05:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-30T05:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME first seen to the SW in SOHO LASCO C2 starting at 2024-10-30T05:12Z. Also seen to the SW in SOHO LASCO C3 and STEREO A COR2. The source of this CME is likely beyond the SW limb as there is no definitive source on the Earth-facing disk. This CME can be seen in white light imagery from SOHO LASCO C3 but is difficult to distinguish in running difference imagery.',
#   'submissionTime': '2024-10-30T18:25Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34294/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-30T13:45Z',
#     'latitude': -54.0,
#     'longitude': 109.0,
#     'halfAngle': 12.0,
#     'speed': 397.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement made with running difference imagery from SOHO LASCO C2 and STEREO A COR2.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-30T18:26Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34295/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-30T07:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-30T07:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME first seen to the SW in SOHO LASCO C2 starting at 2024-10-30T07:48Z. Also seen to the SW in SOHO LASCO C3. The source of this CME is likely beyond the SW limb as there is no definitive source on the Earth-facing disk.',
#   'submissionTime': '2024-10-30T18:43Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34296/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-30T16:49Z',
#     'latitude': -47.0,
#     'longitude': None,
#     'halfAngle': 10.0,
#     'speed': 394.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'Plane-of-sky measurement made with running difference imagery from SOHO LASCO C2/C3 using SWPC_CAT.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-30T18:45Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34297/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-30T09:24:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-30T09:24Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME first seen to the SW in SOHO LASCO C2 starting at 2024-10-30T09:24Z. Also seen to the SW in SOHO LASCO C3 and STEREO A COR2. The source of this CME is likely beyond the SW limb as there is no definitive source on the Earth-facing disk.',
#   'submissionTime': '2024-10-30T19:00Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34298/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-30T17:26Z',
#     'latitude': -41.0,
#     'longitude': 126.0,
#     'halfAngle': 10.0,
#     'speed': 450.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement made with running difference imagery from SOHO LASCO C2/C3 and STEREO A COR2 using SWPC_CAT.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-30T19:01Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34299/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-30T11:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-30T11:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME first seen to the SW in SOHO LASCO C2 starting at 2024-10-30T11:48Z. Also seen to the SW in SOHO LASCO C3 and STEREO A COR2. The source of this CME is likely beyond the SW limb as there is no definitive source on the Earth-facing disk.',
#   'submissionTime': '2024-10-30T19:25Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34301/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-30T21:26Z',
#     'latitude': -38.0,
#     'longitude': 139.0,
#     'halfAngle': 10.0,
#     'speed': 354.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement made with running difference imagery from SOHO LASCO C2/C3 and STEREO A COR2 using SWPC_CAT.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-10-30T19:27Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34302/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-30T15:53:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-30T15:53Z',
#   'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'This CME is visible to the southwest in STEREO A COR2 imagery. It is not seen in SOHO LASCO C2/C3 imagery due to a data gap lasting from 2024-10-30T14:24Z to 20:12Z. The source is likely far-sided and may be related to faint field line movement visible beyond the southwest limb in SDO AIA 171 and 193 imagery starting around 2024-10-30T15:00Z.',
#   'submissionTime': '2024-10-31T00:34Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34320/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-30T23:44Z',
#     'latitude': -32.0,
#     'longitude': None,
#     'halfAngle': 10.0,
#     'speed': 386.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'A plane-of-sky measurement was made using a longitude of 117 degrees due to the far-sided and therefore unknown source location.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 10.8,
#     'submissionTime': '2024-10-31T00:35Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34321/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-10-30T16:38:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-10-30T16:38Z',
#   'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'This CME is visible to the west in STEREO A COR2 imagery. It is not seen in SOHO LASCO C2/C3 imagery due to a data gap lasting from 2024-10-30T14:24Z to 20:12Z. The source is likely far-sided as there are no related source signatures visible on the Earth-facing disk at the time of this event.',
#   'submissionTime': '2024-10-31T00:30Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34318/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-10-31T02:21Z',
#     'latitude': -5.0,
# ...
#   'submissionTime': '2024-11-23T19:11Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35276/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-11-24T01:39Z',
#     'latitude': -33.0,
#     'longitude': -59.0,
#     'halfAngle': 14.0,
#     'speed': 283.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on the best fit between SOHO LASCO C2 and STEREO A COR2 in SWPC_CAT as well as the potential source location. The CME was blocked by the pylon and not measurable in SOHO LASCO C3.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 7.5,
#     'submissionTime': '2024-11-23T19:13Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35277/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-11-23T19:24:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-11-23T19:24Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': 'S19W68',
#   'activeRegionNum': None,
#   'note': 'Faint CME seen to the SW in SOHO LASCO C2 and C3. This CME is not visible in STEREO A COR2 imagery due to a data gap. The source appears to be an eruption from AR13898/plage region 13893 in the SW based on SDO/AIA 131 and 193 starting around 2024-11-23T19:20Z. There are also moving/opening field lines visible along the limb in GOES SUVI 284 which may be associated with the eruption on the disk but could also indicate a far sided simultaneous eruption which could play into overlapping fronts seen with this CME to the SW.',
#   'submissionTime': '2024-11-24T02:41Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35281/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-11-24T00:00Z',
#     'latitude': -37.0,
#     'longitude': 68.0,
#     'halfAngle': 28.0,
#     'speed': 764.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Parameters based on potential source location and best fit in SOHO LASCO C3 imagery.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': 14.6,
#     'submissionTime': '2024-11-24T02:43Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35282/-1',
#     'enlilList': [{'modelCompletionTime': '2024-11-24T02:52Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/35284/-1',
#       'impactList': None,
#       'cmeIDs': ['2024-11-23T19:24:00-CME-001']}]}],
#   'linkedEvents': [{'activityID': '2024-11-23T19:01:00-FLR-001'}]},
#  {'activityID': '2024-11-24T10:24:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-11-24T10:24Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Narrow CME first seen in the SE by SOHO LASCO C2 beginning at 2024-11-24T10:24Z, as well as by SOHO LASCO C3 and STEREO A COR2 in later frames. There is no distinct source for this CME, however a large amount of field line movement, brightening and general activity is visible in the vicinity of ARs 3905 (S09E48) and 3906 (S16E54) as seen in SDO AIA 131, 171, 193 and 211.',
#   'submissionTime': '2024-11-24T18:06Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35285/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-11-24T21:52Z',
#     'latitude': -6.0,
#     'longitude': -65.0,
#     'halfAngle': 13.0,
#     'speed': 311.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on approximate source location and best fit between SOHO LASCO C2/C3 and STEREO A COR2.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-11-24T18:08Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35286/-1',
#     'enlilList': [{'modelCompletionTime': '2024-11-24T18:20Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/35287/-1',
#       'impactList': [{'isGlancingBlow': False,
#         'location': 'BepiColombo',
#         'arrivalTime': '2024-11-25T20:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Parker Solar Probe',
#         'arrivalTime': '2024-11-27T08:00Z'}],
#       'cmeIDs': ['2024-11-24T10:24:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-11-24T16:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-11-24T16:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': 'N15E75',
#   'activeRegionNum': None,
#   'note': 'CME first seen in the NE by SOHO LASCO C2 beginning at 2024-11-24T16:12Z, as well as by SOHO LASCO C3 in later frames. This event is not reliably visible in STEREO A COR2 imagery. The source of this CME is a minor eruption and brightening centered at approx. N15E75 as seen in SDO AIA 171, 193 and 211.',
#   'submissionTime': '2024-11-24T20:15Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35288/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-11-25T03:42Z',
#     'latitude': 10.0,
#     'longitude': -75.0,
#     'halfAngle': 15.0,
#     'speed': 317.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on approximate source location and best fit in SOHO LASCO C2/C3',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-11-24T20:18Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35289/-1',
#     'enlilList': [{'modelCompletionTime': '2024-11-24T20:30Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': None,
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': None,
#       'kp_135': None,
#       'kp_180': None,
#       'isEarthGB': False,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/35291/-1',
#       'impactList': [{'isGlancingBlow': True,
#         'location': 'BepiColombo',
#         'arrivalTime': '2024-11-25T22:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Parker Solar Probe',
#         'arrivalTime': '2024-11-27T12:00Z'}],
#       'cmeIDs': ['2024-11-24T16:12:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-11-25T00:24:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-11-25T00:24Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'Narrow, jet-like CME first visible to the E in SOHO LASCO C2 starting at 2024-11-25T00:24Z. Also visible to the E in SOHO LASCO C3 but is not visible in STEREO A COR2. There appears to be some northward deflection starting a couple frames into the propagation. There is not a definitive source for this CME. One possibility is some brightening and activity just to the NW of AR 3905 best seen in SDO AIA 193 starting at 00:08Z. This coronal signature is likely too late to be the source. Another more likely source possibility is some faint field line movement on the ESE limb best seen in SDO AIA 171 starting at 2024-11-24T23:21Z.',
#   'submissionTime': '2024-11-25T18:23Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35311/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-11-25T11:18Z',
#     'latitude': 2.0,
#     'longitude': None,
#     'halfAngle': 10.0,
#     'speed': 332.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'Plane-of-sky',
#     'note': 'Plane-of-sky measurement made using SWPC_CAT based on running difference imagery from SOHO LASCO C2/C3.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-11-25T18:24Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35312/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-11-25T01:48:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-11-25T01:48Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME first seen to the NNE in SOHO LASCO C2 starting at 2024-11-25T01:48Z. CME also seen to the NNE in SOHO LASCO C3 and STEREO A COR2. This CME is very faint in white light and is better seen in running difference imagery. The source of this CME is possibly some minor brightening and movement of plasma centered around N20E25 starting around 2024-11-25T00:27Z with some northward deflection.',
#   'submissionTime': '2024-11-25T19:12Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35313/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-11-25T07:13Z',
#     'latitude': 35.0,
#     'longitude': -17.0,
#     'halfAngle': 15.0,
#     'speed': 619.0,
#     'type': 'C',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on the best fit between SOHO LASCO C2/C3 and STEREO A COR2 in SWPC_CAT as well as potential source location.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-11-25T19:13Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35314/-1',
#     'enlilList': None}],
#   'linkedEvents': None},
#  {'activityID': '2024-11-25T03:12:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-11-25T03:12Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME first seen to the SSE in SOHO LASCO C2 starting at 2024-11-25T03:12Z. CME also seen to the SSE in SOHO LASCO C3 and STEREO A COR2. The source of this CME is likely a small filament eruption centered around S40-45E28 that is visible in SDO AIA 304 and SDO AIA 193 starting about 2024-11-25T01:30Z.',
#   'submissionTime': '2024-11-25T13:58Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35303/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-11-25T12:37Z',
#     'latitude': -42.0,
#     'longitude': -31.0,
#     'halfAngle': 31.0,
#     'speed': 382.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on the best fit between SOHO LASCO C2/C3 and STEREO A COR2 in SWPC_CAT as well as potential source location.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-11-25T14:00Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35304/-1',
#     'enlilList': [{'modelCompletionTime': '2024-11-25T15:38Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': '2024-11-28T20:00Z',
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': 2,
#       'kp_135': 3,
#       'kp_180': 4,
#       'isEarthGB': True,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/35308/-1',
#       'impactList': [{'isGlancingBlow': True,
#         'location': 'BepiColombo',
#         'arrivalTime': '2024-11-26T10:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Europa Clipper',
#         'arrivalTime': '2024-11-29T00:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Juice',
#         'arrivalTime': '2024-11-27T20:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Lucy',
#         'arrivalTime': '2024-11-28T16:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-11-28T18:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-11-29T02:00Z'}],
#       'cmeIDs': ['2024-11-25T03:12:00-CME-001',
#        '2024-11-25T04:00:00-CME-001']}]}],
#   'linkedEvents': None},
#  {'activityID': '2024-11-25T04:00:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2024-11-25T04:00Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'note': 'CME first visible to the SSE in SOHO LASCO C2 starting at 2024-11-25T04:00Z. Also visible to the SSE in SOHO LASCO C3 and STEREO A COR2. This CME closely follows CME: 2024-11-25T03:12Z but is slightly slower and slightly wider and is clearly distinguishable in running difference imagery. There is not a clearly definitive source for this CME, but a possible candidate is a deflected source associated with an M1.1 flare from AR 3906 (S13E46) that peaked at 2024-11-25T01:59Z.',
#   'submissionTime': '2024-11-25T14:06Z',
#   'versionId': 1,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35305/-1',
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2024-11-25T14:50Z',
#     'latitude': -33.0,
#     'longitude': -16.0,
#     'halfAngle': 33.0,
#     'speed': 315.0,
#     'type': 'S',
#     'featureCode': 'LE',
#     'imageType': 'running difference',
#     'measurementTechnique': 'SWPC_CAT',
#     'note': 'Measurement based on the best fit between SOHO LASCO C2/C3 and STEREO A COR2 in SWPC_CAT.',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
#     'submissionTime': '2024-11-25T14:07Z',
#     'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35306/-1',
#     'enlilList': [{'modelCompletionTime': '2024-11-25T15:38Z',
#       'au': 2.0,
#       'estimatedShockArrivalTime': '2024-11-28T20:00Z',
#       'estimatedDuration': None,
#       'rmin_re': None,
#       'kp_18': None,
#       'kp_90': 2,
#       'kp_135': 3,
#       'kp_180': 4,
#       'isEarthGB': True,
#       'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/35308/-1',
#       'impactList': [{'isGlancingBlow': True,
#         'location': 'BepiColombo',
#         'arrivalTime': '2024-11-26T10:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Europa Clipper',
#         'arrivalTime': '2024-11-29T00:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Juice',
#         'arrivalTime': '2024-11-27T20:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Lucy',
#         'arrivalTime': '2024-11-28T16:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'Solar Orbiter',
#         'arrivalTime': '2024-11-28T18:00Z'},
#        {'isGlancingBlow': True,
#         'location': 'STEREO A',
#         'arrivalTime': '2024-11-29T02:00Z'}],
#       'cmeIDs': ['2024-11-25T03:12:00-CME-001',
#        '2024-11-25T04:00:00-CME-001']}]}],
#   'linkedEvents': None}]

# %%
# Preview the first result in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(cme_json, indent=4))
# Out:
# [
#     {
#         "activityID": "2024-10-26T06:48:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-26T06:48Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S16E60",
#         "activeRegionNum": 13873,
#         "note": "This CME is visible as a partial halo directed towards the southeast in SOHO LASCO C2/C3 and STEREO A COR2 imagery. The source is an eruption which is associated with an M9.5 flare from Active Region 13873 (S14E56) and X1.8 flare from Active Region 13873 (S16E60) starting around 2024-10-26T06:30Z as seen in SDO AIA 131, 171, 193, 304 imagery. A wide opening of field lines is visible over the southeast limb in SDO AIA 171 and 193, with post eruptive arcades visible in SDO AIA 131, 171, 193, 304 starting around 07:50Z.",
#         "submissionTime": "2024-10-30T14:51Z",
#         "versionId": 3,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34212/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-26T09:04Z",
#                 "latitude": -32.0,
#                 "longitude": -54.0,
#                 "halfAngle": 53.0,
#                 "speed": 1523.0,
#                 "type": "O",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement of the bulk portion based on the approximate source location and best fit between SOHO LASCO C2/C3 and STEREO A COR2 imagery. This event is wide and difficult to fit between coronagraphs, with measured longitudes ranging from -41 to -66.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 21.5,
#                 "submissionTime": "2024-10-26T17:58Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34213/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-10-26T15:54Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2024-10-28T04:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 5,
#                         "kp_135": 7,
#                         "kp_180": 7,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34216/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-10-27T18:03Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-10-27T07:24Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-10-27T06:53Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-10-28T00:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-10-28T18:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-10-26T06:48:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2024-10-26T16:17Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": "2024-10-28T04:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 5,
#                         "kp_135": 7,
#                         "kp_180": 7,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34217/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-10-27T18:07Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-10-27T07:03Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-10-27T06:58Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-10-28T00:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-10-28T18:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-10-26T06:48:00-CME-001"
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-26T08:52Z",
#                 "latitude": -19.0,
#                 "longitude": -34.0,
#                 "halfAngle": 54.0,
#                 "speed": 1677.0,
#                 "type": "O",
#                 "featureCode": "SH",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "SHOCK MEASUREMENT based on the best fit between SOHO LASCO C2/C3 and STEREO A COR2 imagery tracking the wider, faint front which precedes the bulk of this CME. This measurement does not capture the entire shock feature observed in both coronagraphs, and instead follows the leading edge of the shock best, missing the widest portions of the partial halo.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 14.6,
#                 "submissionTime": "2024-10-26T17:58Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34221/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-10-26T18:18Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2024-10-27T15:51Z",
#                         "estimatedDuration": 19.1,
#                         "rmin_re": 4.9,
#                         "kp_18": null,
#                         "kp_90": 8,
#                         "kp_135": 9,
#                         "kp_180": 9,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34225/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-10-27T10:53Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-10-27T07:21Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-10-27T01:14Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-10-28T02:03Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-10-28T15:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-10-26T06:48:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2024-10-26T18:41Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": "2024-10-27T15:45Z",
#                         "estimatedDuration": 18.3,
#                         "rmin_re": 4.9,
#                         "kp_18": null,
#                         "kp_90": 8,
#                         "kp_135": 9,
#                         "kp_180": 9,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34226/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-10-27T10:52Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-10-27T07:07Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-10-27T01:07Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-10-28T02:22Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-10-28T15:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-10-26T06:48:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-10-26T05:57:00-FLR-001"
#             },
#             {
#                 "activityID": "2024-10-26T06:32:00-FLR-001"
#             },
#             {
#                 "activityID": "2024-10-26T16:45:00-SEP-001"
#             },
#             {
#                 "activityID": "2024-10-26T18:05:00-SEP-001"
#             },
#             {
#                 "activityID": "2024-10-26T18:57:00-SEP-001"
#             },
#             {
#                 "activityID": "2024-10-26T19:02:00-SEP-001"
#             },
#             {
#                 "activityID": "2024-10-26T19:50:00-SEP-001"
#             },
#             {
#                 "activityID": "2024-10-26T20:06:00-SEP-001"
#             },
#             {
#                 "activityID": "2024-10-26T21:43:00-SEP-001"
#             },
#             {
#                 "activityID": "2024-10-28T04:13:00-IPS-001"
#             },
#             {
#                 "activityID": "2024-10-28T08:57:00-SEP-001"
#             },
#             {
#                 "activityID": "2024-10-28T16:58:00-IPS-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-10-26T08:09:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-26T08:09Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S35E60",
#         "activeRegionNum": null,
#         "note": "Loop CME seen to the south-southeast in the outflow of the halo CME 2024-10-26T06:48Z. May be associated with a secondary eruption or outflow near S35E60.",
#         "submissionTime": "2024-10-26T19:33Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34228/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-26T15:33Z",
#                 "latitude": -63.0,
#                 "longitude": -85.0,
#                 "halfAngle": 19.0,
#                 "speed": 506.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Leading edge measurement using two spacecraft showing southward deflection of the eruption.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 9.0,
#                 "submissionTime": "2024-10-26T19:40Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34230/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-26T08:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-26T08:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Narrow yet bright CME seen best in SOHO C2 nearly due west along the outflow of several more minor CMEs to the southwest. Likely associated with eruptive activity just behind the western limb as evidenced by opening field lines seen in GOES SUVI 284 around 2024-10-26T07:45Z.",
#         "submissionTime": "2024-10-26T20:25Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34235/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-26T23:40Z",
#                 "latitude": -1.0,
#                 "longitude": 93.0,
#                 "halfAngle": 15.0,
#                 "speed": 225.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Triangulation accomplished using two spacecraft leading edge measurement.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 6.0,
#                 "submissionTime": "2024-10-26T20:27Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34236/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-26T12:23:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-26T12:23Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Faint CME/outflow in the wake of the earlier significant 2024-10-26T06:48Z CME. Its source is not clear but there is some movement in the filament eruption in the SE preceding this time.",
#         "submissionTime": "2024-10-27T16:53Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34243/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-26T17:12Z",
#                 "latitude": -62.0,
#                 "longitude": -31.0,
#                 "halfAngle": 28.0,
#                 "speed": 684.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Very approximate analysis based on the fit with two coronagraphs.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-10-27T16:54Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34244/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-26T17:38:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-26T17:38Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Jet CME seen to the south-southeast in STEREO A COR2. Unclear source. May potentially be associated with eruptive activity from the southeast, including the recently eruptive Active Region 3872 with strong southward deflection. No SOHO imagery is available to corroborate a potential longitude due to comet observing.",
#         "submissionTime": "2024-10-27T00:31Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34237/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-27T00:09Z",
#                 "latitude": -70.0,
#                 "longitude": null,
#                 "halfAngle": 10.0,
#                 "speed": 448.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "Plane-of-sky",
#                 "note": "STEREO A plane of sky measurement (-62.7 degrees longitude).",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 8.0,
#                 "submissionTime": "2024-10-27T00:32Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34238/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-27T15:53:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-27T15:53Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "This CME is visible to the NE in SOHO LASCO C3 and STEREO A COR2 imagery. SOHO LASCO C2 imagery is not available for this event due to an on-going comet campaign. The sources is best seen in SDO/AIA 171 as fast moving/opening field lines far behind the NE limb.",
#         "submissionTime": "2024-10-27T21:53Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34245/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-27T20:10Z",
#                 "latitude": 30.0,
#                 "longitude": -122.0,
#                 "halfAngle": 43.0,
#                 "speed": 625.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Parameters based on best fit in SOHO LASCO C3 and STEREO A COR2 imagery. Limited STEREO A frames available for this event.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 17.5,
#                 "submissionTime": "2024-10-27T21:54Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34246/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-10-27T22:05Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34247/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-10-29T23:23Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-10-29T13:20Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-10-27T15:53:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-28T08:48:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-28T08:48Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "N20E100",
#         "activeRegionNum": null,
#         "note": "Bright lightbulb CME first seen in the NE by SOHO LASCO C2 beginning at 2024-10-28T08:48Z, as well as by STEREO A COR2 in later frames. This CME is currently not visible in SOHO LASCO C3 due to a data gap that began at 2024-10-28T02:30Z. The source of this event is a large filament eruption seen along the NE limb (centered at approx. N20E100) in SDO AIA , GOES SUVI and STEREO A EUVI 304. Opening field lines are also visible in SDO AIA 171, 193, 211, and GOES SUVI 284.",
#         "submissionTime": "2024-10-28T15:53Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34257/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-28T15:52Z",
#                 "latitude": 24.0,
#                 "longitude": -110.0,
#                 "halfAngle": 37.0,
#                 "speed": 568.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on approximate source location and best fit between SOHO LASCO C2 and STEREO A COR2.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-10-28T15:54Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34258/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-10-28T16:05Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34259/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-10-30T21:57Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-10-30T08:13Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-10-28T08:48:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-28T14:00:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-28T14:00Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Bright CME first seen in the SW by SOHO LASCO C2 beginning at 2024-10-28T14:00Z, as well as by STEREO A COR2 in later frames. This CME is observed in SOHO LASCO C3 white light imagery, but running difference image quality at this time does not capture the front. The source of this event is a far sided eruption seen along the SW limb. Wide opening field lines can be seen in SDO AIA 171, 193, 211, GOES SUVI 284, and STEREO A EUVI 195. Post eruptive arcades are also visible in SDO AIA 211 and STEREO A EUVI 195.",
#         "submissionTime": "2024-10-29T01:34Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34263/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-28T18:58Z",
#                 "latitude": -54.0,
#                 "longitude": 95.0,
#                 "halfAngle": 43.0,
#                 "speed": 755.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Triangulated measurement between SOHO LASCO C2/STEREO COR2A, and the observed source just beyond the SW limb in SDO AIA imagery. SOHO LASCO is currently in a comet observation campaign affecting imagery, notably LASCO C3 running difference which does not observe the front at all while it can be seen in C3 white light. Enough C2 and COR2A imagery is available and usable for a confident fit, nonetheless.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 14.0,
#                 "submissionTime": "2024-10-29T01:37Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34264/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-10-29T01:33Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34265/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2024-10-28T14:00:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-29T02:53:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-29T02:53Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "CME visible to the southwest in STEREO A COR2 and SOHO LASCO C3. The imagery it is not available in SOHO LASCO C2 due to an ongoing campaign. The source is likely on the far side.",
#         "submissionTime": "2024-10-29T14:31Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34267/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-29T09:43Z",
#                 "latitude": -53.0,
#                 "longitude": 125.0,
#                 "halfAngle": 11.0,
#                 "speed": 517.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "direct",
#                 "measurementTechnique": "StereoCAT",
#                 "note": "Measurement based on triangulation between SOHO LASCO C3 and STEREO A COR2 imagery in SWPC_CAT.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-10-29T14:41Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34268/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-29T04:30:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-29T04:30Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Narrow CME visible to the SE in SOHO LASCO C2/C3 and STEREO A COR2. The CME is not visible in SOHO LASCO C2 due to a campaign. There are two potential on-disk sources for this CME, including dimming seen around S25E10 in SDO AIA 193 starting at 2024-10-29T01:47Z and a region of dimming centered around N05W00 best seen in SDO AIA 193 starting at 2024-10-29T00:37Z. The eruptions are also visible in STEREO A EUV 195.",
#         "submissionTime": "2024-10-29T15:31Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34269/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-29T12:07Z",
#                 "latitude": -62.0,
#                 "longitude": -20.0,
#                 "halfAngle": 10.0,
#                 "speed": 344.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "direct",
#                 "measurementTechnique": "StereoCAT",
#                 "note": "Triangulation based on the SOHO LASCO C3 and STEREO A COR2 white light imagery in StereoCAT.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-10-29T15:32Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34270/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-29T06:30:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-29T06:30Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Narrow CME visible to the SW in SOHO LASCO C3 and STEREO A COR2. Not visible in SOHO LASCO C2 due to an ongoing campaign. The potential source is an eruption best seen in SDO AIA 171 starting at 2024-10-29T05:57Z, not clearly seen from STEREO A EUV imagery.",
#         "submissionTime": "2024-10-29T18:26Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34274/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-29T15:52Z",
#                 "latitude": -48.0,
#                 "longitude": 95.0,
#                 "halfAngle": 10.0,
#                 "speed": 314.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "StereoCAT",
#                 "note": "StereoCAT measurement based on triangulation between STEREO A COR2 and SOHO LASCO C3 white light imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-10-29T18:27Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34275/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-29T06:53:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-29T06:53Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Narrow CME visible to the SE in SOHO LASCO C3 and STEREO A COR2. The CME is not visible in SOHO LASCO C2 due to a campaign There are two potential on-disk sources for this CME, including dimming seen around S25E10 in SDO AIA 193 starting at 2024-10-29T01:47Z and a region of dimming centered around N05W00 best seen in SDO AIA 193 starting at 2024-10-29T00:37Z. The eruptions are also visible in STEREO A EUV 195.",
#         "submissionTime": "2024-10-29T15:53Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34271/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-29T15:38Z",
#                 "latitude": -57.0,
#                 "longitude": -23.0,
#                 "halfAngle": 10.0,
#                 "speed": 435.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "direct",
#                 "measurementTechnique": "StereoCAT",
#                 "note": "Measurement based on triangulation between SOHO LASCO C3 and STEREO A COR2 white light imagery in StereoCAT.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-10-29T15:57Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34272/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-10-29T13:23:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-29T13:23Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "This event is visible for one frame in STEREO A COR2 imagery to the southwest, prior to a data gap from 2024-10-29T13:23Z to 23:23Z. In SOHO LASCO C3 this event is visible as a partial halo directed towards the southwest, but the CME is only observable for a few frames before it exits the field of view. The source is a large filament eruption spanning about S37W25 to S15W90, likely extending beyond the western limb, which begins to erupt around 2024-10-29T12:40Z as seen in SDO AIA 131, 171, 193, 304 imagery. Dimming is visible around the eruption site in SDO AIA 193 around 14:15Z, and post eruptive arcades begin to form around 17:15Z in SDO AIA 171 and 193 imagery.",
#         "submissionTime": "2024-10-30T00:02Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34277/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-29T18:13Z",
#                 "latitude": -31.0,
#                 "longitude": 46.0,
#                 "halfAngle": 47.0,
#                 "speed": 922.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "BULK MEASUREMENT based on the approximate source location. This measurement relies on only a few frames of SOHO LASCO C3 imagery, for which the CME is near the end of the SOHO LASCO C3 field of view. Multiple measurements resulted in longitudes spanning 41 to 54 degrees and speeds ranging from 800 to 1054 km/s. This measurement is speculative due to the limited image availability at the time of this event.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 33.4,
#                 "submissionTime": "2024-10-30T02:53Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34278/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-10-30T18:31Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2024-11-01T10:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 3,
#                         "kp_135": 4,
#                         "kp_180": 4,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34300/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Mars",
#                                 "arrivalTime": "2024-11-01T22:39Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-10-31T17:15Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-10-31T18:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-10-29T13:23:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2024-10-30T18:52Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": "2024-11-01T10:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 3,
#                         "kp_135": 4,
#                         "kp_180": 4,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34304/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Mars",
#                                 "arrivalTime": "2024-11-01T22:19Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-10-31T16:58Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Juno",
#                                 "arrivalTime": "2024-11-11T06:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-10-31T18:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-10-29T13:23:00-CME-001"
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-10-29T18:13Z",
#                 "latitude": -21.0,
#                 "longitude": 33.0,
#                 "halfAngle": 52.0,
#                 "speed": 1047.0,
#                 "type": "O",
#                 "featureCode": "SH",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "SHOCK measurement based on the approximate source location tracking the faint, wider feature surrounding the bulk portion of this CME. This measurement is preliminary due to limited coronagraph imagery and the measured parameters may vary.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 32.7,
#                 "submissionTime": "2024-10-30T02:53Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34286/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-10-30T20:26Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2024-10-31T19:19Z",
#                         "estimatedDuration": 33.5,
#                         "rmin_re": 5.8,
#                         "kp_18": null,
#                         "kp_90": 5,
#                         "kp_135": 6,
#                         "kp_180": 7,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34307/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-10-31T21:50Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Mars",
#                                 "arrivalTime": "2024-11-01T14:31Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-10-31T03:59Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-10-31T10:50Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-10-29T13:23:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2024-10-30T20:48Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": "2024-10-31T19:10Z",
#                         "estimatedDuration": 33.0,
#                         "rmin_re": 5.8,
#                         "kp_18": null,
#                         "kp_90": 5,
#                         "kp_135": 6,
#                         "kp_180": 7,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34310/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-10-31T21:50Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Mars",
#                                 "arrivalTime": "2024-11-01T14:13Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-10-31T03:53Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-10-31T10:36Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Juno",
#                                 "arrivalTime": "2024-11-11T00:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-10-29T13:23:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-10-31T19:28:00-IPS-001"
#             },
#             {
#                 "activityID": "2024-11-01T00:02:00-IPS-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-10-29T19:56:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-10-29T19:56Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "This CME is visible to the southwest in SOHO LASCO C2/C3 imagery prior to a data gap starting at 2024-10-29T20:42Z. The source is likely far-sided as there are no source signatures on the Earth-facing disk around the time of this event.",
#         "submissionTime": "2024-10-30T02:35Z",
#         "versionId": 1,
# ...
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-24T16:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-24T16:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "N15E75",
#         "activeRegionNum": null,
#         "note": "CME first seen in the NE by SOHO LASCO C2 beginning at 2024-11-24T16:12Z, as well as by SOHO LASCO C3 in later frames. This event is not reliably visible in STEREO A COR2 imagery. The source of this CME is a minor eruption and brightening centered at approx. N15E75 as seen in SDO AIA 171, 193 and 211.",
#         "submissionTime": "2024-11-24T20:15Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35288/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-25T03:42Z",
#                 "latitude": 10.0,
#                 "longitude": -75.0,
#                 "halfAngle": 15.0,
#                 "speed": 317.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on approximate source location and best fit in SOHO LASCO C2/C3",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-11-24T20:18Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35289/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-24T20:30Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/35291/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "BepiColombo",
#                                 "arrivalTime": "2024-11-25T22:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-27T12:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-24T16:12:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-25T00:24:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-25T00:24Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Narrow, jet-like CME first visible to the E in SOHO LASCO C2 starting at 2024-11-25T00:24Z. Also visible to the E in SOHO LASCO C3 but is not visible in STEREO A COR2. There appears to be some northward deflection starting a couple frames into the propagation. There is not a definitive source for this CME. One possibility is some brightening and activity just to the NW of AR 3905 best seen in SDO AIA 193 starting at 00:08Z. This coronal signature is likely too late to be the source. Another more likely source possibility is some faint field line movement on the ESE limb best seen in SDO AIA 171 starting at 2024-11-24T23:21Z.",
#         "submissionTime": "2024-11-25T18:23Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35311/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-25T11:18Z",
#                 "latitude": 2.0,
#                 "longitude": null,
#                 "halfAngle": 10.0,
#                 "speed": 332.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "Plane-of-sky",
#                 "note": "Plane-of-sky measurement made using SWPC_CAT based on running difference imagery from SOHO LASCO C2/C3.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-11-25T18:24Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35312/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-25T01:48:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-25T01:48Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "CME first seen to the NNE in SOHO LASCO C2 starting at 2024-11-25T01:48Z. CME also seen to the NNE in SOHO LASCO C3 and STEREO A COR2. This CME is very faint in white light and is better seen in running difference imagery. The source of this CME is possibly some minor brightening and movement of plasma centered around N20E25 starting around 2024-11-25T00:27Z with some northward deflection.",
#         "submissionTime": "2024-11-25T19:12Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35313/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-25T07:13Z",
#                 "latitude": 35.0,
#                 "longitude": -17.0,
#                 "halfAngle": 15.0,
#                 "speed": 619.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on the best fit between SOHO LASCO C2/C3 and STEREO A COR2 in SWPC_CAT as well as potential source location.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-11-25T19:13Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35314/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-25T03:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-25T03:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "CME first seen to the SSE in SOHO LASCO C2 starting at 2024-11-25T03:12Z. CME also seen to the SSE in SOHO LASCO C3 and STEREO A COR2. The source of this CME is likely a small filament eruption centered around S40-45E28 that is visible in SDO AIA 304 and SDO AIA 193 starting about 2024-11-25T01:30Z.",
#         "submissionTime": "2024-11-25T13:58Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35303/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-25T12:37Z",
#                 "latitude": -42.0,
#                 "longitude": -31.0,
#                 "halfAngle": 31.0,
#                 "speed": 382.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on the best fit between SOHO LASCO C2/C3 and STEREO A COR2 in SWPC_CAT as well as potential source location.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-11-25T14:00Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35304/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-25T15:38Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2024-11-28T20:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 2,
#                         "kp_135": 3,
#                         "kp_180": 4,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/35308/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "BepiColombo",
#                                 "arrivalTime": "2024-11-26T10:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Europa Clipper",
#                                 "arrivalTime": "2024-11-29T00:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Juice",
#                                 "arrivalTime": "2024-11-27T20:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-11-28T16:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-11-28T18:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-11-29T02:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-25T03:12:00-CME-001",
#                             "2024-11-25T04:00:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-25T04:00:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-25T04:00Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "CME first visible to the SSE in SOHO LASCO C2 starting at 2024-11-25T04:00Z. Also visible to the SSE in SOHO LASCO C3 and STEREO A COR2. This CME closely follows CME: 2024-11-25T03:12Z but is slightly slower and slightly wider and is clearly distinguishable in running difference imagery. There is not a clearly definitive source for this CME, but a possible candidate is a deflected source associated with an M1.1 flare from AR 3906 (S13E46) that peaked at 2024-11-25T01:59Z.",
#         "submissionTime": "2024-11-25T14:06Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35305/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-25T14:50Z",
#                 "latitude": -33.0,
#                 "longitude": -16.0,
#                 "halfAngle": 33.0,
#                 "speed": 315.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on the best fit between SOHO LASCO C2/C3 and STEREO A COR2 in SWPC_CAT.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-11-25T14:07Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35306/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-25T15:38Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2024-11-28T20:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 2,
#                         "kp_135": 3,
#                         "kp_180": 4,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/35308/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "BepiColombo",
#                                 "arrivalTime": "2024-11-26T10:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Europa Clipper",
#                                 "arrivalTime": "2024-11-29T00:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Juice",
#                                 "arrivalTime": "2024-11-27T20:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-11-28T16:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-11-28T18:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-11-29T02:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-25T03:12:00-CME-001",
#                             "2024-11-25T04:00:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     }
# ]

# %%
# Convert cme_json to a Pandas DataFrame 
df = pd.DataFrame(cme_json)
df

# Keep only the columns: activityID, startTime, linkedEvents
df= df[['activityID', 'startTime', 'linkedEvents']]
df.head()

#call the data base [ then pick columns [
# Out:
#                     activityID          startTime  \
# 0  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
# 1  2024-10-26T08:09:00-CME-001  2024-10-26T08:09Z
# 2  2024-10-26T08:12:00-CME-001  2024-10-26T08:12Z
# 3  2024-10-26T12:23:00-CME-001  2024-10-26T12:23Z
# 4  2024-10-26T17:38:00-CME-001  2024-10-26T17:38Z
#
#                                         linkedEvents
# 0  [{'activityID': '2024-10-26T05:57:00-FLR-001'}...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None

# %%
# Notice that the linkedEvents column allows us to identify the corresponding GST
# Remove rows with missing 'linkedEvents' since we won't be able to assign these to GSTs
df_cleaned = df.dropna(subset="linkedEvents")
df_cleaned
# Out:
#                       activityID          startTime  \
# 0    2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
# 12   2024-10-29T13:23:00-CME-001  2024-10-29T13:23Z
# 32   2024-10-31T13:48:00-CME-001  2024-10-31T13:48Z
# 34   2024-10-31T22:36:00-CME-001  2024-10-31T22:36Z
# 40   2024-11-03T15:27:00-CME-001  2024-11-03T15:27Z
# 42   2024-11-04T01:36:00-CME-001  2024-11-04T01:36Z
# 43   2024-11-04T13:23:00-CME-001  2024-11-04T13:23Z
# 44   2024-11-04T17:24:00-CME-001  2024-11-04T17:24Z
# 45   2024-11-05T00:09:00-CME-001  2024-11-05T00:09Z
# 46   2024-11-05T07:36:00-CME-001  2024-11-05T07:36Z
# 49   2024-11-05T16:09:00-CME-001  2024-11-05T16:09Z
# 54   2024-11-06T16:48:00-CME-001  2024-11-06T16:48Z
# 56   2024-11-06T23:36:00-CME-001  2024-11-06T23:36Z
# 70   2024-11-10T12:36:00-CME-001  2024-11-10T12:36Z
# 71   2024-11-10T17:12:00-CME-001  2024-11-10T17:12Z
# 72   2024-11-10T23:09:00-CME-001  2024-11-10T23:09Z
# 73   2024-11-11T01:23:00-CME-001  2024-11-11T01:23Z
# 81   2024-11-12T13:36:00-CME-001  2024-11-12T13:36Z
# 96   2024-11-15T02:48:00-CME-001  2024-11-15T02:48Z
# 111  2024-11-17T11:24:00-CME-001  2024-11-17T11:24Z
# 116  2024-11-18T12:12:00-CME-001  2024-11-18T12:12Z
# 117  2024-11-18T19:24:00-CME-001  2024-11-18T19:24Z
# 124  2024-11-20T20:00:00-CME-001  2024-11-20T20:00Z
# 128  2024-11-21T18:12:00-CME-001  2024-11-21T18:12Z
# 140  2024-11-22T22:12:00-CME-001  2024-11-22T22:12Z
# 148  2024-11-23T19:24:00-CME-001  2024-11-23T19:24Z
#
#                                           linkedEvents
# 0    [{'activityID': '2024-10-26T05:57:00-FLR-001'}...
# 12   [{'activityID': '2024-10-31T19:28:00-IPS-001'}...
# 32   [{'activityID': '2024-11-03T16:47:00-IPS-001'}...
# 34     [{'activityID': '2024-10-31T21:12:00-FLR-001'}]
# 40     [{'activityID': '2024-11-03T15:13:00-FLR-001'}]
# 42   [{'activityID': '2024-11-04T01:05:00-FLR-001'}...
# 43     [{'activityID': '2024-11-04T11:46:00-FLR-001'}]
# 44   [{'activityID': '2024-11-04T15:26:00-FLR-001'}...
# 45     [{'activityID': '2024-11-07T14:29:00-IPS-001'}]
# 46     [{'activityID': '2024-11-05T06:35:00-FLR-001'}]
# 49     [{'activityID': '2024-11-05T15:05:00-FLR-001'}]
# 54     [{'activityID': '2024-11-06T15:50:00-FLR-001'}]
# 56     [{'activityID': '2024-11-06T23:10:00-FLR-001'}]
# 70     [{'activityID': '2024-11-10T11:51:00-FLR-001'}]
# 71     [{'activityID': '2024-11-10T15:51:00-FLR-001'}]
# 72     [{'activityID': '2024-11-10T22:31:00-FLR-001'}]
# 73     [{'activityID': '2024-11-14T03:32:00-IPS-001'}]
# 81     [{'activityID': '2024-11-12T12:47:00-FLR-001'}]
# 96     [{'activityID': '2024-11-15T01:38:00-FLR-001'}]
# 111    [{'activityID': '2024-11-17T10:38:00-FLR-001'}]
# 116  [{'activityID': '2024-11-18T11:06:00-FLR-001'}...
# 117    [{'activityID': '2024-11-18T18:45:00-FLR-001'}]
# 124    [{'activityID': '2024-11-20T19:11:00-FLR-001'}]
# 128  [{'activityID': '2024-11-21T18:45:00-SEP-001'}...
# 140    [{'activityID': '2024-11-22T21:26:00-FLR-001'}]
# 148    [{'activityID': '2024-11-23T19:01:00-FLR-001'}]

# %%
# Notice that the linkedEvents sometimes contains multiple events per row
# Write a nested for loop that iterates first over each row in the cme DataFrame (using the index)
# and then iterates over the values in 'linkedEvents' 
# and adds the elements individually to a list of dictionaries where each row is one element 
# Initialize an empty list to store the expanded rows
# Iterate over each index in the DataFrame
# Iterate over each dictionary in the list
# # Append a new dictionary to the expanded_rows list for each dictionary item and corresponding 'activityID' and 'startTime' value
#Create a new DataFrame from the expanded rows
#ASK TA!!!!!!!!!!!!!!!!!!! - result is fine. Dont need function but it woks so its fine. 

expanded_rows = []
for index, row in df_cleaned.iterrows():
    activityID = row['activityID']
    startTime = row['startTime']
    linkedEvents = row['linkedEvents']
    for event in linkedEvents:
        expanded_rows.append({'activityID': activityID, 'startTime': startTime, 'linkedEvents': event})
    
df_expanded = pd.DataFrame(expanded_rows)
df_expanded.head()
# Out:
#                     activityID          startTime  \
# 0  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
# 1  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
# 2  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
# 3  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
# 4  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
#
#                                     linkedEvents
# 0  {'activityID': '2024-10-26T05:57:00-FLR-001'}
# 1  {'activityID': '2024-10-26T06:32:00-FLR-001'}
# 2  {'activityID': '2024-10-26T16:45:00-SEP-001'}
# 3  {'activityID': '2024-10-26T18:05:00-SEP-001'}
# 4  {'activityID': '2024-10-26T18:57:00-SEP-001'}

# %%
# Create a function called extract_activityID_from_dict that 
# takes a dict as input such as in linkedEvents
# and verify below that it works as expected using 
# one row from linkedEvents as an example
# Be sure to use a try and except block to handle errors
# Log the error or print it for debugging


# Create a function called extract_activityID_from_dict that takes a dict as input such as in linkedEvents and extracts the value of that dict
def extract_activityID_from_dict(input_dict):
        try:
                activityID = input_dict.get('activityID', None)
                return activityID
        except (ValueError, TypeError) as e:
                print(f"Error processing input dictionary: {input_dict}. Error: {e}")
                return None

extract_activityID_from_dict(df_expanded.loc[0,'linkedEvents'])
# Out:
# '2024-10-26T05:57:00-FLR-001'

# %%
# Apply this function to each row in the 'linkedEvents' column (you can use apply() and a lambda function)
# and create a new column called 'GST_ActivityID' using loc indexer:
# Apply the function to the 'linkedEvents' column
# Verify the new column
# Define the function

df_expanded.loc[:, 'GST_ActivityID']= df_expanded['linkedEvents'].apply(lambda x: extract_activityID_from_dict(x))
df_expanded.head()
# Out:
#                     activityID          startTime  \
# 0  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
# 1  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
# 2  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
# 3  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
# 4  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
#
#                                     linkedEvents               GST_ActivityID
# 0  {'activityID': '2024-10-26T05:57:00-FLR-001'}  2024-10-26T05:57:00-FLR-001
# 1  {'activityID': '2024-10-26T06:32:00-FLR-001'}  2024-10-26T06:32:00-FLR-001
# 2  {'activityID': '2024-10-26T16:45:00-SEP-001'}  2024-10-26T16:45:00-SEP-001
# 3  {'activityID': '2024-10-26T18:05:00-SEP-001'}  2024-10-26T18:05:00-SEP-001
# 4  {'activityID': '2024-10-26T18:57:00-SEP-001'}  2024-10-26T18:57:00-SEP-001

# %%
# Remove rows with missing GST_ActivityID, since we can't assign them to GSTs:
df_expanded = df_expanded.dropna(subset="GST_ActivityID")
df_expanded.head()
# Out:
#                     activityID          startTime  \
# 0  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
# 1  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
# 2  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
# 3  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
# 4  2024-10-26T06:48:00-CME-001  2024-10-26T06:48Z
#
#                                     linkedEvents               GST_ActivityID
# 0  {'activityID': '2024-10-26T05:57:00-FLR-001'}  2024-10-26T05:57:00-FLR-001
# 1  {'activityID': '2024-10-26T06:32:00-FLR-001'}  2024-10-26T06:32:00-FLR-001
# 2  {'activityID': '2024-10-26T16:45:00-SEP-001'}  2024-10-26T16:45:00-SEP-001
# 3  {'activityID': '2024-10-26T18:05:00-SEP-001'}  2024-10-26T18:05:00-SEP-001
# 4  {'activityID': '2024-10-26T18:57:00-SEP-001'}  2024-10-26T18:57:00-SEP-001

# %%
# print out the datatype of each column in this DataFrame:
df_expanded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   activityID      51 non-null     object
#  1   startTime       51 non-null     object
#  2   linkedEvents    51 non-null     object
#  3   GST_ActivityID  51 non-null     object
# dtypes: object(4)
# memory usage: 1.7+ KB

# %%
#ASK!!!!!!!!!!!!!!!!!!!!!! #I only have 50 rows of Data...

# Convert the 'GST_ActivityID' column to string format 
df_expanded['GST_ActivityID'] = df_expanded['GST_ActivityID'].astype(str)

# Convert startTime to datetime format  
df_expanded["startTime"] = pd.to_datetime(df_expanded['startTime'])

# Rename startTime to startTime_CME and activityID to cmeID
df_expanded = df_expanded.rename(columns={
    'startTime': 'startTime_CME',
    'activityID': 'cmeID'
})

# Drop linkedEvents
df_expanded = df_expanded.drop(columns =['linkedEvents'])

# Verify that all steps were executed correctly
df_expanded
# Out:
#                           cmeID             startTime_CME  \
# 0   2024-10-26T06:48:00-CME-001 2024-10-26 06:48:00+00:00
# 1   2024-10-26T06:48:00-CME-001 2024-10-26 06:48:00+00:00
# 2   2024-10-26T06:48:00-CME-001 2024-10-26 06:48:00+00:00
# 3   2024-10-26T06:48:00-CME-001 2024-10-26 06:48:00+00:00
# 4   2024-10-26T06:48:00-CME-001 2024-10-26 06:48:00+00:00
# 5   2024-10-26T06:48:00-CME-001 2024-10-26 06:48:00+00:00
# 6   2024-10-26T06:48:00-CME-001 2024-10-26 06:48:00+00:00
# 7   2024-10-26T06:48:00-CME-001 2024-10-26 06:48:00+00:00
# 8   2024-10-26T06:48:00-CME-001 2024-10-26 06:48:00+00:00
# 9   2024-10-26T06:48:00-CME-001 2024-10-26 06:48:00+00:00
# 10  2024-10-26T06:48:00-CME-001 2024-10-26 06:48:00+00:00
# 11  2024-10-26T06:48:00-CME-001 2024-10-26 06:48:00+00:00
# 12  2024-10-29T13:23:00-CME-001 2024-10-29 13:23:00+00:00
# 13  2024-10-29T13:23:00-CME-001 2024-10-29 13:23:00+00:00
# 14  2024-10-31T13:48:00-CME-001 2024-10-31 13:48:00+00:00
# 15  2024-10-31T13:48:00-CME-001 2024-10-31 13:48:00+00:00
# 16  2024-10-31T22:36:00-CME-001 2024-10-31 22:36:00+00:00
# 17  2024-11-03T15:27:00-CME-001 2024-11-03 15:27:00+00:00
# 18  2024-11-04T01:36:00-CME-001 2024-11-04 01:36:00+00:00
# 19  2024-11-04T01:36:00-CME-001 2024-11-04 01:36:00+00:00
# 20  2024-11-04T13:23:00-CME-001 2024-11-04 13:23:00+00:00
# 21  2024-11-04T17:24:00-CME-001 2024-11-04 17:24:00+00:00
# 22  2024-11-04T17:24:00-CME-001 2024-11-04 17:24:00+00:00
# 23  2024-11-04T17:24:00-CME-001 2024-11-04 17:24:00+00:00
# 24  2024-11-05T00:09:00-CME-001 2024-11-05 00:09:00+00:00
# 25  2024-11-05T07:36:00-CME-001 2024-11-05 07:36:00+00:00
# 26  2024-11-05T16:09:00-CME-001 2024-11-05 16:09:00+00:00
# 27  2024-11-06T16:48:00-CME-001 2024-11-06 16:48:00+00:00
# 28  2024-11-06T23:36:00-CME-001 2024-11-06 23:36:00+00:00
# 29  2024-11-10T12:36:00-CME-001 2024-11-10 12:36:00+00:00
# 30  2024-11-10T17:12:00-CME-001 2024-11-10 17:12:00+00:00
# 31  2024-11-10T23:09:00-CME-001 2024-11-10 23:09:00+00:00
# 32  2024-11-11T01:23:00-CME-001 2024-11-11 01:23:00+00:00
# 33  2024-11-12T13:36:00-CME-001 2024-11-12 13:36:00+00:00
# 34  2024-11-15T02:48:00-CME-001 2024-11-15 02:48:00+00:00
# 35  2024-11-17T11:24:00-CME-001 2024-11-17 11:24:00+00:00
# 36  2024-11-18T12:12:00-CME-001 2024-11-18 12:12:00+00:00
# 37  2024-11-18T12:12:00-CME-001 2024-11-18 12:12:00+00:00
# 38  2024-11-18T19:24:00-CME-001 2024-11-18 19:24:00+00:00
# 39  2024-11-20T20:00:00-CME-001 2024-11-20 20:00:00+00:00
# 40  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 41  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 42  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 43  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 44  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 45  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 46  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 47  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 48  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 49  2024-11-22T22:12:00-CME-001 2024-11-22 22:12:00+00:00
# 50  2024-11-23T19:24:00-CME-001 2024-11-23 19:24:00+00:00
#
#                  GST_ActivityID
# 0   2024-10-26T05:57:00-FLR-001
# 1   2024-10-26T06:32:00-FLR-001
# 2   2024-10-26T16:45:00-SEP-001
# 3   2024-10-26T18:05:00-SEP-001
# 4   2024-10-26T18:57:00-SEP-001
# 5   2024-10-26T19:02:00-SEP-001
# 6   2024-10-26T19:50:00-SEP-001
# 7   2024-10-26T20:06:00-SEP-001
# 8   2024-10-26T21:43:00-SEP-001
# 9   2024-10-28T04:13:00-IPS-001
# 10  2024-10-28T08:57:00-SEP-001
# 11  2024-10-28T16:58:00-IPS-001
# 12  2024-10-31T19:28:00-IPS-001
# 13  2024-11-01T00:02:00-IPS-001
# 14  2024-11-03T16:47:00-IPS-001
# 15  2024-11-07T15:35:00-RBE-001
# 16  2024-10-31T21:12:00-FLR-001
# 17  2024-11-03T15:13:00-FLR-001
# 18  2024-11-04T01:05:00-FLR-001
# 19  2024-11-06T16:20:00-IPS-001
# 20  2024-11-04T11:46:00-FLR-001
# 21  2024-11-04T15:26:00-FLR-001
# 22  2024-11-04T15:36:00-FLR-001
# 23  2024-11-07T14:29:00-IPS-001
# 24  2024-11-07T14:29:00-IPS-001
# 25  2024-11-05T06:35:00-FLR-001
# 26  2024-11-05T15:05:00-FLR-001
# 27  2024-11-06T15:50:00-FLR-001
# 28  2024-11-06T23:10:00-FLR-001
# 29  2024-11-10T11:51:00-FLR-001
# 30  2024-11-10T15:51:00-FLR-001
# 31  2024-11-10T22:31:00-FLR-001
# 32  2024-11-14T03:32:00-IPS-001
# 33  2024-11-12T12:47:00-FLR-001
# 34  2024-11-15T01:38:00-FLR-001
# 35  2024-11-17T10:38:00-FLR-001
# 36  2024-11-18T11:06:00-FLR-001
# 37  2024-11-22T00:47:00-IPS-001
# 38  2024-11-18T18:45:00-FLR-001
# 39  2024-11-20T19:11:00-FLR-001
# 40  2024-11-21T18:45:00-SEP-001
# 41  2024-11-21T19:10:00-SEP-001
# 42  2024-11-21T19:19:00-SEP-001
# 43  2024-11-21T19:21:00-SEP-001
# 44  2024-11-21T19:23:00-SEP-002
# 45  2024-11-21T19:23:00-SEP-001
# 46  2024-11-21T19:24:00-SEP-001
# 47  2024-11-21T19:24:00-SEP-002
# 48  2024-11-21T19:25:00-SEP-001
# 49  2024-11-22T21:26:00-FLR-001
# 50  2024-11-23T19:01:00-FLR-001

# %%
# We are only interested in CMEs related to GSTs so keep only rows where the GST_ActivityID column contains 'GST'
# use the method 'contains()' from the str library.  
#nameofcolumn.str.contains("whatever you're trying to match on")
#ASKKKKKKKKKKK

df_expanded[df_expanded["GST_ActivityID"].str.contains("GST")]
# Out:
# Empty DataFrame
# Columns: [cmeID, startTime_CME, GST_ActivityID]
# Index: []

# %% [markdown]
# ### GST Data

# %%
# Set the base URL to NASA's DONKI API:
base_url = "https://api.nasa.gov/DONKI/"

# Set the specifier for GSTs:
GST = "GST"

# Search for GSTs published between a begin and end date
startDate = "2013-05-01"
endDate   = "2024-05-01"

# Build URL for GST
gst_url = f'{base_url}{GST}?startDate={startDate}&endDate={endDate}&api_key={NASA_API_KEY}'
gst_url
# Out:
# 'https://api.nasa.gov/DONKI/GST?startDate=2013-05-01&endDate=2024-05-01&api_key=xd6laDXZahJaqfGeG0teFyg5EjIWGziP7XsdnUjm'

# %%
# Make a "GET" request for the GST URL and store it in a variable named gst_response
gst_response = requests.get(gst_url)
gst_response.url
# Out:
# 'https://api.nasa.gov/DONKI/GST?startDate=2013-05-01&endDate=2024-05-01&api_key=xd6laDXZahJaqfGeG0teFyg5EjIWGziP7XsdnUjm'

# %%
# Convert the response variable to json and store it as a variable named gst_json

# Preview the first result in JSON format
# Use json.dumps with argument indent=4 to format data

#why is the data not printing

gst_json = gst_response.json()
print(json.dumps(gst_json, indent=4))
# Out:
# [
#     {
#         "gstID": "2013-06-01T01:00:00-GST-001",
#         "startTime": "2013-06-01T01:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2013-06-01T01:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/326/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2013-05-31T15:45:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2013-07-15T19:26Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2013-06-07T03:00:00-GST-001",
#         "startTime": "2013-06-07T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2013-06-07T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/330/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2013-06-02T20:24:00-CME-001"
#             }
#         ],
#         "submissionTime": "2013-07-15T19:41Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2013-06-29T03:00:00-GST-001",
#         "startTime": "2013-06-29T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2013-06-29T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2013-06-29T06:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/561/-1",
#         "linkedEvents": null,
#         "submissionTime": "2013-09-25T04:48Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2013-10-02T03:00:00-GST-001",
#         "startTime": "2013-10-02T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2013-10-02T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/3317/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2013-09-29T22:40:00-CME-001"
#             },
#             {
#                 "activityID": "2013-10-02T01:54:00-IPS-001"
#             },
#             {
#                 "activityID": "2013-10-02T02:47:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2013-10-02T13:23Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2013-12-08T00:00:00-GST-001",
#         "startTime": "2013-12-08T00:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2013-12-08T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/3738/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2013-12-04T23:12:00-CME-001"
#             },
#             {
#                 "activityID": "2013-12-07T21:30:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2013-12-08T03:42Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2014-02-19T03:00:00-GST-001",
#         "startTime": "2014-02-19T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2014-02-19T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/4632/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2014-02-16T14:15:00-CME-001"
#             },
#             {
#                 "activityID": "2014-02-19T03:10:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2014-03-18T23:25Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2014-02-20T03:00:00-GST-001",
#         "startTime": "2014-02-20T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2014-02-20T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/4633/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2014-02-18T01:25:00-CME-001"
#             },
#             {
#                 "activityID": "2014-02-20T02:50:00-IPS-001"
#             },
#             {
#                 "activityID": "2014-02-20T05:14:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2014-03-19T20:13Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2014-02-27T18:00:00-GST-001",
#         "startTime": "2014-02-27T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2014-02-27T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/4640/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2014-02-25T01:25:00-CME-001"
#             },
#             {
#                 "activityID": "2014-02-27T16:10:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2014-03-19T22:41Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2014-06-08T03:00:00-GST-001",
#         "startTime": "2014-06-08T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2014-06-08T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2014-06-08T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/5691/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2014-06-04T13:25:00-CME-001"
#             },
#             {
#                 "activityID": "2014-06-07T16:09:00-IPS-001"
#             },
#             {
#                 "activityID": "2014-06-08T05:08:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2014-06-08T05:28Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2014-08-19T21:00:00-GST-001",
#         "startTime": "2014-08-19T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2014-08-20T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/6430/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2014-08-15T21:12:00-CME-001"
#             },
#             {
#                 "activityID": "2014-08-19T05:57:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2014-08-20T00:37Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2014-09-12T15:00:00-GST-001",
#         "startTime": "2014-09-12T15:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2014-09-12T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2014-09-13T00:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/6639/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2014-09-10T18:18:00-CME-001"
#             },
#             {
#                 "activityID": "2014-09-12T15:26:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2014-09-12T18:11Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-01-07T06:00:00-GST-001",
#         "startTime": "2015-01-07T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-01-07T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-01-07T12:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/7537/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-01-07T05:24:00-IPS-001"
#             },
#             {
#                 "activityID": "2015-01-07T08:40:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2015-01-07T13:42Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2015-03-17T06:00:00-GST-001",
#         "startTime": "2015-03-17T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-03-17T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-17T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-17T15:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-17T18:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-17T21:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-18T00:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-18T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-18T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8031/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-03-15T02:00:00-CME-001"
#             },
#             {
#                 "activityID": "2015-03-17T04:05:00-IPS-001"
#             },
#             {
#                 "activityID": "2015-03-16T00:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-03-18T18:43Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2015-03-22T06:00:00-GST-001",
#         "startTime": "2015-03-22T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-03-22T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8077/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-03-21T20:25:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2015-03-22T09:34Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-04-10T03:00:00-GST-001",
#         "startTime": "2015-04-10T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-04-10T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-04-10T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-04-10T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8201/-1",
#         "linkedEvents": null,
#         "submissionTime": "2015-04-10T06:11Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-04-16T21:00:00-GST-001",
#         "startTime": "2015-04-16T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-04-17T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8246/-1",
#         "linkedEvents": null,
#         "submissionTime": "2015-04-17T00:14Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-05-13T03:00:00-GST-001",
#         "startTime": "2015-05-13T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-05-13T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-05-13T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8487/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-05-12T17:20:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-05-13T06:28Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-05-13T04:30:00-GST-001",
#         "startTime": "2015-05-13T04:30Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-05-13T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8489/-1",
#         "linkedEvents": null,
#         "submissionTime": "2015-05-13T12:08Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-05-19T00:00:00-GST-001",
#         "startTime": "2015-05-19T00:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-05-19T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-05-19T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8521/-1",
#         "linkedEvents": null,
#         "submissionTime": "2015-05-19T03:50Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-06-08T06:00:00-GST-001",
#         "startTime": "2015-06-08T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-06-08T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8621/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-06-08T00:16:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-06-08T09:10Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-06-22T18:00:00-GST-001",
#         "startTime": "2015-06-22T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-06-22T21:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-06-22T21:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-06-23T03:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-06-23T06:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-06-23T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-06-23T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8763/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-06-21T02:48:00-CME-001"
#             },
#             {
#                 "activityID": "2015-06-22T17:59:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2015-06-22T21:22Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-06-25T06:00:00-GST-001",
#         "startTime": "2015-06-25T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-06-25T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8802/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-06-22T18:36:00-CME-001"
#             },
#             {
#                 "activityID": "2015-06-24T12:57:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2015-06-25T09:24Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-07-04T13:00:00-GST-001",
#         "startTime": "2015-07-04T13:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-07-05T00:00Z",
#                 "kpIndex": 5.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-07-05T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-07-05T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/8862/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-07-04T11:58:00-IPS-001"
#             },
#             {
#                 "activityID": "2015-07-04T11:59:00-HSS-001"
#             },
#             {
#                 "activityID": "2015-07-04T20:20:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2015-07-05T01:39Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-08-15T09:00:00-GST-001",
#         "startTime": "2015-08-15T09:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-08-15T12:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-08-15T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-08-16T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9113/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-08-12T15:12:00-CME-001"
#             },
#             {
#                 "activityID": "2015-08-13T00:30:00-CME-001"
#             },
#             {
#                 "activityID": "2015-08-15T07:43:00-IPS-001"
#             },
#             {
#                 "activityID": "2015-08-15T11:03:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2015-08-15T12:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-08-23T06:00:00-GST-001",
#         "startTime": "2015-08-23T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-08-23T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9162/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-08-23T07:15:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-08-23T09:10Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-08-27T03:00:00-GST-001",
#         "startTime": "2015-08-27T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-08-27T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-08-27T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9200/-1",
#         "linkedEvents": null,
#         "submissionTime": "2015-08-27T06:43Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-08-27T21:00:00-GST-001",
#         "startTime": "2015-08-27T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-08-28T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-08-28T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9210/-1",
#         "linkedEvents": null,
#         "submissionTime": "2015-08-28T00:29Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-08-28T18:00:00-GST-001",
#         "startTime": "2015-08-28T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-08-28T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9230/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-08-28T16:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-08-31T13:46Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-09-07T15:00:00-GST-001",
#         "startTime": "2015-09-07T15:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-09-07T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-07T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-08T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-08T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-08T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9274/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-09-07T12:22:00-HSS-001"
#             },
#             {
#                 "activityID": "2015-09-07T13:20:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2015-09-09T16:52Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2015-09-09T03:00:00-GST-001",
#         "startTime": "2015-09-09T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-09-09T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-09T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-09T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-09T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-10T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9294/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-09-04T14:12:00-CME-001"
#             },
#             {
#                 "activityID": "2015-09-04T19:24:00-CME-001"
#             }
#         ],
#         "submissionTime": "2015-09-09T15:16Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2015-09-11T06:00:00-GST-001",
#         "startTime": "2015-09-11T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-09-11T09:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-11T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-11T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9302/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-09-06T23:30:00-CME-001"
#             },
#             {
#                 "activityID": "2015-09-07T10:36:00-CME-001"
#             },
#             {
#                 "activityID": "2015-09-11T06:43:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-09-11T09:32Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-09-20T06:00:00-GST-001",
#         "startTime": "2015-09-20T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-09-20T09:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9349/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-09-18T05:00:00-CME-001"
#             },
#             {
#                 "activityID": "2015-09-20T05:33:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2015-09-20T09:16Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-09-20T09:00:00-GST-001",
#         "startTime": "2015-09-20T09:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-09-20T12:00Z",
#                 "kpIndex": 5.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9352/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-09-18T05:00:00-CME-001"
#             },
#             {
#                 "activityID": "2015-09-20T05:33:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2015-09-20T13:39Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-10-07T18:00:00-GST-001",
#         "startTime": "2015-10-07T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-10-07T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-07T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-07T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-07T21:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-07T21:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-08T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-08T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-08T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9466/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-10-07T13:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-10-07T20:04Z",
#         "versionId": 3
#     },
#     {
#         "gstID": "2015-11-07T03:00:00-GST-001",
#         "startTime": "2015-11-07T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-11-07T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-11-07T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9662/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-11-04T14:24:00-CME-001"
#             },
#             {
#                 "activityID": "2015-11-06T17:34:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2015-11-07T06:43Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-11-10T12:00:00-GST-001",
#         "startTime": "2015-11-10T12:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-11-10T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9682/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-11-09T19:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2015-11-10T15:36Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-12-20T03:00:00-GST-001",
#         "startTime": "2015-12-20T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-12-20T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-12-20T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-12-20T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-12-21T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-12-21T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-12-21T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9878/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-12-16T09:36:00-CME-001"
#             },
#             {
#                 "activityID": "2015-12-16T14:48:00-CME-001"
#             },
#             {
#                 "activityID": "2015-12-19T15:27:00-IPS-001"
#             },
#             {
#                 "activityID": "2015-12-20T00:04:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2015-12-20T06:47Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2015-12-31T13:30:00-GST-001",
#         "startTime": "2015-12-31T13:30Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-12-31T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-12-31T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-01-01T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-01-01T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/9956/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2015-12-28T12:39:00-CME-001"
#             },
#             {
#                 "activityID": "2015-12-31T23:52:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2015-12-31T15:32Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-01-21T03:00:00-GST-001",
#         "startTime": "2016-01-21T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-01-21T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10074/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-01-15T00:00:00-CME-001"
#             },
#             {
#                 "activityID": "2016-01-21T10:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-01-21T06:28Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-02-16T18:00:00-GST-001",
#         "startTime": "2016-02-16T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-02-16T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-02-16T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10217/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-02-16T01:55:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-02-16T22:00Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2016-02-17T21:00:00-GST-001",
#         "startTime": "2016-02-17T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-02-18T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10231/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-02-16T01:55:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-02-18T01:19Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "none",
#         "startTime": "2016-02-17T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-02-19T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10233/-1",
#         "linkedEvents": null,
#         "submissionTime": "2016-02-18T01:06Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2016-03-06T18:00:00-GST-001",
#         "startTime": "2016-03-06T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-03-06T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-03-06T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-03-07T00:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10302/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-03-06T04:30:00-IPS-001"
#             },
#             {
#                 "activityID": "2016-03-06T09:00:00-HSS-001"
#             },
#             {
#                 "activityID": "2016-03-06T16:32:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2016-03-06T21:35Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-03-11T12:00:00-GST-001",
#         "startTime": "2016-03-11T12:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-03-11T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-03-11T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10325/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-03-11T04:21:00-IPS-001"
#             },
#             {
#                 "activityID": "2016-03-11T13:00:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2016-03-11T15:39Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-04-02T21:00:00-GST-001",
#         "startTime": "2016-04-02T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-04-03T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10421/-1",
#         "linkedEvents": null,
#         "submissionTime": "2016-04-03T00:28Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-04-02T22:30:00-GST-001",
#         "startTime": "2016-04-02T22:30Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-04-03T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10423/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-03-31T01:25:00-CME-001"
#             }
#         ],
#         "submissionTime": "2016-04-03T00:31Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-05-02T03:00:00-GST-001",
#         "startTime": "2016-05-02T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-05-02T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10581/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-05-01T13:30:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-05-02T06:22Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-05-08T00:00:00-GST-001",
#         "startTime": "2016-05-08T00:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-05-08T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-05-08T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-05-08T06:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-05-08T06:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-05-08T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-05-09T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-05-09T03:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10610/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-05-08T01:21:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-05-08T03:31Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-06-06T03:00:00-GST-001",
#         "startTime": "2016-06-06T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-06-06T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10741/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-06-04T23:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-06-06T06:26Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-06-14T18:00:00-GST-001",
#         "startTime": "2016-06-14T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-06-14T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-06-14T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/10775/-1",
#         "linkedEvents": null,
#         "submissionTime": "2016-06-14T21:29Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-09-01T21:00:00-GST-001",
#         "startTime": "2016-09-01T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-09-02T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-09-02T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-09-03T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/11205/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-09-01T10:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-09-02T12:18Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2016-09-27T15:00:00-GST-001",
#         "startTime": "2016-09-27T15:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-09-27T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/11309/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-09-26T07:05:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-09-27T18:24Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-09-28T18:00:00-GST-001",
#         "startTime": "2016-09-28T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-09-28T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/11318/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-09-26T07:05:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-09-28T21:36Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-10-13T15:00:00-GST-001",
#         "startTime": "2016-10-13T15:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-10-13T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-10-13T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-10-14T03:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/11387/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-10-08T21:09:00-CME-001"
#             },
#             {
#                 "activityID": "2016-10-12T21:21:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2016-10-13T18:27Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-10-25T12:00:00-GST-001",
#         "startTime": "2016-10-25T12:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-10-25T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-10-25T15:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-10-25T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-10-26T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-10-26T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2016-10-26T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/11438/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-10-25T09:29:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-10-25T14:16Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-11-25T03:00:00-GST-001",
#         "startTime": "2016-11-25T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-11-25T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/11725/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-11-24T05:14:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-11-25T06:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2016-12-21T15:00:00-GST-001",
#         "startTime": "2016-12-21T15:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2016-12-21T18:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/12019/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2016-12-21T03:37:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2016-12-21T18:44Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2017-03-01T23:00:00-GST-001",
#         "startTime": "2017-03-01T23:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2017-03-02T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2017-03-02T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/12246/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2017-03-01T06:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2017-03-01T23:56Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2017-03-27T09:00:00-GST-001",
#         "startTime": "2017-03-27T09:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2017-03-27T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2017-03-27T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2017-03-27T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/12324/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2017-03-27T00:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2017-03-27T12:18Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2017-04-20T03:00:00-GST-001",
#         "startTime": "2017-04-20T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2017-04-20T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/12475/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2017-04-18T18:02:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2017-04-20T06:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2017-04-22T03:00:00-GST-001",
#         "startTime": "2017-04-22T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2017-04-22T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/12490/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2017-04-18T18:02:00-HSS-001"
#             },
#             {
#                 "activityID": "2017-04-21T11:20:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2017-04-22T06:38Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2017-04-23T06:00:00-GST-001",
#         "startTime": "2017-04-23T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2017-04-23T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/12495/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2017-04-21T11:20:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2017-04-23T14:55Z",
#         "versionId": 1
#     },
#     {
# ...
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/24366/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-03-20T02:41:00-CME-001"
#             },
#             {
#                 "activityID": "2023-03-20T14:42:00-CME-001"
#             },
#             {
#                 "activityID": "2023-03-23T09:10:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-03-23T14:52:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-03-23T15:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-04-23T18:00:00-GST-001",
#         "startTime": "2023-04-23T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-04-23T21:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-04-24T00:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-04-24T03:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-04-24T06:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-04-24T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-04-24T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/24772/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-04-21T18:12:00-CME-001"
#             },
#             {
#                 "activityID": "2023-04-23T17:00:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-04-23T19:15:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-04-23T21:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-05-06T03:00:00-GST-001",
#         "startTime": "2023-05-06T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-05-06T06:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/24962/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-05-06T00:25:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2023-05-06T06:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-05-20T00:00:00-GST-001",
#         "startTime": "2023-05-20T00:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-05-20T03:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-05-20T06:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/25253/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-05-19T20:36:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-05-20T03:34:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2023-05-20T13:21Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2023-05-21T18:00:00-GST-001",
#         "startTime": "2023-05-21T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-05-21T21:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-05-22T00:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/25292/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-05-21T14:20:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2023-05-22T12:00Z",
#         "versionId": 3
#     },
#     {
#         "gstID": "2023-06-15T21:00:00-GST-001",
#         "startTime": "2023-06-15T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-06-16T00:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-06-16T06:00Z",
#                 "kpIndex": 6.33,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/25577/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-06-15T05:46:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-06-15T09:15:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2023-06-16T00:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-08-05T03:00:00-GST-001",
#         "startTime": "2023-08-05T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-08-05T06:00Z",
#                 "kpIndex": 6.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/26336/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-08-02T09:12:00-CME-001"
#             },
#             {
#                 "activityID": "2023-08-05T02:10:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2023-08-05T06:39Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-09-03T00:00:00-GST-001",
#         "startTime": "2023-09-03T00:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-09-03T03:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/26745/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-09-01T18:00:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2023-09-06T15:14Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2023-09-12T15:00:00-GST-001",
#         "startTime": "2023-09-12T15:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-09-12T18:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/26894/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-09-12T10:18:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-09-12T13:46:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-09-12T18:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-09-19T00:00:00-GST-001",
#         "startTime": "2023-09-19T00:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-09-19T03:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-09-19T06:00Z",
#                 "kpIndex": 6.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/26987/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-09-14T23:12:00-CME-001"
#             },
#             {
#                 "activityID": "2023-09-16T09:12:00-CME-001"
#             },
#             {
#                 "activityID": "2023-09-18T12:58:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-09-18T17:54:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-09-19T03:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-09-24T18:00:00-GST-001",
#         "startTime": "2023-09-24T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-09-24T21:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-09-25T00:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/27105/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-09-24T19:52:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-09-24T22:30:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-09-24T21:32Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-11-05T09:00:00-GST-001",
#         "startTime": "2023-11-05T09:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-11-05T12:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-11-05T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-11-05T18:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-11-05T21:00Z",
#                 "kpIndex": 6.33,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-11-06T06:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/27600/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-11-02T03:36:00-CME-001"
#             },
#             {
#                 "activityID": "2023-11-03T05:48:00-CME-001"
#             },
#             {
#                 "activityID": "2023-11-05T08:10:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-11-05T10:34:00-MPC-001"
#             },
#             {
#                 "activityID": "2023-11-05T11:45:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-11-05T14:52:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-11-06T17:27Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2023-11-25T18:00:00-GST-001",
#         "startTime": "2023-11-25T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-11-25T21:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/27882/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-11-22T21:36:00-CME-001"
#             },
#             {
#                 "activityID": "2023-11-24T18:50:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-11-24T18:50:00-HSS-001"
#             },
#             {
#                 "activityID": "2023-11-25T07:59:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-11-25T09:28:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-11-29T15:14Z",
#         "versionId": 2
#     },
#     {
#         "gstID": "2023-12-01T09:00:00-GST-001",
#         "startTime": "2023-12-01T09:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-12-01T12:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2023-12-01T15:00Z",
#                 "kpIndex": 6.33,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/27948/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-11-28T20:24:00-CME-001"
#             },
#             {
#                 "activityID": "2023-11-28T20:48:00-CME-001"
#             },
#             {
#                 "activityID": "2023-12-01T08:48:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-12-01T11:04:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-12-01T12:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2023-12-18T06:00:00-GST-001",
#         "startTime": "2023-12-18T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2023-12-18T09:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/28236/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2023-12-14T17:38:00-CME-001"
#             },
#             {
#                 "activityID": "2023-12-17T07:32:00-IPS-001"
#             },
#             {
#                 "activityID": "2023-12-17T10:54:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2023-12-18T09:34Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2024-03-03T18:00:00-GST-001",
#         "startTime": "2024-03-03T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2024-03-03T21:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/29440/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2024-02-28T17:48:00-CME-001"
#             },
#             {
#                 "activityID": "2024-03-03T08:47:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2024-03-03T21:35Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2024-03-23T21:00:00-GST-001",
#         "startTime": "2024-03-23T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2024-03-24T00:00Z",
#                 "kpIndex": 5.67,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/29751/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2024-03-23T12:49:00-IPS-001"
#             },
#             {
#                 "activityID": "2024-03-23T15:35:00-HSS-001"
#             }
#         ],
#         "submissionTime": "2024-03-24T00:33Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2024-03-24T12:00:00-GST-001",
#         "startTime": "2024-03-24T12:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2024-03-24T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2024-03-24T15:00Z",
#                 "kpIndex": 6.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2024-03-24T18:00Z",
#                 "kpIndex": 8.0,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2024-03-24T21:00Z",
#                 "kpIndex": 6.33,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/29769/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2024-03-23T01:25:00-CME-001"
#             },
#             {
#                 "activityID": "2024-03-23T01:48:00-CME-001"
#             },
#             {
#                 "activityID": "2024-03-24T14:10:00-IPS-001"
#             },
#             {
#                 "activityID": "2024-03-24T16:25:00-MPC-001"
#             }
#         ],
#         "submissionTime": "2024-03-24T15:31Z",
#         "versionId": 1
#     },
#     {
#         "gstID": "2024-04-19T18:00:00-GST-001",
#         "startTime": "2024-04-19T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2024-04-19T21:00Z",
#                 "kpIndex": 7.0,
#                 "source": "NOAA"
#             }
#         ],
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/30153/-1",
#         "linkedEvents": [
#             {
#                 "activityID": "2024-04-15T06:48:00-CME-001"
#             },
#             {
#                 "activityID": "2024-04-19T04:53:00-IPS-001"
#             }
#         ],
#         "submissionTime": "2024-04-19T21:40Z",
#         "versionId": 1
#     }
# ]

# %%
# Convert gst_json to a Pandas DataFrame  

# Keep only the columns: gstID, startTime, linkedEvents

df = pd.DataFrame(gst_json)
df

df= df[['gstID', 'startTime', 'linkedEvents']]
df.head()
# Out:
#                          gstID          startTime  \
# 0  2013-06-01T01:00:00-GST-001  2013-06-01T01:00Z
# 1  2013-06-07T03:00:00-GST-001  2013-06-07T03:00Z
# 2  2013-06-29T03:00:00-GST-001  2013-06-29T03:00Z
# 3  2013-10-02T03:00:00-GST-001  2013-10-02T03:00Z
# 4  2013-12-08T00:00:00-GST-001  2013-12-08T00:00Z
#
#                                         linkedEvents
# 0    [{'activityID': '2013-05-31T15:45:00-HSS-001'}]
# 1    [{'activityID': '2013-06-02T20:24:00-CME-001'}]
# 2                                               None
# 3  [{'activityID': '2013-09-29T22:40:00-CME-001'}...
# 4  [{'activityID': '2013-12-04T23:12:00-CME-001'}...

# %%
# Notice that the linkedEvents column allows us to identify the corresponding CME
# Remove rows with missing 'linkedEvents' since we won't be able to assign these to CME
df = df.dropna(subset=["linkedEvents"])
df.head()
# Out:
#                          gstID          startTime  \
# 0  2013-06-01T01:00:00-GST-001  2013-06-01T01:00Z
# 1  2013-06-07T03:00:00-GST-001  2013-06-07T03:00Z
# 3  2013-10-02T03:00:00-GST-001  2013-10-02T03:00Z
# 4  2013-12-08T00:00:00-GST-001  2013-12-08T00:00Z
# 5  2014-02-19T03:00:00-GST-001  2014-02-19T03:00Z
#
#                                         linkedEvents
# 0    [{'activityID': '2013-05-31T15:45:00-HSS-001'}]
# 1    [{'activityID': '2013-06-02T20:24:00-CME-001'}]
# 3  [{'activityID': '2013-09-29T22:40:00-CME-001'}...
# 4  [{'activityID': '2013-12-04T23:12:00-CME-001'}...
# 5  [{'activityID': '2014-02-16T14:15:00-CME-001'}...

# %%
# Notice that the linkedEvents sometimes contains multiple events per row
# Use the explode method to ensure that each row is one element. Ensure to reset the index and drop missing values.
df_explode = df.explode('linkedEvents', ignore_index=True).dropna()
df_explode.head()
# Out:
#                          gstID          startTime  \
# 0  2013-06-01T01:00:00-GST-001  2013-06-01T01:00Z
# 1  2013-06-07T03:00:00-GST-001  2013-06-07T03:00Z
# 2  2013-10-02T03:00:00-GST-001  2013-10-02T03:00Z
# 3  2013-10-02T03:00:00-GST-001  2013-10-02T03:00Z
# 4  2013-10-02T03:00:00-GST-001  2013-10-02T03:00Z
#
#                                     linkedEvents
# 0  {'activityID': '2013-05-31T15:45:00-HSS-001'}
# 1  {'activityID': '2013-06-02T20:24:00-CME-001'}
# 2  {'activityID': '2013-09-29T22:40:00-CME-001'}
# 3  {'activityID': '2013-10-02T01:54:00-IPS-001'}
# 4  {'activityID': '2013-10-02T02:47:00-MPC-001'}

# %%
# Apply the extract_activityID_from_dict function to each row in the 'linkedEvents' column (you can use apply() and a lambda function)
# and create a new column called 'CME_ActivityID' using loc indexer:

# Remove rows with missing CME_ActivityID, since we can't assign them to CMEs:

# %%
# Convert the 'CME_ActivityID' column to string format 
df['CME_ActivityID'] = df['CME_ActivityID'].astype(str)

# Convert the 'gstID' column to string format 

# Convert startTime to datetime format  

# Rename startTime to startTime_GST 

# Drop linkedEvents

# Verify that all steps were executed correctly
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CME_ActivityID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[308], line 2
#       1 # Convert the 'CME_ActivityID' column to string format
# ----> 2 df['CME_ActivityID'] = df['CME_ActivityID'].astype(str)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'CME_ActivityID'

# %%
# We are only interested in GSTs related to CMEs so keep only rows where the CME_ActivityID column contains 'CME'
# use the method 'contains()' from the str library.

# %% [markdown]
# ### Merge both datatsets

# %%
# Now merge both datasets using 'gstID' and 'CME_ActivityID' for gst and 'GST_ActivityID' and 'cmeID' for cme. Use the 'left_on' and 'right_on' specifiers.

# %%
# Verify that the new DataFrame has the same number of rows as cme and gst

# %% [markdown]
# ### Computing the time it takes for a CME to cause a GST

# %%
# Compute the time diff between startTime_GST and startTime_CME by creating a new column called `timeDiff`.
time_diff = startTime_GST - startTime_CME

# %%
# Use describe() to compute the mean and median time 
# that it takes for a CME to cause a GST.

# %% [markdown]
# ### Exporting data in csv format

# %%
# Export data to CSV without the index
df.to_csv('collected_data.csv', index=False)
